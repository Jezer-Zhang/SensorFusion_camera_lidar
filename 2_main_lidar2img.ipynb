# %%
from matplotlib import pyplot as plt
from torch.utils.data import DataLoader
from sensorFusionDataset.creatDataset_lidar import CreateDatasets
from sensorFusionDataset.data_split import split_dataset
from sensorFusionNetwork.simpleAutoencoder import SimpleAutoencoder
from testLoop import test_loop
from trainLoop import train_loop
from visualization import plot_losses, plot_metrics,plotTraining
from earlystopping import EarlyStopping

import h5py as h5
from datetime import datetime
import copy
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import glob
import time

local_time =time.strftime("%Y-%m-%d %H:%M:%S", time.localtime())[-8:-1]
now = datetime.now()
dt_string = now.strftime("%Y%m%d_%H%M%S")
# CPU OR GPU
device = 'cuda' if torch.cuda.is_available() else 'cpu'

img_path = 'image_gray_200_original'
lidar_path = 'lidar_tesor_200_sparse'
# lidar_path = 'lidar_tesor_200_dense'

img_list = sorted(glob.glob(img_path + '/*'))[0:7200]
lidar_list = sorted(glob.glob(lidar_path + '/*'))[0:7200]

print(len(img_list),len(lidar_list))
batch_size = 32
learning_rate = 1e-4
epochs = 600

MyDataset = CreateDatasets(img_list, lidar_list)
train_dataset, test_dataset, val_dataset = split_dataset(MyDataset, 0.7, 0.2)
train_loader = DataLoader(dataset=train_dataset, batch_size=batch_size, shuffle=True, num_workers=0,
                          drop_last=True)
test_loader = DataLoader(dataset=test_dataset, batch_size=batch_size, shuffle=True, num_workers=0,
                         drop_last=True)
val_loader = DataLoader(dataset=val_dataset, batch_size=batch_size, shuffle=False, num_workers=0,
                        drop_last=True)

# print(len(train_loader))

patience = 50	# 当验证集损失在连续20次训练周期中都没有得到降低时，停止模型训练，以防止模型过拟合
save_path = 'model_save/'
early_stopping = EarlyStopping(save_path = save_path, patience = patience)	

new_model = SimpleAutoencoder()
new_model.to(device)
# new_model.load_state_dict(torch.load('model_save/ori2ori/ori2ori_best_model_300_32_20230516_205927.pth'))

# not fix the decoder
optimizer = optim.Adam(new_model.parameters(), lr=learning_rate, betas=(0.5, 0.999))
criterion = nn.MSELoss()
criterion.to(device)

training_loss = []
training_baseloss = []
test_loss = []
testing_baseloss = []
hisLrC = []
min_loss=10000

print (f'loading fertig! {device}' )
# Out:
# 7200 7200
# loading fertig! cuda

# %%
start_time = time.time()
for epoch in range(1, epochs + 1):
    # monitor training loss
    ##############################
    # start training the model #
    ##############################
    hisLrC.append(epoch)
    train_epoch_loss, train_epoch_baseloss = train_loop(train_loader, new_model, criterion, optimizer, device)
    training_loss.append(train_epoch_loss)
    # training_baseloss.append(train_epoch_baseloss)
    print('Epoch: {}/{} \tTraining Loss: {:.6f} \t{:.0f}s'.format(epoch, epochs, train_epoch_loss,
                                                                  time.time() - start_time))

    ##############################
    # start testing the model #
    ##############################
    with torch.no_grad():
        test_epoch_loss, test_epoch_baseloss = test_loop(test_loader, new_model, criterion, device)
        test_loss.append(test_epoch_loss)
        # testing_baseloss.append(test_epoch_baseloss)
        
    # type(train_epoch_loss)) ---> float
    # writer.add_scalars('loss', {'training loss': train_epoch_loss, 'test loss': test_epoch_loss}, epoch)

        
    if test_epoch_loss < min_loss:
        min_loss = test_epoch_loss
        best_model_wts = copy.deepcopy(new_model.state_dict())
       

    if epoch == epochs:
        torch.save(best_model_wts, 'model_save/lidar2img/noFIX_lidar2img_best_model_{}_{}_{}.pth'.format(epochs, batch_size,dt_string))
        print('best_testloss:{:.3f}\t epoch:{}'.format(min_loss, test_loss.index(min_loss)))     

    # 早停止
    date = dt_string
    early_stopping(test_epoch_loss, new_model, date)
    #达到早停止条件时，early_stop会被置为True
    if early_stopping.early_stop:
        torch.save(best_model_wts, 'model_save/lidar2img/noFIX_lidar2img_best_model_{}_{}_{}.pth'.format(epochs, batch_size,dt_string))
        print('best_testloss:{:.3f}\t epoch:{}'.format(min_loss, test_loss.index(min_loss)))  
        print("Early stopping")
        break #跳出迭代，结束训练    
    
# train_baseline = sum(training_baseloss)/len(training_baseloss)
# test_baseline = sum(testing_baseloss)/len(training_baseloss)
# psnr_baseline = np.mean(psnr_base_list)

# train_baseline=train_baseline.item()
# test_baseline =test_baseline.item()
last_trainingloss = training_loss[-1]
last_testloss = test_loss[-1]


# write the dataset in one existed h5-file
now = datetime.now()
dt_string = now.strftime("%Y%m%d_%H%M%S")

lossTrainArr = np.array(training_loss)
lossTestArr = np.array(test_loss)
bestLoss = np.array([min_loss])
LrCArr = np.array(hisLrC)

h5f =h5.File(f"log/recording_{dt_string}.hdf5","w")
# h5f = h5.File('train/train.h5', 'r+') # write in an exsited h5 file
g1 = h5f.create_group('log1')
g1.attrs['data']=now.strftime("%Y-%m-%d")
# g1.attrs['model']=ModelWts
# g1.attrs['optLrOrg']=str(optLrOrg)+'={:3.1e}'.format(optLrOrg) 
# g1.attrs['lrAdstep']= str(lrAdstep)
# g1.attrs['optimizer']= str(optimizer)[:4]

g1.create_dataset('lossTrain', data=lossTrainArr)
g1.create_dataset('lossTest', data=lossTestArr)
g1.create_dataset('bestLoss', data=bestLoss)
g1.create_dataset('LrCArr', data=LrCArr)
h5f.close()
# Out:
# Epoch: 1/600 	Training Loss: 2.505207 	17s
# Epoch: 2/600 	Training Loss: 2.308975 	33s
# Epoch: 3/600 	Training Loss: 2.236450 	49s
# Epoch: 4/600 	Training Loss: 2.191796 	66s
# Epoch: 5/600 	Training Loss: 2.176962 	82s
# Epoch: 6/600 	Training Loss: 2.162750 	99s
# EarlyStopping counter: 1 out of 50
# Epoch: 7/600 	Training Loss: 2.152156 	115s
# Epoch: 8/600 	Training Loss: 2.137337 	131s
# EarlyStopping counter: 1 out of 50
# Epoch: 9/600 	Training Loss: 2.133925 	148s
# EarlyStopping counter: 2 out of 50
# Epoch: 10/600 	Training Loss: 2.129315 	164s
# EarlyStopping counter: 3 out of 50
# Epoch: 11/600 	Training Loss: 2.114317 	181s
# Epoch: 12/600 	Training Loss: 2.109122 	197s
# Epoch: 13/600 	Training Loss: 2.104931 	214s
# EarlyStopping counter: 1 out of 50
# Epoch: 14/600 	Training Loss: 2.095796 	230s
# Epoch: 15/600 	Training Loss: 2.096126 	246s
# Epoch: 16/600 	Training Loss: 2.096601 	263s
# Epoch: 17/600 	Training Loss: 2.088046 	279s
# EarlyStopping counter: 1 out of 50
# Epoch: 18/600 	Training Loss: 2.086085 	296s
# EarlyStopping counter: 2 out of 50
# Epoch: 19/600 	Training Loss: 2.078144 	312s
# Epoch: 20/600 	Training Loss: 2.077205 	329s
# EarlyStopping counter: 1 out of 50
# Epoch: 21/600 	Training Loss: 2.069114 	345s
# Epoch: 22/600 	Training Loss: 2.070228 	362s
# Epoch: 23/600 	Training Loss: 2.065390 	378s
# EarlyStopping counter: 1 out of 50
# Epoch: 24/600 	Training Loss: 2.055881 	395s
# EarlyStopping counter: 2 out of 50
# Epoch: 25/600 	Training Loss: 2.055917 	411s
# Epoch: 26/600 	Training Loss: 2.050645 	427s
# Epoch: 27/600 	Training Loss: 2.038451 	444s
# EarlyStopping counter: 1 out of 50
# Epoch: 28/600 	Training Loss: 2.041455 	460s
# EarlyStopping counter: 2 out of 50
# Epoch: 29/600 	Training Loss: 2.031886 	477s
# EarlyStopping counter: 3 out of 50
# Epoch: 30/600 	Training Loss: 2.027509 	493s
# Epoch: 31/600 	Training Loss: 2.017560 	510s
# Epoch: 32/600 	Training Loss: 2.013783 	526s
# EarlyStopping counter: 1 out of 50
# Epoch: 33/600 	Training Loss: 2.009206 	543s
# Epoch: 34/600 	Training Loss: 2.007187 	559s
# EarlyStopping counter: 1 out of 50
# Epoch: 35/600 	Training Loss: 2.006976 	575s
# Epoch: 36/600 	Training Loss: 1.997141 	592s
# EarlyStopping counter: 1 out of 50
# Epoch: 37/600 	Training Loss: 1.989347 	608s
# EarlyStopping counter: 2 out of 50
# Epoch: 38/600 	Training Loss: 1.991537 	625s
# EarlyStopping counter: 3 out of 50
# Epoch: 39/600 	Training Loss: 1.987235 	641s
# Epoch: 40/600 	Training Loss: 1.982121 	658s
# EarlyStopping counter: 1 out of 50
# Epoch: 41/600 	Training Loss: 1.977432 	674s
# EarlyStopping counter: 2 out of 50
# Epoch: 42/600 	Training Loss: 1.973908 	691s
# EarlyStopping counter: 3 out of 50
# Epoch: 43/600 	Training Loss: 1.976127 	707s
# Epoch: 44/600 	Training Loss: 1.967518 	724s
# Epoch: 45/600 	Training Loss: 1.966205 	741s
# Epoch: 46/600 	Training Loss: 1.965619 	757s
# EarlyStopping counter: 1 out of 50
# Epoch: 47/600 	Training Loss: 1.959088 	773s
# EarlyStopping counter: 2 out of 50
# Epoch: 48/600 	Training Loss: 1.960637 	790s
# Epoch: 49/600 	Training Loss: 1.956890 	806s
# EarlyStopping counter: 1 out of 50
# Epoch: 50/600 	Training Loss: 1.951032 	823s
# Epoch: 51/600 	Training Loss: 1.950924 	839s
# EarlyStopping counter: 1 out of 50
# Epoch: 52/600 	Training Loss: 1.946223 	856s
# EarlyStopping counter: 2 out of 50
# Epoch: 53/600 	Training Loss: 1.945430 	872s
# Epoch: 54/600 	Training Loss: 1.942719 	889s
# Epoch: 55/600 	Training Loss: 1.940252 	905s
# EarlyStopping counter: 1 out of 50
# Epoch: 56/600 	Training Loss: 1.933701 	921s
# EarlyStopping counter: 2 out of 50
# Epoch: 57/600 	Training Loss: 1.931382 	938s
# EarlyStopping counter: 3 out of 50
# Epoch: 58/600 	Training Loss: 1.931757 	954s
# Epoch: 59/600 	Training Loss: 1.928824 	971s
# Epoch: 60/600 	Training Loss: 1.924468 	987s
# EarlyStopping counter: 1 out of 50
# Epoch: 61/600 	Training Loss: 1.921980 	1004s
# EarlyStopping counter: 2 out of 50
# Epoch: 62/600 	Training Loss: 1.922562 	1020s
# Epoch: 63/600 	Training Loss: 1.919534 	1036s
# EarlyStopping counter: 1 out of 50
# Epoch: 64/600 	Training Loss: 1.916808 	1053s
# Epoch: 65/600 	Training Loss: 1.914589 	1069s
# EarlyStopping counter: 1 out of 50
# Epoch: 66/600 	Training Loss: 1.913820 	1086s
# EarlyStopping counter: 2 out of 50
# Epoch: 67/600 	Training Loss: 1.912255 	1102s
# EarlyStopping counter: 3 out of 50
# Epoch: 68/600 	Training Loss: 1.907409 	1118s
# Epoch: 69/600 	Training Loss: 1.904960 	1135s
# Epoch: 70/600 	Training Loss: 1.903661 	1151s
# EarlyStopping counter: 1 out of 50
# Epoch: 71/600 	Training Loss: 1.900607 	1168s
# Epoch: 72/600 	Training Loss: 1.894925 	1184s
# EarlyStopping counter: 1 out of 50
# Epoch: 73/600 	Training Loss: 1.896402 	1201s
# Epoch: 74/600 	Training Loss: 1.893671 	1217s
# EarlyStopping counter: 1 out of 50
# Epoch: 75/600 	Training Loss: 1.897805 	1233s
# EarlyStopping counter: 2 out of 50
# Epoch: 76/600 	Training Loss: 1.892669 	1250s
# EarlyStopping counter: 3 out of 50
# Epoch: 77/600 	Training Loss: 1.887899 	1266s
# EarlyStopping counter: 4 out of 50
# Epoch: 78/600 	Training Loss: 1.883007 	1283s
# Epoch: 79/600 	Training Loss: 1.890408 	1299s
# Epoch: 80/600 	Training Loss: 1.881782 	1315s
# EarlyStopping counter: 1 out of 50
# Epoch: 81/600 	Training Loss: 1.882265 	1332s
# EarlyStopping counter: 2 out of 50
# Epoch: 82/600 	Training Loss: 1.880642 	1348s
# EarlyStopping counter: 3 out of 50
# Epoch: 83/600 	Training Loss: 1.875208 	1365s
# EarlyStopping counter: 4 out of 50
# Epoch: 84/600 	Training Loss: 1.875542 	1381s
# EarlyStopping counter: 5 out of 50
# Epoch: 85/600 	Training Loss: 1.872750 	1397s
# Epoch: 86/600 	Training Loss: 1.871572 	1413s
# Epoch: 87/600 	Training Loss: 1.868765 	1480s
# EarlyStopping counter: 1 out of 50
# Epoch: 88/600 	Training Loss: 1.869400 	1640s
# EarlyStopping counter: 2 out of 50
# Epoch: 89/600 	Training Loss: 1.866544 	1657s
# Epoch: 90/600 	Training Loss: 1.863253 	1673s
# EarlyStopping counter: 1 out of 50
# Epoch: 91/600 	Training Loss: 1.862643 	1690s
# Epoch: 92/600 	Training Loss: 1.859961 	1706s
# EarlyStopping counter: 1 out of 50
# Epoch: 93/600 	Training Loss: 1.857177 	1722s
# Epoch: 94/600 	Training Loss: 1.857333 	1739s
# Epoch: 95/600 	Training Loss: 1.851800 	1755s
# EarlyStopping counter: 1 out of 50
# Epoch: 96/600 	Training Loss: 1.852132 	1771s
# Epoch: 97/600 	Training Loss: 1.850571 	1788s
# EarlyStopping counter: 1 out of 50
# Epoch: 98/600 	Training Loss: 1.848789 	1804s
# Epoch: 99/600 	Training Loss: 1.847122 	1821s
# Epoch: 100/600 	Training Loss: 1.845583 	1837s
# EarlyStopping counter: 1 out of 50
# Epoch: 101/600 	Training Loss: 1.844871 	1854s
# EarlyStopping counter: 2 out of 50
# Epoch: 102/600 	Training Loss: 1.840346 	1870s
# EarlyStopping counter: 3 out of 50
# Epoch: 103/600 	Training Loss: 1.841698 	1887s
# EarlyStopping counter: 4 out of 50
# Epoch: 104/600 	Training Loss: 1.838909 	1903s
# Epoch: 105/600 	Training Loss: 1.833143 	1919s
# EarlyStopping counter: 1 out of 50
# Epoch: 106/600 	Training Loss: 1.832858 	1936s
# EarlyStopping counter: 2 out of 50
# Epoch: 107/600 	Training Loss: 1.837257 	1952s
# EarlyStopping counter: 3 out of 50
# Epoch: 108/600 	Training Loss: 1.833936 	1969s
# EarlyStopping counter: 4 out of 50
# Epoch: 109/600 	Training Loss: 1.831856 	1985s
# EarlyStopping counter: 5 out of 50
# Epoch: 110/600 	Training Loss: 1.831434 	2001s
# Epoch: 111/600 	Training Loss: 1.825011 	2018s
# Epoch: 112/600 	Training Loss: 1.825922 	2034s
# EarlyStopping counter: 1 out of 50
# Epoch: 113/600 	Training Loss: 1.825153 	2050s
# EarlyStopping counter: 2 out of 50
# Epoch: 114/600 	Training Loss: 1.823002 	2067s
# EarlyStopping counter: 3 out of 50
# Epoch: 115/600 	Training Loss: 1.821169 	2083s
# EarlyStopping counter: 4 out of 50
# Epoch: 116/600 	Training Loss: 1.818075 	2099s
# EarlyStopping counter: 5 out of 50
# Epoch: 117/600 	Training Loss: 1.819749 	2116s
# EarlyStopping counter: 6 out of 50
# Epoch: 118/600 	Training Loss: 1.818964 	2132s
# Epoch: 119/600 	Training Loss: 1.812298 	2148s
# EarlyStopping counter: 1 out of 50
# Epoch: 120/600 	Training Loss: 1.813525 	2165s
# EarlyStopping counter: 2 out of 50
# Epoch: 121/600 	Training Loss: 1.808094 	2181s
# EarlyStopping counter: 3 out of 50
# Epoch: 122/600 	Training Loss: 1.810924 	2198s
# EarlyStopping counter: 4 out of 50
# Epoch: 123/600 	Training Loss: 1.811504 	2214s
# EarlyStopping counter: 5 out of 50
# Epoch: 124/600 	Training Loss: 1.807746 	2230s
# EarlyStopping counter: 6 out of 50
# Epoch: 125/600 	Training Loss: 1.805816 	2247s
# Epoch: 126/600 	Training Loss: 1.804166 	2263s
# Epoch: 127/600 	Training Loss: 1.803920 	2280s
# Epoch: 128/600 	Training Loss: 1.799467 	2296s
# EarlyStopping counter: 1 out of 50
# Epoch: 129/600 	Training Loss: 1.803017 	2312s
# Epoch: 130/600 	Training Loss: 1.796964 	2329s
# EarlyStopping counter: 1 out of 50
# Epoch: 131/600 	Training Loss: 1.798277 	2345s
# EarlyStopping counter: 2 out of 50
# Epoch: 132/600 	Training Loss: 1.797579 	2362s
# EarlyStopping counter: 3 out of 50
# Epoch: 133/600 	Training Loss: 1.794997 	2378s
# Epoch: 134/600 	Training Loss: 1.792607 	2394s
# EarlyStopping counter: 1 out of 50
# Epoch: 135/600 	Training Loss: 1.793825 	2411s
# EarlyStopping counter: 2 out of 50
# Epoch: 136/600 	Training Loss: 1.790321 	2427s
# EarlyStopping counter: 3 out of 50
# Epoch: 137/600 	Training Loss: 1.787566 	2443s
# EarlyStopping counter: 4 out of 50
# Epoch: 138/600 	Training Loss: 1.790039 	2460s
# EarlyStopping counter: 5 out of 50
# Epoch: 139/600 	Training Loss: 1.785976 	2477s
# Epoch: 140/600 	Training Loss: 1.783518 	2493s
# EarlyStopping counter: 1 out of 50
# Epoch: 141/600 	Training Loss: 1.783385 	2509s
# EarlyStopping counter: 2 out of 50
# Epoch: 142/600 	Training Loss: 1.782934 	2526s
# EarlyStopping counter: 3 out of 50
# Epoch: 143/600 	Training Loss: 1.778855 	2542s
# EarlyStopping counter: 4 out of 50
# Epoch: 144/600 	Training Loss: 1.780318 	2559s
# EarlyStopping counter: 5 out of 50
# Epoch: 145/600 	Training Loss: 1.781266 	2575s
# EarlyStopping counter: 6 out of 50
# Epoch: 146/600 	Training Loss: 1.776754 	2591s
# EarlyStopping counter: 7 out of 50
# Epoch: 147/600 	Training Loss: 1.775668 	2608s
# EarlyStopping counter: 8 out of 50
# Epoch: 148/600 	Training Loss: 1.776256 	2624s
# EarlyStopping counter: 9 out of 50
# Epoch: 149/600 	Training Loss: 1.774620 	2641s
# EarlyStopping counter: 10 out of 50
# Epoch: 150/600 	Training Loss: 1.774400 	2657s
# EarlyStopping counter: 11 out of 50
# Epoch: 151/600 	Training Loss: 1.764785 	2674s
# EarlyStopping counter: 12 out of 50
# Epoch: 152/600 	Training Loss: 1.768641 	2690s
# Epoch: 153/600 	Training Loss: 1.766914 	2706s
# EarlyStopping counter: 1 out of 50
# Epoch: 154/600 	Training Loss: 1.764848 	2723s
# EarlyStopping counter: 2 out of 50
# Epoch: 155/600 	Training Loss: 1.768527 	2740s
# Epoch: 156/600 	Training Loss: 1.765619 	2756s
# Epoch: 157/600 	Training Loss: 1.763288 	2773s
# EarlyStopping counter: 1 out of 50
# Epoch: 158/600 	Training Loss: 1.761006 	2789s
# EarlyStopping counter: 2 out of 50
# Epoch: 159/600 	Training Loss: 1.759375 	2805s
# Epoch: 160/600 	Training Loss: 1.758816 	2822s
# EarlyStopping counter: 1 out of 50
# Epoch: 161/600 	Training Loss: 1.759965 	2838s
# EarlyStopping counter: 2 out of 50
# Epoch: 162/600 	Training Loss: 1.758073 	2855s
# Epoch: 163/600 	Training Loss: 1.755688 	2871s
# Epoch: 164/600 	Training Loss: 1.751158 	2887s
# EarlyStopping counter: 1 out of 50
# Epoch: 165/600 	Training Loss: 1.752740 	2904s
# EarlyStopping counter: 2 out of 50
# Epoch: 166/600 	Training Loss: 1.747592 	2920s
# EarlyStopping counter: 3 out of 50
# Epoch: 167/600 	Training Loss: 1.747029 	2937s
# EarlyStopping counter: 4 out of 50
# Epoch: 168/600 	Training Loss: 1.748184 	2953s
# EarlyStopping counter: 5 out of 50
# Epoch: 169/600 	Training Loss: 1.746949 	2969s
# Epoch: 170/600 	Training Loss: 1.747055 	2986s
# EarlyStopping counter: 1 out of 50
# Epoch: 171/600 	Training Loss: 1.744830 	3002s
# EarlyStopping counter: 2 out of 50
# Epoch: 172/600 	Training Loss: 1.741927 	3018s
# Epoch: 173/600 	Training Loss: 1.741520 	3035s
# EarlyStopping counter: 1 out of 50
# Epoch: 174/600 	Training Loss: 1.739246 	3051s
# EarlyStopping counter: 2 out of 50
# Epoch: 175/600 	Training Loss: 1.737966 	3068s
# EarlyStopping counter: 3 out of 50
# Epoch: 176/600 	Training Loss: 1.737517 	3084s
# EarlyStopping counter: 4 out of 50
# Epoch: 177/600 	Training Loss: 1.736835 	3100s
# Epoch: 178/600 	Training Loss: 1.736313 	3117s
# EarlyStopping counter: 1 out of 50
# Epoch: 179/600 	Training Loss: 1.733593 	3133s
# EarlyStopping counter: 2 out of 50
# Epoch: 180/600 	Training Loss: 1.733106 	3149s
# EarlyStopping counter: 3 out of 50
# Epoch: 181/600 	Training Loss: 1.732399 	3166s
# EarlyStopping counter: 4 out of 50
# Epoch: 182/600 	Training Loss: 1.731963 	3182s
# EarlyStopping counter: 5 out of 50
# Epoch: 183/600 	Training Loss: 1.729415 	3198s
# EarlyStopping counter: 6 out of 50
# Epoch: 184/600 	Training Loss: 1.728725 	3215s
# EarlyStopping counter: 7 out of 50
# Epoch: 185/600 	Training Loss: 1.726063 	3231s
# EarlyStopping counter: 8 out of 50
# Epoch: 186/600 	Training Loss: 1.730306 	3247s
# EarlyStopping counter: 9 out of 50
# Epoch: 187/600 	Training Loss: 1.725922 	3264s
# EarlyStopping counter: 10 out of 50
# Epoch: 188/600 	Training Loss: 1.724140 	3280s
# EarlyStopping counter: 11 out of 50
# Epoch: 189/600 	Training Loss: 1.724124 	3297s
# Epoch: 190/600 	Training Loss: 1.722246 	3313s
# EarlyStopping counter: 1 out of 50
# Epoch: 191/600 	Training Loss: 1.721178 	3329s
# EarlyStopping counter: 2 out of 50
# Epoch: 192/600 	Training Loss: 1.716696 	3346s
# EarlyStopping counter: 3 out of 50
# Epoch: 193/600 	Training Loss: 1.718073 	3362s
# EarlyStopping counter: 4 out of 50
# Epoch: 194/600 	Training Loss: 1.718570 	3379s
# Epoch: 195/600 	Training Loss: 1.713081 	3395s
# EarlyStopping counter: 1 out of 50
# Epoch: 196/600 	Training Loss: 1.714919 	3412s
# EarlyStopping counter: 2 out of 50
# Epoch: 197/600 	Training Loss: 1.714076 	3428s
# Epoch: 198/600 	Training Loss: 1.714429 	3445s
# EarlyStopping counter: 1 out of 50
# Epoch: 199/600 	Training Loss: 1.713096 	3461s
# EarlyStopping counter: 2 out of 50
# Epoch: 200/600 	Training Loss: 1.709817 	3477s
# EarlyStopping counter: 3 out of 50
# Epoch: 201/600 	Training Loss: 1.711253 	3494s
# Epoch: 202/600 	Training Loss: 1.708596 	3510s
# EarlyStopping counter: 1 out of 50
# Epoch: 203/600 	Training Loss: 1.704224 	3526s
# EarlyStopping counter: 2 out of 50
# Epoch: 204/600 	Training Loss: 1.703541 	3543s
# EarlyStopping counter: 3 out of 50
# Epoch: 205/600 	Training Loss: 1.705451 	3559s
# EarlyStopping counter: 4 out of 50
# Epoch: 206/600 	Training Loss: 1.703021 	3575s
# EarlyStopping counter: 5 out of 50
# Epoch: 207/600 	Training Loss: 1.701568 	3592s
# Epoch: 208/600 	Training Loss: 1.702973 	3608s
# EarlyStopping counter: 1 out of 50
# Epoch: 209/600 	Training Loss: 1.700259 	3624s
# EarlyStopping counter: 2 out of 50
# Epoch: 210/600 	Training Loss: 1.697983 	3641s
# EarlyStopping counter: 3 out of 50
# Epoch: 211/600 	Training Loss: 1.698086 	3657s
# EarlyStopping counter: 4 out of 50
# Epoch: 212/600 	Training Loss: 1.696310 	3673s
# Epoch: 213/600 	Training Loss: 1.700243 	3690s
# EarlyStopping counter: 1 out of 50
# Epoch: 214/600 	Training Loss: 1.696197 	3706s
# EarlyStopping counter: 2 out of 50
# Epoch: 215/600 	Training Loss: 1.694585 	3723s
# EarlyStopping counter: 3 out of 50
# Epoch: 216/600 	Training Loss: 1.691527 	3739s
# EarlyStopping counter: 4 out of 50
# Epoch: 217/600 	Training Loss: 1.688083 	3755s
# EarlyStopping counter: 5 out of 50
# Epoch: 218/600 	Training Loss: 1.692543 	3771s
# EarlyStopping counter: 6 out of 50
# Epoch: 219/600 	Training Loss: 1.685511 	3788s
# EarlyStopping counter: 7 out of 50
# Epoch: 220/600 	Training Loss: 1.688319 	3804s
# EarlyStopping counter: 8 out of 50
# Epoch: 221/600 	Training Loss: 1.688369 	3821s
# EarlyStopping counter: 9 out of 50
# Epoch: 222/600 	Training Loss: 1.687746 	3837s
# EarlyStopping counter: 10 out of 50
# Epoch: 223/600 	Training Loss: 1.686412 	3853s
# EarlyStopping counter: 11 out of 50
# Epoch: 224/600 	Training Loss: 1.685218 	3870s
# EarlyStopping counter: 12 out of 50
# Epoch: 225/600 	Training Loss: 1.684613 	3886s
# EarlyStopping counter: 13 out of 50
# Epoch: 226/600 	Training Loss: 1.681181 	3903s
# EarlyStopping counter: 14 out of 50
# Epoch: 227/600 	Training Loss: 1.677926 	3919s
# Epoch: 228/600 	Training Loss: 1.677264 	3935s
# EarlyStopping counter: 1 out of 50
# Epoch: 229/600 	Training Loss: 1.681463 	3952s
# EarlyStopping counter: 2 out of 50
# Epoch: 230/600 	Training Loss: 1.674801 	3968s
# EarlyStopping counter: 3 out of 50
# Epoch: 231/600 	Training Loss: 1.672371 	3984s
# Epoch: 232/600 	Training Loss: 1.672938 	4001s
# EarlyStopping counter: 1 out of 50
# Epoch: 233/600 	Training Loss: 1.674620 	4017s
# EarlyStopping counter: 2 out of 50
# Epoch: 234/600 	Training Loss: 1.671317 	4033s
# EarlyStopping counter: 3 out of 50
# Epoch: 235/600 	Training Loss: 1.670480 	4050s
# EarlyStopping counter: 4 out of 50
# Epoch: 236/600 	Training Loss: 1.671390 	4066s
# EarlyStopping counter: 5 out of 50
# Epoch: 237/600 	Training Loss: 1.669610 	4083s
# Epoch: 238/600 	Training Loss: 1.667441 	4099s
# EarlyStopping counter: 1 out of 50
# Epoch: 239/600 	Training Loss: 1.665069 	4115s
# EarlyStopping counter: 2 out of 50
# Epoch: 240/600 	Training Loss: 1.669824 	4132s
# EarlyStopping counter: 3 out of 50
# Epoch: 241/600 	Training Loss: 1.670422 	4148s
# EarlyStopping counter: 4 out of 50
# Epoch: 242/600 	Training Loss: 1.665262 	4165s
# EarlyStopping counter: 5 out of 50
# Epoch: 243/600 	Training Loss: 1.663375 	4181s
# Epoch: 244/600 	Training Loss: 1.663055 	4197s
# Epoch: 245/600 	Training Loss: 1.664059 	4214s
# EarlyStopping counter: 1 out of 50
# Epoch: 246/600 	Training Loss: 1.663046 	4230s
# Epoch: 247/600 	Training Loss: 1.659735 	4246s
# EarlyStopping counter: 1 out of 50
# Epoch: 248/600 	Training Loss: 1.659975 	4263s
# EarlyStopping counter: 2 out of 50
# Epoch: 249/600 	Training Loss: 1.660771 	4279s
# EarlyStopping counter: 3 out of 50
# Epoch: 250/600 	Training Loss: 1.655586 	4295s
# EarlyStopping counter: 4 out of 50
# Epoch: 251/600 	Training Loss: 1.654976 	4312s
# EarlyStopping counter: 5 out of 50
# Epoch: 252/600 	Training Loss: 1.655411 	4328s
# EarlyStopping counter: 6 out of 50
# Epoch: 253/600 	Training Loss: 1.653145 	4344s
# EarlyStopping counter: 7 out of 50
# Epoch: 254/600 	Training Loss: 1.652928 	4361s
# EarlyStopping counter: 8 out of 50
# Epoch: 255/600 	Training Loss: 1.651758 	4377s
# EarlyStopping counter: 9 out of 50
# Epoch: 256/600 	Training Loss: 1.648934 	4394s
# EarlyStopping counter: 10 out of 50
# Epoch: 257/600 	Training Loss: 1.649785 	4410s
# EarlyStopping counter: 11 out of 50
# Epoch: 258/600 	Training Loss: 1.648672 	4426s
# EarlyStopping counter: 12 out of 50
# Epoch: 259/600 	Training Loss: 1.644767 	4442s
# EarlyStopping counter: 13 out of 50
# Epoch: 260/600 	Training Loss: 1.647201 	4459s
# EarlyStopping counter: 14 out of 50
# Epoch: 261/600 	Training Loss: 1.646139 	4475s
# EarlyStopping counter: 15 out of 50
# Epoch: 262/600 	Training Loss: 1.646243 	4491s
# EarlyStopping counter: 16 out of 50
# Epoch: 263/600 	Training Loss: 1.644648 	4508s
# EarlyStopping counter: 17 out of 50
# Epoch: 264/600 	Training Loss: 1.643963 	4524s
# EarlyStopping counter: 18 out of 50
# Epoch: 265/600 	Training Loss: 1.639738 	4540s
# EarlyStopping counter: 19 out of 50
# Epoch: 266/600 	Training Loss: 1.641427 	4557s
# EarlyStopping counter: 20 out of 50
# Epoch: 267/600 	Training Loss: 1.640004 	4573s
# Epoch: 268/600 	Training Loss: 1.636344 	4589s
# EarlyStopping counter: 1 out of 50
# Epoch: 269/600 	Training Loss: 1.639854 	4606s
# EarlyStopping counter: 2 out of 50
# Epoch: 270/600 	Training Loss: 1.632683 	4622s
# EarlyStopping counter: 3 out of 50
# Epoch: 271/600 	Training Loss: 1.638011 	4639s
# EarlyStopping counter: 4 out of 50
# Epoch: 272/600 	Training Loss: 1.637141 	4655s
# EarlyStopping counter: 5 out of 50
# Epoch: 273/600 	Training Loss: 1.634830 	4671s
# EarlyStopping counter: 6 out of 50
# Epoch: 274/600 	Training Loss: 1.635381 	4688s
# EarlyStopping counter: 7 out of 50
# Epoch: 275/600 	Training Loss: 1.632670 	4704s
# EarlyStopping counter: 8 out of 50
# Epoch: 276/600 	Training Loss: 1.632274 	4720s
# EarlyStopping counter: 9 out of 50
# Epoch: 277/600 	Training Loss: 1.628502 	4737s
# EarlyStopping counter: 10 out of 50
# Epoch: 278/600 	Training Loss: 1.632298 	4753s
# EarlyStopping counter: 11 out of 50
# Epoch: 279/600 	Training Loss: 1.627662 	4769s
# EarlyStopping counter: 12 out of 50
# Epoch: 280/600 	Training Loss: 1.628113 	4786s
# Epoch: 281/600 	Training Loss: 1.626010 	4802s
# EarlyStopping counter: 1 out of 50
# Epoch: 282/600 	Training Loss: 1.627057 	4818s
# EarlyStopping counter: 2 out of 50
# Epoch: 283/600 	Training Loss: 1.624893 	4835s
# EarlyStopping counter: 3 out of 50
# Epoch: 284/600 	Training Loss: 1.620947 	4851s
# EarlyStopping counter: 4 out of 50
# Epoch: 285/600 	Training Loss: 1.620741 	4868s
# EarlyStopping counter: 5 out of 50
# Epoch: 286/600 	Training Loss: 1.626875 	4884s
# EarlyStopping counter: 6 out of 50
# Epoch: 287/600 	Training Loss: 1.621510 	4900s
# EarlyStopping counter: 7 out of 50
# Epoch: 288/600 	Training Loss: 1.621282 	4917s
# EarlyStopping counter: 8 out of 50
# Epoch: 289/600 	Training Loss: 1.619011 	4933s
# EarlyStopping counter: 9 out of 50
# Epoch: 290/600 	Training Loss: 1.619642 	4950s
# EarlyStopping counter: 10 out of 50
# Epoch: 291/600 	Training Loss: 1.617867 	4966s
# EarlyStopping counter: 11 out of 50
# Epoch: 292/600 	Training Loss: 1.615619 	4982s
# EarlyStopping counter: 12 out of 50
# Epoch: 293/600 	Training Loss: 1.615309 	4999s
# EarlyStopping counter: 13 out of 50
# Epoch: 294/600 	Training Loss: 1.615550 	5015s
# EarlyStopping counter: 14 out of 50
# Epoch: 295/600 	Training Loss: 1.613112 	5031s
# EarlyStopping counter: 15 out of 50
# Epoch: 296/600 	Training Loss: 1.613667 	5048s
# EarlyStopping counter: 16 out of 50
# Epoch: 297/600 	Training Loss: 1.610713 	5064s
# EarlyStopping counter: 17 out of 50
# Epoch: 298/600 	Training Loss: 1.612448 	5080s
# EarlyStopping counter: 18 out of 50
# Epoch: 299/600 	Training Loss: 1.611868 	5097s
# EarlyStopping counter: 19 out of 50
# Epoch: 300/600 	Training Loss: 1.612306 	5113s
# EarlyStopping counter: 20 out of 50
# Epoch: 301/600 	Training Loss: 1.606611 	5129s
# Epoch: 302/600 	Training Loss: 1.608535 	5146s
# EarlyStopping counter: 1 out of 50
# Epoch: 303/600 	Training Loss: 1.608575 	5162s
# EarlyStopping counter: 2 out of 50
# Epoch: 304/600 	Training Loss: 1.605610 	5178s
# EarlyStopping counter: 3 out of 50
# Epoch: 305/600 	Training Loss: 1.604865 	5195s
# EarlyStopping counter: 4 out of 50
# Epoch: 306/600 	Training Loss: 1.603995 	5211s
# EarlyStopping counter: 5 out of 50
# Epoch: 307/600 	Training Loss: 1.604202 	5228s
# Epoch: 308/600 	Training Loss: 1.604205 	5244s
# EarlyStopping counter: 1 out of 50
# Epoch: 309/600 	Training Loss: 1.600723 	5260s
# EarlyStopping counter: 2 out of 50
# Epoch: 310/600 	Training Loss: 1.598584 	5277s
# EarlyStopping counter: 3 out of 50
# Epoch: 311/600 	Training Loss: 1.597253 	5293s
# EarlyStopping counter: 4 out of 50
# Epoch: 312/600 	Training Loss: 1.600871 	5309s
# EarlyStopping counter: 5 out of 50
# Epoch: 313/600 	Training Loss: 1.600282 	5326s
# Epoch: 314/600 	Training Loss: 1.592933 	5342s
# EarlyStopping counter: 1 out of 50
# Epoch: 315/600 	Training Loss: 1.595922 	5359s
# Epoch: 316/600 	Training Loss: 1.597351 	5375s
# Epoch: 317/600 	Training Loss: 1.598012 	5391s
# EarlyStopping counter: 1 out of 50
# Epoch: 318/600 	Training Loss: 1.591726 	5408s
# EarlyStopping counter: 2 out of 50
# Epoch: 319/600 	Training Loss: 1.593106 	5424s
# EarlyStopping counter: 3 out of 50
# Epoch: 320/600 	Training Loss: 1.591817 	5440s
# EarlyStopping counter: 4 out of 50
# Epoch: 321/600 	Training Loss: 1.592372 	5457s
# EarlyStopping counter: 5 out of 50
# Epoch: 322/600 	Training Loss: 1.590533 	5473s
# EarlyStopping counter: 6 out of 50
# Epoch: 323/600 	Training Loss: 1.590158 	5489s
# EarlyStopping counter: 7 out of 50
# Epoch: 324/600 	Training Loss: 1.590689 	5506s
# EarlyStopping counter: 8 out of 50
# Epoch: 325/600 	Training Loss: 1.585234 	5522s
# EarlyStopping counter: 9 out of 50
# Epoch: 326/600 	Training Loss: 1.586419 	5539s
# EarlyStopping counter: 10 out of 50
# Epoch: 327/600 	Training Loss: 1.588737 	5555s
# EarlyStopping counter: 11 out of 50
# Epoch: 328/600 	Training Loss: 1.588498 	5571s
# EarlyStopping counter: 12 out of 50
# Epoch: 329/600 	Training Loss: 1.585531 	5588s
# EarlyStopping counter: 13 out of 50
# Epoch: 330/600 	Training Loss: 1.583960 	5604s
# EarlyStopping counter: 14 out of 50
# Epoch: 331/600 	Training Loss: 1.582002 	5620s
# EarlyStopping counter: 15 out of 50
# Epoch: 332/600 	Training Loss: 1.580552 	5636s
# EarlyStopping counter: 16 out of 50
# Epoch: 333/600 	Training Loss: 1.582503 	5653s
# EarlyStopping counter: 17 out of 50
# Epoch: 334/600 	Training Loss: 1.581732 	5669s
# EarlyStopping counter: 18 out of 50
# Epoch: 335/600 	Training Loss: 1.580670 	5686s
# EarlyStopping counter: 19 out of 50
# Epoch: 336/600 	Training Loss: 1.579535 	5702s
# EarlyStopping counter: 20 out of 50
# Epoch: 337/600 	Training Loss: 1.578538 	5718s
# EarlyStopping counter: 21 out of 50
# Epoch: 338/600 	Training Loss: 1.578894 	5734s
# EarlyStopping counter: 22 out of 50
# Epoch: 339/600 	Training Loss: 1.571915 	5751s
# EarlyStopping counter: 23 out of 50
# Epoch: 340/600 	Training Loss: 1.575551 	5767s
# EarlyStopping counter: 24 out of 50
# Epoch: 341/600 	Training Loss: 1.571908 	5783s
# EarlyStopping counter: 25 out of 50
# Epoch: 342/600 	Training Loss: 1.579479 	5800s
# EarlyStopping counter: 26 out of 50
# Epoch: 343/600 	Training Loss: 1.572971 	5816s
# EarlyStopping counter: 27 out of 50
# Epoch: 344/600 	Training Loss: 1.572176 	5832s
# EarlyStopping counter: 28 out of 50
# Epoch: 345/600 	Training Loss: 1.570750 	5849s
# EarlyStopping counter: 29 out of 50
# Epoch: 346/600 	Training Loss: 1.576264 	5865s
# EarlyStopping counter: 30 out of 50
# Epoch: 347/600 	Training Loss: 1.570287 	5881s
# EarlyStopping counter: 31 out of 50
# Epoch: 348/600 	Training Loss: 1.571377 	5898s
# EarlyStopping counter: 32 out of 50
# Epoch: 349/600 	Training Loss: 1.568071 	5914s
# EarlyStopping counter: 33 out of 50
# Epoch: 350/600 	Training Loss: 1.567326 	5930s
# Epoch: 351/600 	Training Loss: 1.565530 	5947s
# EarlyStopping counter: 1 out of 50
# Epoch: 352/600 	Training Loss: 1.565136 	5963s
# EarlyStopping counter: 2 out of 50
# Epoch: 353/600 	Training Loss: 1.567072 	5979s
# EarlyStopping counter: 3 out of 50
# Epoch: 354/600 	Training Loss: 1.566036 	5996s
# EarlyStopping counter: 4 out of 50
# Epoch: 355/600 	Training Loss: 1.564535 	6012s
# EarlyStopping counter: 5 out of 50
# Epoch: 356/600 	Training Loss: 1.563429 	6028s
# EarlyStopping counter: 6 out of 50
# Epoch: 357/600 	Training Loss: 1.565155 	6045s
# EarlyStopping counter: 7 out of 50
# Epoch: 358/600 	Training Loss: 1.561247 	6061s
# EarlyStopping counter: 8 out of 50
# Epoch: 359/600 	Training Loss: 1.559272 	6077s
# EarlyStopping counter: 9 out of 50
# Epoch: 360/600 	Training Loss: 1.561465 	6094s
# EarlyStopping counter: 10 out of 50
# Epoch: 361/600 	Training Loss: 1.558344 	6110s
# EarlyStopping counter: 11 out of 50
# Epoch: 362/600 	Training Loss: 1.558707 	6126s
# EarlyStopping counter: 12 out of 50
# Epoch: 363/600 	Training Loss: 1.558951 	6143s
# EarlyStopping counter: 13 out of 50
# Epoch: 364/600 	Training Loss: 1.554951 	6159s
# EarlyStopping counter: 14 out of 50
# Epoch: 365/600 	Training Loss: 1.557555 	6175s
# EarlyStopping counter: 15 out of 50
# Epoch: 366/600 	Training Loss: 1.556140 	6192s
# EarlyStopping counter: 16 out of 50
# Epoch: 367/600 	Training Loss: 1.554916 	6208s
# EarlyStopping counter: 17 out of 50
# Epoch: 368/600 	Training Loss: 1.553040 	6224s
# EarlyStopping counter: 18 out of 50
# Epoch: 369/600 	Training Loss: 1.550737 	6240s
# EarlyStopping counter: 19 out of 50
# Epoch: 370/600 	Training Loss: 1.558327 	6257s
# Epoch: 371/600 	Training Loss: 1.549627 	6273s
# EarlyStopping counter: 1 out of 50
# Epoch: 372/600 	Training Loss: 1.551888 	6289s
# EarlyStopping counter: 2 out of 50
# Epoch: 373/600 	Training Loss: 1.547514 	6306s
# EarlyStopping counter: 3 out of 50
# Epoch: 374/600 	Training Loss: 1.545823 	6322s
# EarlyStopping counter: 4 out of 50
# Epoch: 375/600 	Training Loss: 1.548613 	6339s
# EarlyStopping counter: 5 out of 50
# Epoch: 376/600 	Training Loss: 1.546385 	6355s
# EarlyStopping counter: 6 out of 50
# Epoch: 377/600 	Training Loss: 1.551403 	6371s
# EarlyStopping counter: 7 out of 50
# Epoch: 378/600 	Training Loss: 1.548142 	6388s
# EarlyStopping counter: 8 out of 50
# Epoch: 379/600 	Training Loss: 1.544169 	6404s
# EarlyStopping counter: 9 out of 50
# Epoch: 380/600 	Training Loss: 1.546444 	6420s
# EarlyStopping counter: 10 out of 50
# Epoch: 381/600 	Training Loss: 1.544153 	6437s
# EarlyStopping counter: 11 out of 50
# Epoch: 382/600 	Training Loss: 1.541655 	6453s
# EarlyStopping counter: 12 out of 50
# Epoch: 383/600 	Training Loss: 1.543133 	6469s
# Epoch: 384/600 	Training Loss: 1.540656 	6486s
# EarlyStopping counter: 1 out of 50
# Epoch: 385/600 	Training Loss: 1.539685 	6502s
# EarlyStopping counter: 2 out of 50
# Epoch: 386/600 	Training Loss: 1.545714 	6518s
# EarlyStopping counter: 3 out of 50
# Epoch: 387/600 	Training Loss: 1.541365 	6535s
# EarlyStopping counter: 4 out of 50
# Epoch: 388/600 	Training Loss: 1.539031 	6551s
# EarlyStopping counter: 5 out of 50
# Epoch: 389/600 	Training Loss: 1.542430 	6567s
# EarlyStopping counter: 6 out of 50
# Epoch: 390/600 	Training Loss: 1.543050 	6584s
# EarlyStopping counter: 7 out of 50
# Epoch: 391/600 	Training Loss: 1.536638 	6600s
# EarlyStopping counter: 8 out of 50
# Epoch: 392/600 	Training Loss: 1.533528 	6616s
# EarlyStopping counter: 9 out of 50
# Epoch: 393/600 	Training Loss: 1.533934 	6633s
# EarlyStopping counter: 10 out of 50
# Epoch: 394/600 	Training Loss: 1.538807 	6649s
# EarlyStopping counter: 11 out of 50
# Epoch: 395/600 	Training Loss: 1.536253 	6665s
# EarlyStopping counter: 12 out of 50
# Epoch: 396/600 	Training Loss: 1.535215 	6682s
# EarlyStopping counter: 13 out of 50
# Epoch: 397/600 	Training Loss: 1.531579 	6698s
# EarlyStopping counter: 14 out of 50
# Epoch: 398/600 	Training Loss: 1.531644 	6714s
# EarlyStopping counter: 15 out of 50
# Epoch: 399/600 	Training Loss: 1.530337 	6730s
# EarlyStopping counter: 16 out of 50
# Epoch: 400/600 	Training Loss: 1.530723 	6747s
# EarlyStopping counter: 17 out of 50
# Epoch: 401/600 	Training Loss: 1.531485 	6763s
# EarlyStopping counter: 18 out of 50
# Epoch: 402/600 	Training Loss: 1.528795 	6780s
# EarlyStopping counter: 19 out of 50
# Epoch: 403/600 	Training Loss: 1.530664 	6796s
# EarlyStopping counter: 20 out of 50
# Epoch: 404/600 	Training Loss: 1.525518 	6812s
# EarlyStopping counter: 21 out of 50
# Epoch: 405/600 	Training Loss: 1.528558 	6829s
# EarlyStopping counter: 22 out of 50
# Epoch: 406/600 	Training Loss: 1.526292 	6845s
# EarlyStopping counter: 23 out of 50
# Epoch: 407/600 	Training Loss: 1.526631 	6861s
# EarlyStopping counter: 24 out of 50
# Epoch: 408/600 	Training Loss: 1.528254 	6878s
# EarlyStopping counter: 25 out of 50
# Epoch: 409/600 	Training Loss: 1.523603 	6894s
# EarlyStopping counter: 26 out of 50
# Epoch: 410/600 	Training Loss: 1.527543 	6910s
# EarlyStopping counter: 27 out of 50
# Epoch: 411/600 	Training Loss: 1.521407 	6927s
# EarlyStopping counter: 28 out of 50
# Epoch: 412/600 	Training Loss: 1.524083 	6943s
# EarlyStopping counter: 29 out of 50
# Epoch: 413/600 	Training Loss: 1.523404 	6959s
# EarlyStopping counter: 30 out of 50
# Epoch: 414/600 	Training Loss: 1.515441 	6976s
# EarlyStopping counter: 31 out of 50
# Epoch: 415/600 	Training Loss: 1.524360 	6992s
# EarlyStopping counter: 32 out of 50
# Epoch: 416/600 	Training Loss: 1.519011 	7009s
# EarlyStopping counter: 33 out of 50
# Epoch: 417/600 	Training Loss: 1.518485 	7025s
# EarlyStopping counter: 34 out of 50
# Epoch: 418/600 	Training Loss: 1.519596 	7041s
# EarlyStopping counter: 35 out of 50
# Epoch: 419/600 	Training Loss: 1.516353 	7058s
# EarlyStopping counter: 36 out of 50
# Epoch: 420/600 	Training Loss: 1.518712 	7074s
# EarlyStopping counter: 37 out of 50
# Epoch: 421/600 	Training Loss: 1.515224 	7090s
# EarlyStopping counter: 38 out of 50
# Epoch: 422/600 	Training Loss: 1.514924 	7106s
# EarlyStopping counter: 39 out of 50
# Epoch: 423/600 	Training Loss: 1.515820 	7123s
# EarlyStopping counter: 40 out of 50
# Epoch: 424/600 	Training Loss: 1.514648 	7139s
# EarlyStopping counter: 41 out of 50
# Epoch: 425/600 	Training Loss: 1.512236 	7155s
# EarlyStopping counter: 42 out of 50
# Epoch: 426/600 	Training Loss: 1.514827 	7172s
# EarlyStopping counter: 43 out of 50
# Epoch: 427/600 	Training Loss: 1.513883 	7188s
# EarlyStopping counter: 44 out of 50
# Epoch: 428/600 	Training Loss: 1.511366 	7204s
# EarlyStopping counter: 45 out of 50
# Epoch: 429/600 	Training Loss: 1.511205 	7221s
# EarlyStopping counter: 46 out of 50
# Epoch: 430/600 	Training Loss: 1.508281 	7237s
# EarlyStopping counter: 47 out of 50
# Epoch: 431/600 	Training Loss: 1.507104 	7253s
# EarlyStopping counter: 48 out of 50
# Epoch: 432/600 	Training Loss: 1.513356 	7270s
# EarlyStopping counter: 49 out of 50
# Epoch: 433/600 	Training Loss: 1.510265 	7286s
# EarlyStopping counter: 50 out of 50
# best_testloss:1.757	 epoch:382
# Early stopping

# %%
# # plot training and test
# f = h5.File('Experiment2_sequence_inverse/log/recording_20230509_232651.hdf5','r')

# lossTrainArr = f['log1']['lossTrain'][:]
# lossTestArr = f['log1']['lossTest'][:]
# bestLoss = f['log1']['bestLoss'][:]
# LrCArr = f['log1']['LrCArr'][:]

zoomin = 10
zoomout = 382
plotTraining(lossTrainArr, lossTestArr, LrCArr, bestLoss, zoomin, zoomout)

# %%
##################################################
# visualize one batch of the validation images #
##################################################
# test_model.to(device)
test_model_best = SimpleAutoencoder()
# test_model_last.load_state_dict(torch.load('model_save/damage_{}/last_model_{}.pth'.format(damage_label, experimentIndex)))
test_model_best.load_state_dict(
    # torch.load('model_save/damage_{}/best_model_{}_{}_{}.pth'.format(damage_label, epochs, batch_size,learning_rate))
    torch.load('model_save/lidar2img/noFIX_lidar2img_best_model_600_32_20230517_213143.pth')
)

# 01_sensor_fusion/Coding/sensorFusion/Experiment2_sequence_inverse/lidar2img_model/best_model_300_32_20230501_141654.pth

test_model_best.eval()

# obtain one batch of test images
dataiter = iter(val_loader) # 22 batchse for validation
ori_img, noi_img = next(dataiter)

# get sample outputs
output = test_model_best(noi_img)

# prep images for display
# for i in range(ori_img.shape[0]):
for i in range(32):
    img1 = ori_img[i].numpy()
    img1 = img1.transpose(1, 2, 0)
    img2 = noi_img[i].numpy()
    img2 = img2.transpose(1, 2, 0)
    img3 = output[i].detach().numpy()
    img3 = img3.transpose(1, 2, 0)


    ax = plt.subplot(1, 3, 1)
    plt.xticks([])
    plt.yticks([])
    # ax.set_title('original image')
    plt.imshow(img1,cmap='gray')
    # plt.colorbar()


    ax = plt.subplot(1, 3, 2)
    plt.xticks([])
    plt.yticks([])
    # ax.set_title('noisy image')
    plt.imshow(img2)
    # plt.colorbar()

    # cmap='gray'
    ax = plt.subplot(1, 3, 3)
    plt.xticks([])
    plt.yticks([])
    # ax.set_title('denoised image')
    plt.imshow(img3,cmap='gray')
    # plt.colorbar()

    plt.savefig('output_save/2_main_lidar2img_600/{}.png'.format(i))
# plt.show()

# %%
import cv2
from PIL import Image
from torchvision import transforms

##################################################
# visualize one batch of the validation images #
##################################################
# load the best/last model

test_model_best = SimpleAutoencoder()
test_model_best.load_state_dict(
    torch.load('model_save/lidar2img/noFIX_lidar2img_best_model_600_32_20230517_213143.pth')
)


test_model_best.eval()
# obtain one batch of validation images
# for batch_index, dataiter in enumerate (val_loader)
dataiter = iter(val_loader)
# print (type(next(dataiter)))
ori_img, noi_img = next(dataiter)
# ori_img, noi_img = next(dataiter) # 2. batch


# get sample outputs

output = test_model_best(noi_img)


toPIL = transforms.ToPILImage()

# print(output.shape)
# prep images for display
for i in range(32):
    img1 = ori_img[i]
    img3 = output[i]
    # print(img1.shape, img3.shape)
    # print(type(img1),type(img3))
    # im1 = toPIL(img1)
    im3 = toPIL(img3)
    name = '%02d' %i

    # im1.save('output_save/ori_img/{}.png'.format(name))

    im3.save('output_save/2_main_lidar2img_reconstructed_600/{}.png'.format(name))

# %%
# mse

# load the best/last model
test_model_best = SimpleAutoencoder()

test_model_best.load_state_dict(
    torch.load('model_save/lidar2img/noFIX_lidar2img_best_model_600_32_20230517_213143.pth')
)

test_model_best.eval()

# obtain one batch of test images
dataiter = iter(val_loader)
ori_img, noi_img = next(dataiter)
# ori_img, noi_img = next(dataiter)
# ori_img, noi_img = next(dataiter)

# get sample outputs
# output = test_model_last(noi_img)
output = test_model_best(noi_img)

# %%
# mse
count = 0
batch_size = 32
for i in range (batch_size):
    img1 = ori_img[i]
    img3 = output[i]
    mse = criterion(img1,img3)
    mse = round(mse.item(),6)
    count = count+mse

mse_mean = count
print (f' {round(mse_mean,6)}')
# Out:
#  1.902381

# %%
# SSIM

import torch
from skimage.metrics import structural_similarity as ssim
from sensorFusionDataset.creatDataset import CreateDatasets
import glob
from torch.utils.data import DataLoader
from sensorFusionNetwork.simpleAutoencoder import SimpleAutoencoder

# dataset_path = '../../Dataset/lidar_img_16200/damaged_image_gray_all/DamagedDatasetforComparison'
# noi_img_list = sorted(glob.glob(dataset_path + '/*'))
# CAM_FRONT_path = '../../Dataset/lidar_img_16200/original_image_gray'
# img_list = sorted(glob.glob(CAM_FRONT_path + '/*'))[14400:14656]

metric_value_list = []
batch_size = 32

# ValDataset = CreateDatasets(img_list, noi_img_list)
# new_valloader = DataLoader(dataset=ValDataset, batch_size=batch_size, shuffle=False, num_workers=0, drop_last=True)

test_model_best = SimpleAutoencoder()
test_model_best.load_state_dict(torch.load('model_save/lidar2img/noFIX_lidar2img_best_model_600_32_20230517_213143.pth'))

for i, batch in enumerate(val_loader):
    ori_img, noi_img = batch
    test_model_best.eval()
    output = test_model_best(noi_img)
    count = 0
    for j in range(ori_img.size(0)):
        ori_img_np = ori_img[j][0].detach().cpu().numpy()
        output_np = output[j][0].detach().cpu().numpy()
        ssim_img, diff = ssim(ori_img_np, output_np, full=True, data_range=1.0)
        count = count + ssim_img
    ssim_img = round(count / ori_img.size(0), 3)
    metric_value_list.append(ssim_img)

print(metric_value_list)
# Out:
# [0.306, 0.321, 0.316, 0.315, 0.303, 0.31, 0.321, 0.311, 0.297, 0.3, 0.303, 0.327, 0.323, 0.275, 0.318, 0.304, 0.329, 0.346, 0.332, 0.318, 0.306, 0.317]

# %%
print(round(sum(metric_value_list)/len(metric_value_list),6))
# Out:
# 0.313545

# %%
# LLIPS metrics

import lpips

from sensorFusionDataset.creatDataset import CreateDatasets
import glob
from matplotlib import pyplot as plt
from torch.utils.data import DataLoader
from sensorFusionDataset.creatDataset import CreateDatasets
from sensorFusionNetwork.simpleAutoencoder import SimpleAutoencoder
import numpy as np
import torch



metric_value_list =[]
batch_size = 32



test_model_best = SimpleAutoencoder()
# test_model_last.load_state_dict(torch.load('model_save/damage_{}/last_model_{}.pth'.format(damage_label, experimentIndex)))
test_model_best.load_state_dict(
    torch.load('model_save/lidar2img/noFIX_lidar2img_best_model_600_32_20230517_213143.pth')
)

loss_fn = lpips.LPIPS(net='alex')


for i, batch in enumerate(val_loader):  # i -->index of batch
    if i == 0:
        ori_img, noi_img = batch
        test_model_best.eval()
        output = test_model_best(noi_img)
        count = 0
        # for j in range(ori_img.size(0)):
        # ori_img_np = ori_img[j][0].detach().numpy()
        # output_np = output[j][0].detach().numpy()
        lpips_img = loss_fn.forward(ori_img, output) # --> one batch lpips
        # print(lpips_img.shape) # --> torch.Size([32, 1, 1, 1])

        sum_result = (torch.sum(lpips_img)).item()
        print(round(sum_result,6))
        # count = count+sum_result
            # count = count.item()
        lpips_img_mean = round(sum_result/ori_img.size(0),3)
        print(round(lpips_img_mean,6)) # --> one batch lpips
        # metric_value_list.append(lpips_img)

# print(f'scuccess: {sum(metric_value_list)/len(metric_value_list)}')
# Out:
# Setting up [LPIPS] perceptual loss: trunk [alex], v[0.1], spatial [off]
# Loading model from: /usr/local/Anaconda3-2021.11-Linux-x86_64/envs/pytorch/lib/python3.8/site-packages/lpips/weights/v0.1/alex.pth
# 16.998831
# 0.531
