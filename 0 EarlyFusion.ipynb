# %%
# early fusion at the input

# %%
from matplotlib import pyplot as plt
from torch.utils.data import DataLoader
from sensorFusionDataset.creatDataset_2_encoder import CreateDatasets
from sensorFusionDataset.data_split import split_dataset
from sensorFusionNetwork.simpleAutoencoder_early import SimpleAutoencoder
from testLoop import test_loop_fusion
from trainLoop import train_loop_fusion
from visualization import plot_losses, plot_metrics,plotTraining
from earlystopping import EarlyStopping

import h5py as h5
from datetime import datetime
import copy
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import glob
import time

local_time =time.strftime("%Y-%m-%d %H:%M:%S", time.localtime())[-8:-1]
now = datetime.now()
dt_string = now.strftime("%Y%m%d_%H%M%S")
# CPU OR GPU
device = 'cuda' if torch.cuda.is_available() else 'cpu'

damaged_img_path = 'image_gray_200_damaged' 

lidar_mode = 'sparse'

if lidar_mode == 'sparse':
    lidar_path = 'lidar_tesor_200_sparse'
else:
    lidar_path = 'lidar_tesor_200_dense'

label_path = 'image_gray_200_original'

damaged_img_list = sorted(glob.glob(damaged_img_path + '/*'))[0:7200]
lidar_list = sorted(glob.glob(lidar_path + '/*'))[0:7200]
label_list = sorted(glob.glob(label_path + '/*'))[0:7200]


batch_size = 32
learning_rate = 1e-4
epochs = 300

MyDataset = CreateDatasets(label_list, damaged_img_list, lidar_list)#, img_size=img_size
train_dataset, test_dataset, val_dataset = split_dataset(MyDataset, 0.7, 0.2)
train_loader = DataLoader(dataset=train_dataset, batch_size=batch_size, shuffle=True, num_workers=0,
                          drop_last=True)
test_loader = DataLoader(dataset=test_dataset, batch_size=batch_size, shuffle=True, num_workers=0,
                         drop_last=True)
val_loader = DataLoader(dataset=val_dataset, batch_size=batch_size, shuffle=False, num_workers=0,
                        drop_last=True)

patience = 50	# 当验证集损失在连续20次训练周期中都没有得到降低时，停止模型训练，以防止模型过拟合
save_path = 'fusion_model/'
early_stopping = EarlyStopping(save_path = save_path, patience = patience)	

criterion = nn.MSELoss()

training_loss = []
training_baseloss = []
test_loss = []
testing_baseloss = []
hisLrC = []
min_loss=10000

print (f'loading fertig! {device}' )
# Out:
# loading fertig! cuda

# %%
# retraining with the channel adjust
# loading model

fusion_net_early = SimpleAutoencoder()
fusion_net_early.to(device)

learning_rate = 0.0004  # 2e-4 batchsize=30
optimizer = torch.optim.Adam(fusion_net_early.parameters(), lr=learning_rate)

criterion = nn.MSELoss()
criterion.to(device)


start_time = time.time()
for epoch in range(1, epochs + 1):
    # monitor training loss
    ##############################
    # start training the model #
    ##############################
    hisLrC.append(epoch)
    train_epoch_loss, train_epoch_baseloss = train_loop_fusion(train_loader, fusion_net_early, criterion, optimizer, device)
    training_loss.append(train_epoch_loss)
    # training_baseloss.append(train_epoch_baseloss)
    print('Epoch: {}/{} \tTraining Loss: {:.6f} \t{:.0f}s'.format(epoch, epochs, train_epoch_loss,
                                                                  time.time() - start_time))

    ##############################
    # start testing the model #
    ##############################
    with torch.no_grad():
        test_epoch_loss, test_epoch_baseloss = test_loop_fusion(test_loader, fusion_net_early, criterion, device)
        test_loss.append(test_epoch_loss)
        # testing_baseloss.append(test_epoch_baseloss)
        
    # type(train_epoch_loss)) ---> float
    # writer.add_scalars('loss', {'training loss': train_epoch_loss, 'test loss': test_epoch_loss}, epoch)

        
    if test_epoch_loss < min_loss:
        min_loss = test_epoch_loss
        best_model_wts = copy.deepcopy(fusion_net_early.state_dict())
       

    if epoch == epochs:
        torch.save(best_model_wts, 'model_save/fusion/12_early_best_model_{}_{}_{}.pth'.format(epochs, batch_size,dt_string))
        print('best_testloss:{:.3f}\t epoch:{}'.format(min_loss, test_loss.index(min_loss)))     

    # 早停止
    date = dt_string
    early_stopping(test_epoch_loss, fusion_net_early, date)
    #达到早停止条件时，early_stop会被置为True
    if early_stopping.early_stop:
        torch.save(best_model_wts, 'model_save/fusion/12_early_best_model_{}_{}_{}.pth'.format(epochs, batch_size,dt_string))
        # torch.save(fusion_net.state_dict(), 'Experiment2_sequence_inverse/fusion_model/last_model_{}_{}_{}.pth'.format(epochs, batch_size,dt_string))
        print('best_testloss:{:.3f}\t epoch:{}'.format(min_loss, test_loss.index(min_loss)))  
        print("Early stopping")
        break #跳出迭代，结束训练    
    
# train_baseline = sum(training_baseloss)/len(training_baseloss)
# test_baseline = sum(testing_baseloss)/len(training_baseloss)
# psnr_baseline = np.mean(psnr_base_list)

# train_baseline=train_baseline.item()
# test_baseline =test_baseline.item()
last_trainingloss = training_loss[-1]
last_testloss = test_loss[-1]


# write the dataset in one existed h5-file
now = datetime.now()
dt_string = now.strftime("%Y%m%d_%H%M%S")

lossTrainArr = np.array(training_loss)
lossTestArr = np.array(test_loss)
bestLoss = np.array([min_loss])
LrCArr = np.array(hisLrC)

h5f =h5.File(f"log/recording_{dt_string}.hdf5","w")
# h5f = h5.File('train/train.h5', 'r+') # write in an exsited h5 file
g1 = h5f.create_group('log1')
g1.attrs['data']=now.strftime("%Y-%m-%d")
# g1.attrs['model']=ModelWts
# g1.attrs['optLrOrg']=str(optLrOrg)+'={:3.1e}'.format(optLrOrg) 
# g1.attrs['lrAdstep']= str(lrAdstep)
# g1.attrs['optimizer']= str(optimizer)[:4]

g1.create_dataset('lossTrain', data=lossTrainArr)
g1.create_dataset('lossTest', data=lossTestArr)
g1.create_dataset('bestLoss', data=bestLoss)
g1.create_dataset('LrCArr', data=LrCArr)
h5f.close()

# print('train_baseline:{:.3f} \t test_baseline:{:.3f} \t last trainingloss:{:.3f} \t last testloss:{:.3f}'.format(train_baseline, test_baseline,last_trainingloss,last_testloss))
# Out:
# Epoch: 1/300 	Training Loss: 1.697163 	230s
# Epoch: 2/300 	Training Loss: 1.313926 	359s
# Epoch: 3/300 	Training Loss: 1.205806 	375s
# EarlyStopping counter: 1 out of 50
# Epoch: 4/300 	Training Loss: 1.165682 	391s
# Epoch: 5/300 	Training Loss: 1.098494 	406s
# Epoch: 6/300 	Training Loss: 1.085790 	422s
# Epoch: 7/300 	Training Loss: 1.020282 	439s
# Epoch: 8/300 	Training Loss: 0.979674 	455s
# EarlyStopping counter: 1 out of 50
# Epoch: 9/300 	Training Loss: 0.953579 	470s
# Epoch: 10/300 	Training Loss: 0.901419 	487s
# EarlyStopping counter: 1 out of 50
# Epoch: 11/300 	Training Loss: 0.871762 	503s
# Epoch: 12/300 	Training Loss: 0.840453 	518s
# EarlyStopping counter: 1 out of 50
# Epoch: 13/300 	Training Loss: 0.810536 	535s
# Epoch: 14/300 	Training Loss: 0.791546 	551s
# EarlyStopping counter: 1 out of 50
# Epoch: 15/300 	Training Loss: 0.769984 	567s
# Epoch: 16/300 	Training Loss: 0.740112 	584s
# Epoch: 17/300 	Training Loss: 0.727042 	600s
# EarlyStopping counter: 1 out of 50
# Epoch: 18/300 	Training Loss: 0.693118 	615s
# Epoch: 19/300 	Training Loss: 0.660079 	632s
# Epoch: 20/300 	Training Loss: 0.651757 	648s
# EarlyStopping counter: 1 out of 50
# Epoch: 21/300 	Training Loss: 0.640464 	664s
# EarlyStopping counter: 2 out of 50
# Epoch: 22/300 	Training Loss: 0.649565 	680s
# EarlyStopping counter: 3 out of 50
# Epoch: 23/300 	Training Loss: 0.600496 	696s
# Epoch: 24/300 	Training Loss: 0.592401 	712s
# EarlyStopping counter: 1 out of 50
# Epoch: 25/300 	Training Loss: 0.595967 	728s
# Epoch: 26/300 	Training Loss: 0.597224 	744s
# EarlyStopping counter: 1 out of 50
# Epoch: 27/300 	Training Loss: 0.572790 	760s
# Epoch: 28/300 	Training Loss: 0.553599 	776s
# Epoch: 29/300 	Training Loss: 0.567888 	793s
# EarlyStopping counter: 1 out of 50
# Epoch: 30/300 	Training Loss: 0.533874 	809s
# Epoch: 31/300 	Training Loss: 0.537499 	825s
# EarlyStopping counter: 1 out of 50
# Epoch: 32/300 	Training Loss: 0.521456 	842s
# EarlyStopping counter: 2 out of 50
# Epoch: 33/300 	Training Loss: 0.524060 	858s
# EarlyStopping counter: 3 out of 50
# Epoch: 34/300 	Training Loss: 0.499581 	873s
# Epoch: 35/300 	Training Loss: 0.518087 	889s
# EarlyStopping counter: 1 out of 50
# Epoch: 36/300 	Training Loss: 0.497861 	905s
# EarlyStopping counter: 2 out of 50
# Epoch: 37/300 	Training Loss: 0.493953 	921s
# EarlyStopping counter: 3 out of 50
# Epoch: 38/300 	Training Loss: 0.483410 	937s
# Epoch: 39/300 	Training Loss: 0.478224 	954s
# EarlyStopping counter: 1 out of 50
# Epoch: 40/300 	Training Loss: 0.470278 	969s
# Epoch: 41/300 	Training Loss: 0.481102 	985s
# EarlyStopping counter: 1 out of 50
# Epoch: 42/300 	Training Loss: 0.451345 	1001s
# Epoch: 43/300 	Training Loss: 0.440413 	1017s
# EarlyStopping counter: 1 out of 50
# Epoch: 44/300 	Training Loss: 0.445612 	1034s
# EarlyStopping counter: 2 out of 50
# Epoch: 45/300 	Training Loss: 0.455337 	1050s
# EarlyStopping counter: 3 out of 50
# Epoch: 46/300 	Training Loss: 0.435731 	1066s
# Epoch: 47/300 	Training Loss: 0.437237 	1082s
# EarlyStopping counter: 1 out of 50
# Epoch: 48/300 	Training Loss: 0.428711 	1098s
# EarlyStopping counter: 2 out of 50
# Epoch: 49/300 	Training Loss: 0.427046 	1114s
# EarlyStopping counter: 3 out of 50
# Epoch: 50/300 	Training Loss: 0.430565 	1130s
# Epoch: 51/300 	Training Loss: 0.418805 	1145s
# Epoch: 52/300 	Training Loss: 0.429280 	1161s
# Epoch: 53/300 	Training Loss: 0.412123 	1177s
# EarlyStopping counter: 1 out of 50
# Epoch: 54/300 	Training Loss: 0.429894 	1192s
# EarlyStopping counter: 2 out of 50
# Epoch: 55/300 	Training Loss: 0.411341 	1208s
# Epoch: 56/300 	Training Loss: 0.400716 	1224s
# Epoch: 57/300 	Training Loss: 0.395697 	1240s
# Epoch: 58/300 	Training Loss: 0.414430 	1256s
# EarlyStopping counter: 1 out of 50
# Epoch: 59/300 	Training Loss: 0.387886 	1272s
# EarlyStopping counter: 2 out of 50
# Epoch: 60/300 	Training Loss: 0.412444 	1288s
# Epoch: 61/300 	Training Loss: 0.397551 	1304s
# EarlyStopping counter: 1 out of 50
# Epoch: 62/300 	Training Loss: 0.380884 	1320s
# Epoch: 63/300 	Training Loss: 0.392678 	1336s
# EarlyStopping counter: 1 out of 50
# Epoch: 64/300 	Training Loss: 0.406398 	1352s
# EarlyStopping counter: 2 out of 50
# Epoch: 65/300 	Training Loss: 0.391674 	1369s
# EarlyStopping counter: 3 out of 50
# Epoch: 66/300 	Training Loss: 0.375501 	1384s
# EarlyStopping counter: 4 out of 50
# Epoch: 67/300 	Training Loss: 0.379078 	1400s
# EarlyStopping counter: 5 out of 50
# Epoch: 68/300 	Training Loss: 0.366405 	1416s
# EarlyStopping counter: 6 out of 50
# Epoch: 69/300 	Training Loss: 0.373643 	1431s
# EarlyStopping counter: 7 out of 50
# Epoch: 70/300 	Training Loss: 0.365902 	1446s
# Epoch: 71/300 	Training Loss: 0.361813 	1462s
# Epoch: 72/300 	Training Loss: 0.363354 	1477s
# Epoch: 73/300 	Training Loss: 0.349204 	1493s
# Epoch: 74/300 	Training Loss: 0.358072 	1508s
# EarlyStopping counter: 1 out of 50
# Epoch: 75/300 	Training Loss: 0.354492 	1523s
# EarlyStopping counter: 2 out of 50
# Epoch: 76/300 	Training Loss: 0.347275 	1539s
# Epoch: 77/300 	Training Loss: 0.364974 	1555s
# EarlyStopping counter: 1 out of 50
# Epoch: 78/300 	Training Loss: 0.360295 	1570s
# EarlyStopping counter: 2 out of 50
# Epoch: 79/300 	Training Loss: 0.348457 	1586s
# EarlyStopping counter: 3 out of 50
# Epoch: 80/300 	Training Loss: 0.346551 	1601s
# Epoch: 81/300 	Training Loss: 0.340200 	1617s
# EarlyStopping counter: 1 out of 50
# Epoch: 82/300 	Training Loss: 0.344217 	1632s
# EarlyStopping counter: 2 out of 50
# Epoch: 83/300 	Training Loss: 0.342304 	1648s
# EarlyStopping counter: 3 out of 50
# Epoch: 84/300 	Training Loss: 0.338438 	1663s
# EarlyStopping counter: 4 out of 50
# Epoch: 85/300 	Training Loss: 0.332616 	1679s
# EarlyStopping counter: 5 out of 50
# Epoch: 86/300 	Training Loss: 0.334738 	1695s
# EarlyStopping counter: 6 out of 50
# Epoch: 87/300 	Training Loss: 0.339944 	1710s
# EarlyStopping counter: 7 out of 50
# Epoch: 88/300 	Training Loss: 0.342192 	1726s
# EarlyStopping counter: 8 out of 50
# Epoch: 89/300 	Training Loss: 0.336039 	1741s
# Epoch: 90/300 	Training Loss: 0.329784 	1757s
# EarlyStopping counter: 1 out of 50
# Epoch: 91/300 	Training Loss: 0.325322 	1773s
# Epoch: 92/300 	Training Loss: 0.340455 	1788s
# EarlyStopping counter: 1 out of 50
# Epoch: 93/300 	Training Loss: 0.335732 	1804s
# EarlyStopping counter: 2 out of 50
# Epoch: 94/300 	Training Loss: 0.318931 	1819s
# EarlyStopping counter: 3 out of 50
# Epoch: 95/300 	Training Loss: 0.335380 	1835s
# EarlyStopping counter: 4 out of 50
# Epoch: 96/300 	Training Loss: 0.326151 	1850s
# EarlyStopping counter: 5 out of 50
# Epoch: 97/300 	Training Loss: 0.335278 	1866s
# EarlyStopping counter: 6 out of 50
# Epoch: 98/300 	Training Loss: 0.313062 	1881s
# EarlyStopping counter: 7 out of 50
# Epoch: 99/300 	Training Loss: 0.317073 	1897s
# EarlyStopping counter: 8 out of 50
# Epoch: 100/300 	Training Loss: 0.330319 	1913s
# EarlyStopping counter: 9 out of 50
# Epoch: 101/300 	Training Loss: 0.329064 	1928s
# EarlyStopping counter: 10 out of 50
# Epoch: 102/300 	Training Loss: 0.315725 	1944s
# Epoch: 103/300 	Training Loss: 0.308650 	1960s
# EarlyStopping counter: 1 out of 50
# Epoch: 104/300 	Training Loss: 0.308895 	1975s
# Epoch: 105/300 	Training Loss: 0.313623 	1991s
# EarlyStopping counter: 1 out of 50
# Epoch: 106/300 	Training Loss: 0.317238 	2006s
# Epoch: 107/300 	Training Loss: 0.320136 	2022s
# EarlyStopping counter: 1 out of 50
# Epoch: 108/300 	Training Loss: 0.310582 	2038s
# EarlyStopping counter: 2 out of 50
# Epoch: 109/300 	Training Loss: 0.315707 	2053s
# EarlyStopping counter: 3 out of 50
# Epoch: 110/300 	Training Loss: 0.303463 	2069s
# EarlyStopping counter: 4 out of 50
# Epoch: 111/300 	Training Loss: 0.357450 	2084s
# EarlyStopping counter: 5 out of 50
# Epoch: 112/300 	Training Loss: 0.308898 	2100s
# EarlyStopping counter: 6 out of 50
# Epoch: 113/300 	Training Loss: 0.298140 	2116s
# EarlyStopping counter: 7 out of 50
# Epoch: 114/300 	Training Loss: 0.303251 	2130s
# EarlyStopping counter: 8 out of 50
# Epoch: 115/300 	Training Loss: 0.307890 	2146s
# EarlyStopping counter: 9 out of 50
# Epoch: 116/300 	Training Loss: 0.299569 	2162s
# EarlyStopping counter: 10 out of 50
# Epoch: 117/300 	Training Loss: 0.308422 	2177s
# EarlyStopping counter: 11 out of 50
# Epoch: 118/300 	Training Loss: 0.303063 	2192s
# Epoch: 119/300 	Training Loss: 0.295431 	2208s
# EarlyStopping counter: 1 out of 50
# Epoch: 120/300 	Training Loss: 0.300056 	2224s
# EarlyStopping counter: 2 out of 50
# Epoch: 121/300 	Training Loss: 0.299865 	2239s
# EarlyStopping counter: 3 out of 50
# Epoch: 122/300 	Training Loss: 0.291270 	2255s
# EarlyStopping counter: 4 out of 50
# Epoch: 123/300 	Training Loss: 0.295719 	2270s
# EarlyStopping counter: 5 out of 50
# Epoch: 124/300 	Training Loss: 0.292622 	2286s
# EarlyStopping counter: 6 out of 50
# Epoch: 125/300 	Training Loss: 0.294673 	2302s
# EarlyStopping counter: 7 out of 50
# Epoch: 126/300 	Training Loss: 0.333979 	2317s
# EarlyStopping counter: 8 out of 50
# Epoch: 127/300 	Training Loss: 0.334206 	2332s
# EarlyStopping counter: 9 out of 50
# Epoch: 128/300 	Training Loss: 0.302414 	2346s
# EarlyStopping counter: 10 out of 50
# Epoch: 129/300 	Training Loss: 0.301462 	2360s
# EarlyStopping counter: 11 out of 50
# Epoch: 130/300 	Training Loss: 0.291204 	2375s
# EarlyStopping counter: 12 out of 50
# Epoch: 131/300 	Training Loss: 0.300110 	2390s
# EarlyStopping counter: 13 out of 50
# Epoch: 132/300 	Training Loss: 0.286259 	2406s
# EarlyStopping counter: 14 out of 50
# Epoch: 133/300 	Training Loss: 0.283555 	2422s
# EarlyStopping counter: 15 out of 50
# Epoch: 134/300 	Training Loss: 0.289548 	2437s
# EarlyStopping counter: 16 out of 50
# Epoch: 135/300 	Training Loss: 0.299453 	2453s
# EarlyStopping counter: 17 out of 50
# Epoch: 136/300 	Training Loss: 0.291327 	2468s
# EarlyStopping counter: 18 out of 50
# Epoch: 137/300 	Training Loss: 0.289219 	2483s
# EarlyStopping counter: 19 out of 50
# Epoch: 138/300 	Training Loss: 0.284834 	2498s
# Epoch: 139/300 	Training Loss: 0.277589 	2513s
# Epoch: 140/300 	Training Loss: 0.283528 	2529s
# Epoch: 141/300 	Training Loss: 0.286256 	2545s
# EarlyStopping counter: 1 out of 50
# Epoch: 142/300 	Training Loss: 0.281718 	2560s
# EarlyStopping counter: 2 out of 50
# Epoch: 143/300 	Training Loss: 0.291255 	2576s
# Epoch: 144/300 	Training Loss: 0.278438 	2591s
# Epoch: 145/300 	Training Loss: 0.288864 	2607s
# EarlyStopping counter: 1 out of 50
# Epoch: 146/300 	Training Loss: 0.278618 	2622s
# Epoch: 147/300 	Training Loss: 0.280156 	2637s
# EarlyStopping counter: 1 out of 50
# Epoch: 148/300 	Training Loss: 0.291196 	2653s
# EarlyStopping counter: 2 out of 50
# Epoch: 149/300 	Training Loss: 0.277653 	2668s
# EarlyStopping counter: 3 out of 50
# Epoch: 150/300 	Training Loss: 0.279005 	2684s
# EarlyStopping counter: 4 out of 50
# Epoch: 151/300 	Training Loss: 0.293346 	2700s
# EarlyStopping counter: 5 out of 50
# Epoch: 152/300 	Training Loss: 0.275810 	2716s
# EarlyStopping counter: 6 out of 50
# Epoch: 153/300 	Training Loss: 0.272204 	2732s
# EarlyStopping counter: 7 out of 50
# Epoch: 154/300 	Training Loss: 0.264619 	2747s
# Epoch: 155/300 	Training Loss: 0.273795 	2763s
# EarlyStopping counter: 1 out of 50
# Epoch: 156/300 	Training Loss: 0.282965 	2779s
# EarlyStopping counter: 2 out of 50
# Epoch: 157/300 	Training Loss: 0.276245 	2794s
# EarlyStopping counter: 3 out of 50
# Epoch: 158/300 	Training Loss: 0.269708 	2810s
# EarlyStopping counter: 4 out of 50
# Epoch: 159/300 	Training Loss: 0.265583 	2826s
# EarlyStopping counter: 5 out of 50
# Epoch: 160/300 	Training Loss: 0.276498 	2841s
# EarlyStopping counter: 6 out of 50
# Epoch: 161/300 	Training Loss: 0.283978 	2857s
# EarlyStopping counter: 7 out of 50
# Epoch: 162/300 	Training Loss: 0.268116 	2872s
# EarlyStopping counter: 8 out of 50
# Epoch: 163/300 	Training Loss: 0.280875 	2887s
# EarlyStopping counter: 9 out of 50
# Epoch: 164/300 	Training Loss: 0.265990 	2903s
# EarlyStopping counter: 10 out of 50
# Epoch: 165/300 	Training Loss: 0.264280 	2919s
# Epoch: 166/300 	Training Loss: 0.269537 	2934s
# EarlyStopping counter: 1 out of 50
# Epoch: 167/300 	Training Loss: 0.272426 	2950s
# EarlyStopping counter: 2 out of 50
# Epoch: 168/300 	Training Loss: 0.270661 	2966s
# EarlyStopping counter: 3 out of 50
# Epoch: 169/300 	Training Loss: 0.262855 	2981s
# Epoch: 170/300 	Training Loss: 0.261493 	2997s
# EarlyStopping counter: 1 out of 50
# Epoch: 171/300 	Training Loss: 0.263950 	3012s
# EarlyStopping counter: 2 out of 50
# Epoch: 172/300 	Training Loss: 0.256281 	3028s
# EarlyStopping counter: 3 out of 50
# Epoch: 173/300 	Training Loss: 0.265112 	3044s
# EarlyStopping counter: 4 out of 50
# Epoch: 174/300 	Training Loss: 0.264064 	3059s
# EarlyStopping counter: 5 out of 50
# Epoch: 175/300 	Training Loss: 0.264165 	3075s
# EarlyStopping counter: 6 out of 50
# Epoch: 176/300 	Training Loss: 0.262053 	3089s
# EarlyStopping counter: 7 out of 50
# Epoch: 177/300 	Training Loss: 0.254129 	3104s
# EarlyStopping counter: 8 out of 50
# Epoch: 178/300 	Training Loss: 0.263247 	3119s
# EarlyStopping counter: 9 out of 50
# Epoch: 179/300 	Training Loss: 0.262284 	3134s
# EarlyStopping counter: 10 out of 50
# Epoch: 180/300 	Training Loss: 0.272050 	3149s
# EarlyStopping counter: 11 out of 50
# Epoch: 181/300 	Training Loss: 0.272614 	3165s
# EarlyStopping counter: 12 out of 50
# Epoch: 182/300 	Training Loss: 0.258589 	3181s
# Epoch: 183/300 	Training Loss: 0.254298 	3196s
# EarlyStopping counter: 1 out of 50
# Epoch: 184/300 	Training Loss: 0.260321 	3212s
# EarlyStopping counter: 2 out of 50
# Epoch: 185/300 	Training Loss: 0.257184 	3227s
# EarlyStopping counter: 3 out of 50
# Epoch: 186/300 	Training Loss: 0.257126 	3243s
# EarlyStopping counter: 4 out of 50
# Epoch: 187/300 	Training Loss: 0.318385 	3259s
# EarlyStopping counter: 5 out of 50
# Epoch: 188/300 	Training Loss: 0.268967 	3274s
# EarlyStopping counter: 6 out of 50
# Epoch: 189/300 	Training Loss: 0.254676 	3289s
# EarlyStopping counter: 7 out of 50
# Epoch: 190/300 	Training Loss: 0.260357 	3304s
# Epoch: 191/300 	Training Loss: 0.249142 	3320s
# EarlyStopping counter: 1 out of 50
# Epoch: 192/300 	Training Loss: 0.247024 	3335s
# EarlyStopping counter: 2 out of 50
# Epoch: 193/300 	Training Loss: 0.260830 	3351s
# EarlyStopping counter: 3 out of 50
# Epoch: 194/300 	Training Loss: 0.253707 	3367s
# EarlyStopping counter: 4 out of 50
# Epoch: 195/300 	Training Loss: 0.245655 	3382s
# Epoch: 196/300 	Training Loss: 0.256996 	3397s
# EarlyStopping counter: 1 out of 50
# Epoch: 197/300 	Training Loss: 0.265669 	3413s
# EarlyStopping counter: 2 out of 50
# Epoch: 198/300 	Training Loss: 0.250695 	3429s
# EarlyStopping counter: 3 out of 50
# Epoch: 199/300 	Training Loss: 0.251662 	3444s
# EarlyStopping counter: 4 out of 50
# Epoch: 200/300 	Training Loss: 0.253034 	3460s
# EarlyStopping counter: 5 out of 50
# Epoch: 201/300 	Training Loss: 0.247155 	3475s
# EarlyStopping counter: 6 out of 50
# Epoch: 202/300 	Training Loss: 0.249217 	3491s
# Epoch: 203/300 	Training Loss: 0.242647 	3507s
# EarlyStopping counter: 1 out of 50
# Epoch: 204/300 	Training Loss: 0.243521 	3522s
# EarlyStopping counter: 2 out of 50
# Epoch: 205/300 	Training Loss: 0.254609 	3538s
# EarlyStopping counter: 3 out of 50
# Epoch: 206/300 	Training Loss: 0.246264 	3553s
# EarlyStopping counter: 4 out of 50
# Epoch: 207/300 	Training Loss: 0.249194 	3569s
# EarlyStopping counter: 5 out of 50
# Epoch: 208/300 	Training Loss: 0.240506 	3584s
# EarlyStopping counter: 6 out of 50
# Epoch: 209/300 	Training Loss: 0.245207 	3600s
# EarlyStopping counter: 7 out of 50
# Epoch: 210/300 	Training Loss: 0.244914 	3616s
# EarlyStopping counter: 8 out of 50
# Epoch: 211/300 	Training Loss: 0.241766 	3630s
# EarlyStopping counter: 9 out of 50
# Epoch: 212/300 	Training Loss: 0.242217 	3645s
# EarlyStopping counter: 10 out of 50
# Epoch: 213/300 	Training Loss: 0.243524 	3660s
# EarlyStopping counter: 11 out of 50
# Epoch: 214/300 	Training Loss: 0.242693 	3676s
# EarlyStopping counter: 12 out of 50
# Epoch: 215/300 	Training Loss: 0.253384 	3691s
# EarlyStopping counter: 13 out of 50
# Epoch: 216/300 	Training Loss: 0.246422 	3707s
# Epoch: 217/300 	Training Loss: 0.241954 	3722s
# EarlyStopping counter: 1 out of 50
# Epoch: 218/300 	Training Loss: 0.270630 	3738s
# EarlyStopping counter: 2 out of 50
# Epoch: 219/300 	Training Loss: 0.245801 	3753s
# EarlyStopping counter: 3 out of 50
# Epoch: 220/300 	Training Loss: 0.241158 	3768s
# EarlyStopping counter: 4 out of 50
# Epoch: 221/300 	Training Loss: 0.239226 	3784s
# EarlyStopping counter: 5 out of 50
# Epoch: 222/300 	Training Loss: 0.239749 	3799s
# EarlyStopping counter: 6 out of 50
# Epoch: 223/300 	Training Loss: 0.240307 	3815s
# EarlyStopping counter: 7 out of 50
# Epoch: 224/300 	Training Loss: 0.237499 	3830s
# EarlyStopping counter: 8 out of 50
# Epoch: 225/300 	Training Loss: 0.240477 	3845s
# EarlyStopping counter: 9 out of 50
# Epoch: 226/300 	Training Loss: 0.235504 	3859s
# EarlyStopping counter: 10 out of 50
# Epoch: 227/300 	Training Loss: 0.236619 	3875s
# EarlyStopping counter: 11 out of 50
# Epoch: 228/300 	Training Loss: 0.274413 	3890s
# EarlyStopping counter: 12 out of 50
# Epoch: 229/300 	Training Loss: 0.238460 	3906s
# EarlyStopping counter: 13 out of 50
# Epoch: 230/300 	Training Loss: 0.237142 	3922s
# EarlyStopping counter: 14 out of 50
# Epoch: 231/300 	Training Loss: 0.230862 	3938s
# EarlyStopping counter: 15 out of 50
# Epoch: 232/300 	Training Loss: 0.235469 	3953s
# Epoch: 233/300 	Training Loss: 0.237279 	3969s
# EarlyStopping counter: 1 out of 50
# Epoch: 234/300 	Training Loss: 0.239154 	3985s
# EarlyStopping counter: 2 out of 50
# Epoch: 235/300 	Training Loss: 0.238142 	4252s
# EarlyStopping counter: 3 out of 50
# Epoch: 236/300 	Training Loss: 0.236122 	4269s
# EarlyStopping counter: 4 out of 50
# Epoch: 237/300 	Training Loss: 0.249049 	4285s
# EarlyStopping counter: 5 out of 50
# Epoch: 238/300 	Training Loss: 0.234224 	4300s
# Epoch: 239/300 	Training Loss: 0.232092 	4316s
# EarlyStopping counter: 1 out of 50
# Epoch: 240/300 	Training Loss: 0.231962 	4332s
# EarlyStopping counter: 2 out of 50
# Epoch: 241/300 	Training Loss: 0.232648 	4348s
# EarlyStopping counter: 3 out of 50
# Epoch: 242/300 	Training Loss: 0.228059 	4365s
# EarlyStopping counter: 4 out of 50
# Epoch: 243/300 	Training Loss: 0.237973 	4381s
# EarlyStopping counter: 5 out of 50
# Epoch: 244/300 	Training Loss: 0.233424 	4397s
# EarlyStopping counter: 6 out of 50
# Epoch: 245/300 	Training Loss: 0.226808 	4414s
# EarlyStopping counter: 7 out of 50
# Epoch: 246/300 	Training Loss: 0.232223 	4429s
# EarlyStopping counter: 8 out of 50
# Epoch: 247/300 	Training Loss: 0.228377 	4445s
# EarlyStopping counter: 9 out of 50
# Epoch: 248/300 	Training Loss: 0.226703 	4461s
# EarlyStopping counter: 10 out of 50
# Epoch: 249/300 	Training Loss: 0.234364 	4476s
# EarlyStopping counter: 11 out of 50
# Epoch: 250/300 	Training Loss: 0.239862 	4490s
# EarlyStopping counter: 12 out of 50
# Epoch: 251/300 	Training Loss: 0.237630 	4504s
# EarlyStopping counter: 13 out of 50
# Epoch: 252/300 	Training Loss: 0.230310 	4520s
# EarlyStopping counter: 14 out of 50
# Epoch: 253/300 	Training Loss: 0.229071 	4536s
# EarlyStopping counter: 15 out of 50
# Epoch: 254/300 	Training Loss: 0.225979 	4552s
# EarlyStopping counter: 16 out of 50
# Epoch: 255/300 	Training Loss: 0.234027 	4568s
# EarlyStopping counter: 17 out of 50
# Epoch: 256/300 	Training Loss: 0.242130 	4584s
# EarlyStopping counter: 18 out of 50
# Epoch: 257/300 	Training Loss: 0.234125 	4600s
# EarlyStopping counter: 19 out of 50
# Epoch: 258/300 	Training Loss: 0.226256 	4616s
# EarlyStopping counter: 20 out of 50
# Epoch: 259/300 	Training Loss: 0.233398 	4631s
# EarlyStopping counter: 21 out of 50
# Epoch: 260/300 	Training Loss: 0.221571 	4647s
# EarlyStopping counter: 22 out of 50
# Epoch: 261/300 	Training Loss: 0.237203 	4662s
# EarlyStopping counter: 23 out of 50
# Epoch: 262/300 	Training Loss: 0.224178 	4677s
# EarlyStopping counter: 24 out of 50
# Epoch: 263/300 	Training Loss: 0.224755 	4693s
# EarlyStopping counter: 25 out of 50
# Epoch: 264/300 	Training Loss: 0.227002 	4709s
# EarlyStopping counter: 26 out of 50
# Epoch: 265/300 	Training Loss: 0.241872 	4724s
# Epoch: 266/300 	Training Loss: 0.219710 	4740s
# EarlyStopping counter: 1 out of 50
# Epoch: 267/300 	Training Loss: 0.222418 	4756s
# EarlyStopping counter: 2 out of 50
# Epoch: 268/300 	Training Loss: 0.225363 	4771s
# EarlyStopping counter: 3 out of 50
# Epoch: 269/300 	Training Loss: 0.224677 	4787s
# EarlyStopping counter: 4 out of 50
# Epoch: 270/300 	Training Loss: 0.223508 	4803s
# EarlyStopping counter: 5 out of 50
# Epoch: 271/300 	Training Loss: 0.251213 	4818s
# EarlyStopping counter: 6 out of 50
# Epoch: 272/300 	Training Loss: 0.228443 	4834s
# Epoch: 273/300 	Training Loss: 0.226220 	4849s
# Epoch: 274/300 	Training Loss: 0.222072 	4864s
# EarlyStopping counter: 1 out of 50
# Epoch: 275/300 	Training Loss: 0.219880 	4880s
# EarlyStopping counter: 2 out of 50
# Epoch: 276/300 	Training Loss: 0.220516 	4897s
# EarlyStopping counter: 3 out of 50
# Epoch: 277/300 	Training Loss: 0.223256 	4912s
# EarlyStopping counter: 4 out of 50
# Epoch: 278/300 	Training Loss: 0.223701 	4928s
# EarlyStopping counter: 5 out of 50
# Epoch: 279/300 	Training Loss: 0.217938 	4944s
# EarlyStopping counter: 6 out of 50
# Epoch: 280/300 	Training Loss: 0.218682 	4961s
# EarlyStopping counter: 7 out of 50
# Epoch: 281/300 	Training Loss: 0.222729 	4977s
# EarlyStopping counter: 8 out of 50
# Epoch: 282/300 	Training Loss: 0.217153 	4993s
# EarlyStopping counter: 9 out of 50
# Epoch: 283/300 	Training Loss: 0.221739 	5010s
# EarlyStopping counter: 10 out of 50
# Epoch: 284/300 	Training Loss: 0.237342 	5026s
# EarlyStopping counter: 11 out of 50
# Epoch: 285/300 	Training Loss: 0.224221 	5041s
# EarlyStopping counter: 12 out of 50
# Epoch: 286/300 	Training Loss: 0.223123 	5057s
# EarlyStopping counter: 13 out of 50
# Epoch: 287/300 	Training Loss: 0.227384 	5073s
# EarlyStopping counter: 14 out of 50
# Epoch: 288/300 	Training Loss: 0.221565 	5088s
# EarlyStopping counter: 15 out of 50
# Epoch: 289/300 	Training Loss: 0.219852 	5104s
# EarlyStopping counter: 16 out of 50
# Epoch: 290/300 	Training Loss: 0.214792 	5120s
# EarlyStopping counter: 17 out of 50
# Epoch: 291/300 	Training Loss: 0.225089 	5135s
# EarlyStopping counter: 18 out of 50
# Epoch: 292/300 	Training Loss: 0.226043 	5151s
# EarlyStopping counter: 19 out of 50
# Epoch: 293/300 	Training Loss: 0.219385 	5167s
# EarlyStopping counter: 20 out of 50
# Epoch: 294/300 	Training Loss: 0.222054 	5181s
# EarlyStopping counter: 21 out of 50
# Epoch: 295/300 	Training Loss: 0.211410 	5197s
# EarlyStopping counter: 22 out of 50
# Epoch: 296/300 	Training Loss: 0.216304 	5212s
# EarlyStopping counter: 23 out of 50
# Epoch: 297/300 	Training Loss: 0.213766 	5226s
# EarlyStopping counter: 24 out of 50
# Epoch: 298/300 	Training Loss: 0.218412 	5242s
# EarlyStopping counter: 25 out of 50
# Epoch: 299/300 	Training Loss: 0.216102 	5257s
# EarlyStopping counter: 26 out of 50
# Epoch: 300/300 	Training Loss: 0.218897 	5273s
# best_testloss:0.288	 epoch:299

# %%
zoomin = 0
zoomout = 6
plotTraining(lossTrainArr, lossTestArr, LrCArr, bestLoss, zoomin, zoomout)

# %%
# create testdataset

damaged_img_path = 'testdataset/damaged_image' 

if lidar_mode == 'sparse':
    lidar_path = 'testdataset/lidar_tensor/sparse'
else:
    lidar_path = 'testdataset/lidar_tensor/dense'

label_path = 'testdataset/ori_image'

damaged_img_list = sorted(glob.glob(damaged_img_path + '/*'))
lidar_list = sorted(glob.glob(lidar_path + '/*'))
label_list = sorted(glob.glob(label_path + '/*'))

learning_rate = 1e-4
batch_size = 32

TestDataset = CreateDatasets(label_list, damaged_img_list, lidar_list)
new_testloader = DataLoader(dataset=TestDataset, batch_size=batch_size, shuffle=False, num_workers=0, drop_last=True)

test_model_best = SimpleAutoencoder()
# for name, value in test_model_best.named_parameters():
#     print(name)

# test_model_last.load_state_dict(torch.load('model_save/damage_{}/last_model_{}.pth'.format(damage_label, experimentIndex)))

# if lidar_mode == 'sparse':
#     test_model_best.load_state_dict(
#     torch.load('model_save/fusion/3_sparse_best_model_600_32_20230521_174942.pth')
# )
# else:
#     test_model_best.load_state_dict(
#     torch.load('model_save/fusion/3_dense_best_model_600_32_20230522_072759.pth')
# )
# # test_model.to(device)
# test_model_last.eval()

test_model_best.load_state_dict(
    torch.load('model_save/fusion/12_early_best_model_300_32_20230531_120830.pth')
)
test_model_best.eval()


dataiter = iter(new_testloader)
label, damaged_img, lidar = next(dataiter)
# label, damaged_img, lidar = next(dataiter)
# label, damaged_img, lidar = next(dataiter)
# label, damaged_img, lidar = next(dataiter)
# label, damaged_img, lidar = next(dataiter)
# label, damaged_img, lidar = next(dataiter)
# label, damaged_img, lidar = next(dataiter)
# label, damaged_img, lidar = next(dataiter)




output = test_model_best(damaged_img, lidar)

# %%
##################################################
# visualize one batch of the validation images #
##################################################
# test_model.to(device)




# test_model.to(device)
# test_model_last.eval()
test_model_best.eval()


# obtain one batch of test images
dataiter = iter(new_testloader)
# dataiter = iter(valloader)

label, damaged_img, lidar = next(dataiter)

# get sample outputs
output = test_model_best(damaged_img, lidar)

# prep images for display
i = 31
# for i in range(32):

img1 = label[i].numpy()
img1 = img1.transpose(1, 2, 0)
img2 = damaged_img[i].numpy()
img2 = img2.transpose(1, 2, 0)
img3 = lidar[i].detach().numpy()
img3 = img3.transpose(1, 2, 0)
img4 = output[i].detach().numpy()
img4 = img4.transpose(1, 2, 0)


ax = plt.subplot(1, 4, 1)
plt.xticks([])
plt.yticks([])
# ax.set_title('label')
plt.imshow(img1,cmap='gray')

ax = plt.subplot(1, 4, 2)
plt.xticks([])
plt.yticks([])
# ax.set_title('damaged image')
plt.imshow(img2,cmap='gray')

ax = plt.subplot(1, 4, 3)
plt.xticks([])
plt.yticks([])
# ax.set_title('lidar')
plt.imshow(img3)

ax = plt.subplot(1, 4, 4)
plt.xticks([])
plt.yticks([])
#  ax.set_title('reconstructed image')
plt.imshow(img4, cmap='gray')

# plt.savefig('fig_save/{}.png'.format(i))
    
plt.show()

# %%
import cv2
from PIL import Image
from torchvision import transforms
from matplotlib import pyplot as plt


toPIL = transforms.ToPILImage()

# prep images for display
for i in range(32):
# i = 31

    img1 = label[i]
    img2 = damaged_img[i]
    img3 = lidar[i]
    img4 = output[i]
    # print(img1.shape, img3.shape)
    # print(type(img1),type(img3))
    # im1 = toPIL(img1)
    img4 = img4[0]
    max_value = torch.max(img4)
    min_value = torch.min(img4)
    print(max_value,min_value)

    

    img4_normalized = (img4 - min_value) / (max_value - min_value)


    im4 = toPIL(img4_normalized)
    im3 = toPIL(img3)
    name = '%02d' %i

# im1.save('RecosntructedImages/ori_img/{}.png'.format(name))
# im2.save('RecosntructedImages/masked_img/{}.png'.format(name))
# im4.save('output_save/5_main_fusion_3_dense/A/{}.png'.format(name))
# im3.save('output_save/lidar_sparse_testing/{}.png'.format(name))
# im4.save('{}.png'.format(name))

# import numpy as np
# import cv2

# for i in range(32):
#     if i ==13:
#         img1 = label[i].numpy()
#         img1 = img1.transpose(1, 2, 0)
#         img2 = damaged_img[i].numpy()
#         img2 = img2.transpose(1, 2, 0)
#         img3 = lidar[i].detach().numpy()
#         img3 = img3.transpose(1, 2, 0)
#         img4 = output[i].detach().numpy()
#         img4 = img4.transpose(1, 2, 0)

#         name = '%02d' %i
#         filepath = 'output_save/test/{}.png'.format(name)

#         # 调用函数将灰度图像保存为RGB图像的PNG
#         # cv2.imwrite(filepath, img4)
#         plt.xticks([])
#         plt.yticks([])
#         plt.imshow(img4, cmap='gray')
#         plt.savefig(filepath)
#         plt.colorbar()
#         plt.show()
# Out:
# tensor(1.0590, grad_fn=<MaxBackward1>) tensor(-0.0068, grad_fn=<MinBackward1>)
# tensor(1.1087, grad_fn=<MaxBackward1>) tensor(0.0157, grad_fn=<MinBackward1>)
# tensor(1.1730, grad_fn=<MaxBackward1>) tensor(0.0492, grad_fn=<MinBackward1>)
# tensor(1.2108, grad_fn=<MaxBackward1>) tensor(0.0889, grad_fn=<MinBackward1>)
# tensor(1.1027, grad_fn=<MaxBackward1>) tensor(0.0243, grad_fn=<MinBackward1>)
# tensor(1.0759, grad_fn=<MaxBackward1>) tensor(0.0110, grad_fn=<MinBackward1>)
# tensor(1.0808, grad_fn=<MaxBackward1>) tensor(-0.0420, grad_fn=<MinBackward1>)
# tensor(1.1386, grad_fn=<MaxBackward1>) tensor(0.0065, grad_fn=<MinBackward1>)
# tensor(1.1145, grad_fn=<MaxBackward1>) tensor(-0.0084, grad_fn=<MinBackward1>)
# tensor(1.1468, grad_fn=<MaxBackward1>) tensor(-0.0678, grad_fn=<MinBackward1>)
# tensor(1.1297, grad_fn=<MaxBackward1>) tensor(0.0129, grad_fn=<MinBackward1>)
# tensor(1.1884, grad_fn=<MaxBackward1>) tensor(-0.0378, grad_fn=<MinBackward1>)
# tensor(1.1725, grad_fn=<MaxBackward1>) tensor(0.0098, grad_fn=<MinBackward1>)
# tensor(1.2034, grad_fn=<MaxBackward1>) tensor(0.0052, grad_fn=<MinBackward1>)
# tensor(1.1897, grad_fn=<MaxBackward1>) tensor(-0.0379, grad_fn=<MinBackward1>)
# tensor(1.0158, grad_fn=<MaxBackward1>) tensor(-0.0865, grad_fn=<MinBackward1>)
# tensor(1.1563, grad_fn=<MaxBackward1>) tensor(0.0439, grad_fn=<MinBackward1>)
# tensor(1.1152, grad_fn=<MaxBackward1>) tensor(-0.0401, grad_fn=<MinBackward1>)
# tensor(1.1378, grad_fn=<MaxBackward1>) tensor(0.0118, grad_fn=<MinBackward1>)
# tensor(1.0568, grad_fn=<MaxBackward1>) tensor(-0.0113, grad_fn=<MinBackward1>)
# tensor(1.1285, grad_fn=<MaxBackward1>) tensor(0.0018, grad_fn=<MinBackward1>)
# tensor(1.0817, grad_fn=<MaxBackward1>) tensor(-0.0624, grad_fn=<MinBackward1>)
# tensor(1.0866, grad_fn=<MaxBackward1>) tensor(0.0049, grad_fn=<MinBackward1>)
# tensor(1.1885, grad_fn=<MaxBackward1>) tensor(-0.0627, grad_fn=<MinBackward1>)
# tensor(1.2119, grad_fn=<MaxBackward1>) tensor(0.0021, grad_fn=<MinBackward1>)
# tensor(0.9890, grad_fn=<MaxBackward1>) tensor(-0.0130, grad_fn=<MinBackward1>)
# tensor(1.1017, grad_fn=<MaxBackward1>) tensor(0.0346, grad_fn=<MinBackward1>)
# tensor(1.1487, grad_fn=<MaxBackward1>) tensor(-0.0351, grad_fn=<MinBackward1>)
# tensor(1.1557, grad_fn=<MaxBackward1>) tensor(0.0440, grad_fn=<MinBackward1>)
# tensor(1.1426, grad_fn=<MaxBackward1>) tensor(0.0385, grad_fn=<MinBackward1>)
# tensor(0.9970, grad_fn=<MaxBackward1>) tensor(-0.0692, grad_fn=<MinBackward1>)
# tensor(1.1206, grad_fn=<MaxBackward1>) tensor(-0.0156, grad_fn=<MinBackward1>)

# %%
# MSE for all damages
criterion = nn.MSELoss()
criterion.to(device)

for i, batch in enumerate(new_testloader):# i -->index of batch
    count = 0
    for j in range (batch_size):
        img1 = label[i]
        img3 = output[i]
        mse = criterion(img1,img3)
        mse = round(mse.item(),6)
        count = count+mse

    mse_mean = round(count,3)
    print(mse_mean)
# Out:
# 0.619
# 0.242
# 0.486
# 0.244
# 0.226
# 0.92
# 0.116
# 0.434

# %%
# # regional mse

# batch_size = 32

# def create_mask(image_shape, block_size, num_blocks):
#     mask = np.ones(image_shape, dtype=np.float32) 
#     block_size_px = (int(image_shape[0] * block_size), int(image_shape[1] * block_size))
#     np.random.seed(6)

#     for _ in range(num_blocks):
#         top_left = np.random.randint(0, image_shape[0] - block_size_px[0] + 1), np.random.randint(0, image_shape[1] - block_size_px[1] + 1)
#         bottom_right = top_left[0] + block_size_px[0], top_left[1] + block_size_px[1]
#         mask[top_left[0]:bottom_right[0], top_left[1]:bottom_right[1]] = 0
        
#     return mask


# block_size = 0.2  # 方块大小为原图大小的百分比
# num_blocks = 16  # 方块数量

# count = 0

# # for j in range(label.size(0)):
# #     ori_img_np = label[j][0].detach().numpy()
# #     output_np = output[j][0].detach().numpy()
# #     mask = create_mask(ori_img_np.shape[:2], block_size, num_blocks)
# #     local_mse = np.mean(np.square(output_np - ori_img_np) * mask)
# #     count = count+local_mse
# # local_mse = round(count/batch_size, 6)

# # baseline
# for j in range(label.size(0)):
#     ori_img_np = label[j][0].detach().numpy()
#     output_np = output[j][0].detach().numpy()
#     mask = create_mask(ori_img_np.shape[:2], block_size, num_blocks)
#     local_mse = np.mean(np.square(output_np - ori_img_np) * mask)
#     count = count+local_mse
# local_mse = round(count/batch_size, 6)

# print(local_mse)
# Out:
# 0.003846

# %%
import cv2
import os
import numpy

masked_region_list = []
original_image_list = []

image_path = 'testdataset/ori_image'
images = sorted(glob.glob(image_path + '/*'))[0:32]
damage_label = 'A'

def create_mask(image_shape, block_size, num_blocks):
    mask = np.ones(image_shape, dtype=np.float32) 
    block_size_px = (int(image_shape[0] * block_size), int(image_shape[1] * block_size))
    np.random.seed(6)
    masked_region = []

    for _ in range(num_blocks):
        top_left = np.random.randint(0, image_shape[0] - block_size_px[0] + 1), np.random.randint(0, image_shape[1] - block_size_px[1] + 1)
        bottom_right = top_left[0] + block_size_px[0], top_left[1] + block_size_px[1]
        mask[top_left[0]:bottom_right[0], top_left[1]:bottom_right[1]] = 0
        masked_region.append((top_left, bottom_right))
        
    return mask, masked_region


for i in range(len(images)):
    image = cv2.imread(images[i])
    image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    ori_img_name = os.path.basename(images[i])

    block_size = 0.2  # 方块大小为原图大小的百分比
    num_blocks = 16  # 方块数量
    mask, masked_region = create_mask(image.shape[:2], block_size, num_blocks)
    masked_region_list.append(masked_region)
    original_image_list.append(image)
    damaged_img1 = image * mask
    # cv2.imwrite(f'testdataset/damaged_image/{damage_label}_{ori_img_name}', damaged_img1)

regional_mse_list = []

for i in range(len(images)):
    original_image = original_image_list[i]
    masked_region = masked_region_list[i]
    original_image = (original_image-np.min(original_image))/(np.max(original_image)-np.min(original_image))
    

    
    # Obtain the output reconstructed image
    output_image = output[i][0].detach().numpy()  # Replace this with the code to get the output image from your image reconstruction network
    # output_image = (output_image-np.min(output_image))/(np.max(output_image)-np.min(output_image))
    
    mse = 0
    num_pixels = 0

    for region in masked_region:
        top_left, bottom_right = region
        original_pixels = original_image[top_left[0]:bottom_right[0], top_left[1]:bottom_right[1]]
        output_pixels = output_image[top_left[0]:bottom_right[0], top_left[1]:bottom_right[1]]
        diff = original_pixels.astype(np.float32) - output_pixels.astype(np.float32)
        mse += np.sum(diff ** 2)
        num_pixels += original_pixels.size

    mse /= num_pixels
    regional_mse_list.append(mse)

print(np.mean(regional_mse_list))
# Out:
# 0.022718672346236417

# %%
# SSIM

import torch
from skimage.metrics import structural_similarity as ssim
import glob


metric_value_list = []
batch_size = 32


for i, batch in enumerate(new_testloader):
    label, damaged_img, lidar = batch
    count = 0
    for j in range(label.size(0)):
        ori_img_np = label[j][0].detach().cpu().numpy()
        output_np = output[j][0].detach().cpu().numpy()
        ssim_img, diff = ssim(ori_img_np, output_np, full=True, data_range=1.0)
        count = count + ssim_img
    ssim_img = round(count / label.size(0), 3)
    print(ssim_img)
#     metric_value_list.append(ssim_img)

# print(metric_value_list)
# Out:
# 0.642
# 0.234
# 0.219
# 0.209
# 0.208
# 0.213
# 0.223
# 0.223

# %%
# LLIPS metrics

import lpips

loss_fn = lpips.LPIPS(net='alex')


for i, batch in enumerate(new_testloader):  # i -->index of batch
    label, damaged_img, lidar = batch
    count = 0
    for j in range(label.size(0)):
        # ori_img_np = ori_img[j][0].detach().numpy()
        # output_np = output[j][0].detach().numpy()
        lpips_img = loss_fn.forward(label, output)
        sum_result = (torch.sum(lpips_img)).item()
        count = count+sum_result
        # count = count.item()
    lpips_img = round(count/label.size(0),3)
    print(lpips_img)
#     metric_value_list.append(lpips_img)

# print(f'scuccess: {metric_value_list}')
# Out:
# Setting up [LPIPS] perceptual loss: trunk [alex], v[0.1], spatial [off]
# Loading model from: /usr/local/Anaconda3-2021.11-Linux-x86_64/envs/pytorch/lib/python3.8/site-packages/lpips/weights/v0.1/alex.pth
# 9.668
# 17.138
# 17.44
# 17.781
# 17.519
# 17.409
# 17.671
# 17.586
# 17.696
