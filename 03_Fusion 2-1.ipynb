# %%
# generate a new weights tensor for the fusion + CNN

# %%
from matplotlib import pyplot as plt
from torch.utils.data import DataLoader
from sensorFusionDataset.creatDataset_2_encoder import CreateDatasets
from sensorFusionDataset.data_split import split_dataset
from sensorFusionNetwork.simpleAutoencoder import SimpleAutoencoder, TwoEncoderOneDecoder_fusion_4, WeightsGenerator
from testLoop import test_loop_fusion
from trainLoop import train_loop_fusion
from visualization import plot_losses, plot_metrics,plotTraining
from earlystopping import EarlyStopping

import h5py as h5
from datetime import datetime
import copy
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import glob
import time

local_time =time.strftime("%Y-%m-%d %H:%M:%S", time.localtime())[-8:-1]
now = datetime.now()
dt_string = now.strftime("%Y%m%d_%H%M%S")
# CPU OR GPU
device = 'cuda' if torch.cuda.is_available() else 'cpu'

damaged_img_path = 'image_gray_200_damaged' 

lidar_mode = 'sparse'

if lidar_mode == 'sparse':
    lidar_path = 'lidar_tesor_200_sparse'
else:
    lidar_path = 'lidar_tesor_200_dense'

label_path = 'image_gray_200_original'

damaged_img_list = sorted(glob.glob(damaged_img_path + '/*'))[0:7200]
lidar_list = sorted(glob.glob(lidar_path + '/*'))[0:7200]
label_list = sorted(glob.glob(label_path + '/*'))[0:7200]


batch_size = 32
learning_rate = 1e-4
epochs = 600

MyDataset = CreateDatasets(label_list, damaged_img_list, lidar_list)#, img_size=img_size
train_dataset, test_dataset, val_dataset = split_dataset(MyDataset, 0.7, 0.2)
train_loader = DataLoader(dataset=train_dataset, batch_size=batch_size, shuffle=True, num_workers=0,
                          drop_last=True)
test_loader = DataLoader(dataset=test_dataset, batch_size=batch_size, shuffle=True, num_workers=0,
                         drop_last=True)
val_loader = DataLoader(dataset=val_dataset, batch_size=batch_size, shuffle=False, num_workers=0,
                        drop_last=True)

patience = 50	# 当验证集损失在连续20次训练周期中都没有得到降低时，停止模型训练，以防止模型过拟合
save_path = 'fusion_model/'
early_stopping = EarlyStopping(save_path = save_path, patience = patience)	

criterion = nn.MSELoss()




# new_model = SimpleAutoencoder()
# new_model.to(device)
# new_model.load_state_dict(torch.load('denoising_model/best_model_300_32_0.0004_20230422_153250.pth'))

# for name, value in new_model.named_parameters():
#     #print (name) # print(model.state_dict().keys())
#     if name.startswith('decoder'):
#         value.requires_grad = False
        
# params = filter(lambda p: p.requires_grad, new_model.parameters())
# optimizer = torch.optim.Adam(params, lr=learning_rate)

# criterion = nn.MSELoss()
# criterion.to(device)

training_loss = []
training_baseloss = []
test_loss = []
testing_baseloss = []
hisLrC = []
min_loss=10000

print (f'loading fertig! {device}' )
# Out:
# loading fertig! cuda

# %%
# retraining with the channel adjust
# loading model
removal_layer = nn.Sequential()

encoder_img = SimpleAutoencoder()
encoder_img.load_state_dict(torch.load('model_save/ori2ori/ori2ori_best_model_600_32_20230518_044338.pth'))
encoder_img.decoder = removal_layer


encoder_lidar = SimpleAutoencoder()
if lidar_mode == 'sparse':
    encoder_lidar.load_state_dict(torch.load('model_save/lidar2img/sparse_FIX_best_model_600_32_20230518_063828.pth'))
else:
    encoder_lidar.load_state_dict(torch.load('model_save/lidar2img/dense_FIX_best_model_600_32_20230518_154020.pth'))
encoder_lidar.decoder = removal_layer


decoder = SimpleAutoencoder()
decoder.load_state_dict(torch.load('model_save/ori2ori/ori2ori_best_model_600_32_20230518_044338.pth'))
# decoder.load_state_dict(torch.load('denoising_model/best_model_300_32_0.0004_20230422_153250.pth'))
decoder.encoder = removal_layer

channelAdjust = WeightsGenerator()
# channelAdjust.to(device)

fusion_net = TwoEncoderOneDecoder_fusion_4(encoder_img, encoder_lidar, decoder, channelAdjust)
fusion_net.to(device)

for name, value in fusion_net.named_parameters():
    # print (name) # print(model.state_dict().keys())
    if name.startswith('decoder'):
        value.requires_grad = False
    if name.startswith('encoder'):
        value.requires_grad = False
        
params = filter(lambda p: p.requires_grad, fusion_net.parameters())


learning_rate = 0.0004  # 2e-4 batchsize=30
optimizer = torch.optim.Adam(params, lr=learning_rate)

criterion = nn.MSELoss()
criterion.to(device)


start_time = time.time()
for epoch in range(1, epochs + 1):
    # monitor training loss
    ##############################
    # start training the model #
    ##############################
    hisLrC.append(epoch)
    train_epoch_loss, train_epoch_baseloss = train_loop_fusion(train_loader, fusion_net, criterion, optimizer, device)
    training_loss.append(train_epoch_loss)
    # training_baseloss.append(train_epoch_baseloss)
    print('Epoch: {}/{} \tTraining Loss: {:.6f} \t{:.0f}s'.format(epoch, epochs, train_epoch_loss,
                                                                  time.time() - start_time))

    ##############################
    # start testing the model #
    ##############################
    with torch.no_grad():
        test_epoch_loss, test_epoch_baseloss = test_loop_fusion(test_loader, fusion_net, criterion, device)
        test_loss.append(test_epoch_loss)
        # testing_baseloss.append(test_epoch_baseloss)
        
    # type(train_epoch_loss)) ---> float
    # writer.add_scalars('loss', {'training loss': train_epoch_loss, 'test loss': test_epoch_loss}, epoch)

        
    if test_epoch_loss < min_loss:
        min_loss = test_epoch_loss
        best_model_wts = copy.deepcopy(fusion_net.state_dict())
       

    if epoch == epochs:
        torch.save(best_model_wts, 'model_save/fusion/10_fusion_4_best_model_{}_{}_{}.pth'.format(epochs, batch_size,dt_string))
        print('best_testloss:{:.3f}\t epoch:{}'.format(min_loss, test_loss.index(min_loss)))     

    # 早停止
    date = dt_string
    early_stopping(test_epoch_loss, fusion_net, date)
    #达到早停止条件时，early_stop会被置为True
    if early_stopping.early_stop:
        torch.save(best_model_wts, 'model_save/fusion/10_fusion_4_best_model_{}_{}_{}.pth'.format(epochs, batch_size,dt_string))
        # torch.save(fusion_net.state_dict(), 'Experiment2_sequence_inverse/fusion_model/last_model_{}_{}_{}.pth'.format(epochs, batch_size,dt_string))
        print('best_testloss:{:.3f}\t epoch:{}'.format(min_loss, test_loss.index(min_loss)))  
        print("Early stopping")
        break #跳出迭代，结束训练    
    
# train_baseline = sum(training_baseloss)/len(training_baseloss)
# test_baseline = sum(testing_baseloss)/len(training_baseloss)
# psnr_baseline = np.mean(psnr_base_list)

# train_baseline=train_baseline.item()
# test_baseline =test_baseline.item()
last_trainingloss = training_loss[-1]
last_testloss = test_loss[-1]


# write the dataset in one existed h5-file
now = datetime.now()
dt_string = now.strftime("%Y%m%d_%H%M%S")

lossTrainArr = np.array(training_loss)
lossTestArr = np.array(test_loss)
bestLoss = np.array([min_loss])
LrCArr = np.array(hisLrC)

h5f =h5.File(f"log/recording_{dt_string}.hdf5","w")
# h5f = h5.File('train/train.h5', 'r+') # write in an exsited h5 file
g1 = h5f.create_group('log1')
g1.attrs['data']=now.strftime("%Y-%m-%d")
# g1.attrs['model']=ModelWts
# g1.attrs['optLrOrg']=str(optLrOrg)+'={:3.1e}'.format(optLrOrg) 
# g1.attrs['lrAdstep']= str(lrAdstep)
# g1.attrs['optimizer']= str(optimizer)[:4]

g1.create_dataset('lossTrain', data=lossTrainArr)
g1.create_dataset('lossTest', data=lossTestArr)
g1.create_dataset('bestLoss', data=bestLoss)
g1.create_dataset('LrCArr', data=LrCArr)
h5f.close()

# print('train_baseline:{:.3f} \t test_baseline:{:.3f} \t last trainingloss:{:.3f} \t last testloss:{:.3f}'.format(train_baseline, test_baseline,last_trainingloss,last_testloss))
# Out:
# Epoch: 1/600 	Training Loss: 1.299612 	202s
# Epoch: 2/600 	Training Loss: 1.053763 	295s
# Epoch: 3/600 	Training Loss: 1.003158 	312s
# Epoch: 4/600 	Training Loss: 0.972748 	330s
# EarlyStopping counter: 1 out of 50
# Epoch: 5/600 	Training Loss: 0.951093 	347s
# Epoch: 6/600 	Training Loss: 0.927590 	365s
# Epoch: 7/600 	Training Loss: 0.910320 	383s
# Epoch: 8/600 	Training Loss: 0.895940 	400s
# Epoch: 9/600 	Training Loss: 0.874406 	418s
# Epoch: 10/600 	Training Loss: 0.857874 	435s
# Epoch: 11/600 	Training Loss: 0.846582 	453s
# EarlyStopping counter: 1 out of 50
# Epoch: 12/600 	Training Loss: 0.852153 	470s
# Epoch: 13/600 	Training Loss: 0.831565 	488s
# EarlyStopping counter: 1 out of 50
# Epoch: 14/600 	Training Loss: 0.825997 	505s
# Epoch: 15/600 	Training Loss: 0.819050 	523s
# EarlyStopping counter: 1 out of 50
# Epoch: 16/600 	Training Loss: 0.813059 	540s
# Epoch: 17/600 	Training Loss: 0.806763 	558s
# Epoch: 18/600 	Training Loss: 0.806924 	575s
# EarlyStopping counter: 1 out of 50
# Epoch: 19/600 	Training Loss: 0.800004 	593s
# Epoch: 20/600 	Training Loss: 0.795835 	610s
# Epoch: 21/600 	Training Loss: 0.789483 	628s
# EarlyStopping counter: 1 out of 50
# Epoch: 22/600 	Training Loss: 0.784664 	645s
# EarlyStopping counter: 2 out of 50
# Epoch: 23/600 	Training Loss: 0.777190 	663s
# Epoch: 24/600 	Training Loss: 0.774191 	680s
# Epoch: 25/600 	Training Loss: 0.771405 	698s
# EarlyStopping counter: 1 out of 50
# Epoch: 26/600 	Training Loss: 0.767267 	715s
# Epoch: 27/600 	Training Loss: 0.764327 	733s
# Epoch: 28/600 	Training Loss: 0.755697 	750s
# Epoch: 29/600 	Training Loss: 0.755863 	768s
# EarlyStopping counter: 1 out of 50
# Epoch: 30/600 	Training Loss: 0.752803 	786s
# Epoch: 31/600 	Training Loss: 0.755377 	803s
# EarlyStopping counter: 1 out of 50
# Epoch: 32/600 	Training Loss: 0.755367 	821s
# Epoch: 33/600 	Training Loss: 0.748611 	838s
# Epoch: 34/600 	Training Loss: 0.745517 	856s
# EarlyStopping counter: 1 out of 50
# Epoch: 35/600 	Training Loss: 0.745427 	873s
# EarlyStopping counter: 2 out of 50
# Epoch: 36/600 	Training Loss: 0.739591 	891s
# EarlyStopping counter: 3 out of 50
# Epoch: 37/600 	Training Loss: 0.735866 	909s
# EarlyStopping counter: 4 out of 50
# Epoch: 38/600 	Training Loss: 0.736491 	926s
# Epoch: 39/600 	Training Loss: 0.739456 	943s
# Epoch: 40/600 	Training Loss: 0.728657 	961s
# EarlyStopping counter: 1 out of 50
# Epoch: 41/600 	Training Loss: 0.727208 	979s
# Epoch: 42/600 	Training Loss: 0.726580 	996s
# EarlyStopping counter: 1 out of 50
# Epoch: 43/600 	Training Loss: 0.722852 	1014s
# EarlyStopping counter: 2 out of 50
# Epoch: 44/600 	Training Loss: 0.719142 	1031s
# EarlyStopping counter: 3 out of 50
# Epoch: 45/600 	Training Loss: 0.715888 	1049s
# EarlyStopping counter: 4 out of 50
# Epoch: 46/600 	Training Loss: 0.722935 	1067s
# EarlyStopping counter: 5 out of 50
# Epoch: 47/600 	Training Loss: 0.716022 	1084s
# Epoch: 48/600 	Training Loss: 0.717940 	1102s
# EarlyStopping counter: 1 out of 50
# Epoch: 49/600 	Training Loss: 0.716761 	1120s
# EarlyStopping counter: 2 out of 50
# Epoch: 50/600 	Training Loss: 0.709269 	1137s
# EarlyStopping counter: 3 out of 50
# Epoch: 51/600 	Training Loss: 0.707959 	1155s
# Epoch: 52/600 	Training Loss: 0.707300 	1172s
# EarlyStopping counter: 1 out of 50
# Epoch: 53/600 	Training Loss: 0.708083 	1190s
# EarlyStopping counter: 2 out of 50
# Epoch: 54/600 	Training Loss: 0.704784 	1208s
# EarlyStopping counter: 3 out of 50
# Epoch: 55/600 	Training Loss: 0.698646 	1225s
# Epoch: 56/600 	Training Loss: 0.702306 	1242s
# EarlyStopping counter: 1 out of 50
# Epoch: 57/600 	Training Loss: 0.700861 	1260s
# EarlyStopping counter: 2 out of 50
# Epoch: 58/600 	Training Loss: 0.702291 	1277s
# EarlyStopping counter: 3 out of 50
# Epoch: 59/600 	Training Loss: 0.700634 	1295s
# EarlyStopping counter: 4 out of 50
# Epoch: 60/600 	Training Loss: 0.696521 	1312s
# Epoch: 61/600 	Training Loss: 0.693395 	1330s
# EarlyStopping counter: 1 out of 50
# Epoch: 62/600 	Training Loss: 0.695096 	1347s
# Epoch: 63/600 	Training Loss: 0.692511 	1365s
# EarlyStopping counter: 1 out of 50
# Epoch: 64/600 	Training Loss: 0.694406 	1382s
# EarlyStopping counter: 2 out of 50
# Epoch: 65/600 	Training Loss: 0.697545 	1400s
# Epoch: 66/600 	Training Loss: 0.687296 	1417s
# Epoch: 67/600 	Training Loss: 0.690583 	1435s
# EarlyStopping counter: 1 out of 50
# Epoch: 68/600 	Training Loss: 0.687184 	1453s
# EarlyStopping counter: 2 out of 50
# Epoch: 69/600 	Training Loss: 0.688726 	1470s
# Epoch: 70/600 	Training Loss: 0.682929 	1488s
# EarlyStopping counter: 1 out of 50
# Epoch: 71/600 	Training Loss: 0.681504 	1505s
# Epoch: 72/600 	Training Loss: 0.687972 	1523s
# EarlyStopping counter: 1 out of 50
# Epoch: 73/600 	Training Loss: 0.684065 	1540s
# EarlyStopping counter: 2 out of 50
# Epoch: 74/600 	Training Loss: 0.689222 	1557s
# EarlyStopping counter: 3 out of 50
# Epoch: 75/600 	Training Loss: 0.690700 	1575s
# EarlyStopping counter: 4 out of 50
# Epoch: 76/600 	Training Loss: 0.677521 	1592s
# EarlyStopping counter: 5 out of 50
# Epoch: 77/600 	Training Loss: 0.673338 	1610s
# EarlyStopping counter: 6 out of 50
# Epoch: 78/600 	Training Loss: 0.682987 	1627s
# EarlyStopping counter: 7 out of 50
# Epoch: 79/600 	Training Loss: 0.678321 	1645s
# EarlyStopping counter: 8 out of 50
# Epoch: 80/600 	Training Loss: 0.673273 	1662s
# Epoch: 81/600 	Training Loss: 0.676493 	1680s
# EarlyStopping counter: 1 out of 50
# Epoch: 82/600 	Training Loss: 0.673858 	1697s
# Epoch: 83/600 	Training Loss: 0.675004 	1715s
# EarlyStopping counter: 1 out of 50
# Epoch: 84/600 	Training Loss: 0.674054 	1732s
# EarlyStopping counter: 2 out of 50
# Epoch: 85/600 	Training Loss: 0.666911 	1750s
# EarlyStopping counter: 3 out of 50
# Epoch: 86/600 	Training Loss: 0.667901 	1767s
# EarlyStopping counter: 4 out of 50
# Epoch: 87/600 	Training Loss: 0.666736 	1785s
# Epoch: 88/600 	Training Loss: 0.669961 	1803s
# EarlyStopping counter: 1 out of 50
# Epoch: 89/600 	Training Loss: 0.670151 	1820s
# EarlyStopping counter: 2 out of 50
# Epoch: 90/600 	Training Loss: 0.668098 	1837s
# EarlyStopping counter: 3 out of 50
# Epoch: 91/600 	Training Loss: 0.673659 	1855s
# EarlyStopping counter: 4 out of 50
# Epoch: 92/600 	Training Loss: 0.663170 	1872s
# EarlyStopping counter: 5 out of 50
# Epoch: 93/600 	Training Loss: 0.672063 	1890s
# EarlyStopping counter: 6 out of 50
# Epoch: 94/600 	Training Loss: 0.665519 	1907s
# EarlyStopping counter: 7 out of 50
# Epoch: 95/600 	Training Loss: 0.658480 	1925s
# EarlyStopping counter: 8 out of 50
# Epoch: 96/600 	Training Loss: 0.660218 	1943s
# EarlyStopping counter: 9 out of 50
# Epoch: 97/600 	Training Loss: 0.660446 	1960s
# Epoch: 98/600 	Training Loss: 0.662608 	1978s
# EarlyStopping counter: 1 out of 50
# Epoch: 99/600 	Training Loss: 0.659344 	1995s
# EarlyStopping counter: 2 out of 50
# Epoch: 100/600 	Training Loss: 0.653477 	2012s
# EarlyStopping counter: 3 out of 50
# Epoch: 101/600 	Training Loss: 0.663116 	2030s
# EarlyStopping counter: 4 out of 50
# Epoch: 102/600 	Training Loss: 0.656144 	2048s
# EarlyStopping counter: 5 out of 50
# Epoch: 103/600 	Training Loss: 0.657240 	2066s
# Epoch: 104/600 	Training Loss: 0.659120 	2083s
# EarlyStopping counter: 1 out of 50
# Epoch: 105/600 	Training Loss: 0.653926 	2101s
# Epoch: 106/600 	Training Loss: 0.652920 	2118s
# EarlyStopping counter: 1 out of 50
# Epoch: 107/600 	Training Loss: 0.651538 	2136s
# EarlyStopping counter: 2 out of 50
# Epoch: 108/600 	Training Loss: 0.664547 	2153s
# EarlyStopping counter: 3 out of 50
# Epoch: 109/600 	Training Loss: 0.651860 	2171s
# EarlyStopping counter: 4 out of 50
# Epoch: 110/600 	Training Loss: 0.654904 	2188s
# EarlyStopping counter: 5 out of 50
# Epoch: 111/600 	Training Loss: 0.648562 	2206s
# EarlyStopping counter: 6 out of 50
# Epoch: 112/600 	Training Loss: 0.647399 	2223s
# EarlyStopping counter: 7 out of 50
# Epoch: 113/600 	Training Loss: 0.653338 	2241s
# EarlyStopping counter: 8 out of 50
# Epoch: 114/600 	Training Loss: 0.651626 	2258s
# EarlyStopping counter: 9 out of 50
# Epoch: 115/600 	Training Loss: 0.646550 	2276s
# EarlyStopping counter: 10 out of 50
# Epoch: 116/600 	Training Loss: 0.647586 	2293s
# EarlyStopping counter: 11 out of 50
# Epoch: 117/600 	Training Loss: 0.650596 	2311s
# EarlyStopping counter: 12 out of 50
# Epoch: 118/600 	Training Loss: 0.647961 	2328s
# EarlyStopping counter: 13 out of 50
# Epoch: 119/600 	Training Loss: 0.649870 	2346s
# EarlyStopping counter: 14 out of 50
# Epoch: 120/600 	Training Loss: 0.645765 	2363s
# EarlyStopping counter: 15 out of 50
# Epoch: 121/600 	Training Loss: 0.642994 	2381s
# EarlyStopping counter: 16 out of 50
# Epoch: 122/600 	Training Loss: 0.642204 	2398s
# EarlyStopping counter: 17 out of 50
# Epoch: 123/600 	Training Loss: 0.644780 	2416s
# EarlyStopping counter: 18 out of 50
# Epoch: 124/600 	Training Loss: 0.644542 	2433s
# Epoch: 125/600 	Training Loss: 0.642511 	2451s
# EarlyStopping counter: 1 out of 50
# Epoch: 126/600 	Training Loss: 0.638181 	2468s
# Epoch: 127/600 	Training Loss: 0.639330 	2486s
# EarlyStopping counter: 1 out of 50
# Epoch: 128/600 	Training Loss: 0.642061 	2503s
# EarlyStopping counter: 2 out of 50
# Epoch: 129/600 	Training Loss: 0.641427 	2521s
# EarlyStopping counter: 3 out of 50
# Epoch: 130/600 	Training Loss: 0.639574 	2538s
# Epoch: 131/600 	Training Loss: 0.637638 	2556s
# EarlyStopping counter: 1 out of 50
# Epoch: 132/600 	Training Loss: 0.641018 	2573s
# EarlyStopping counter: 2 out of 50
# Epoch: 133/600 	Training Loss: 0.637345 	2591s
# EarlyStopping counter: 3 out of 50
# Epoch: 134/600 	Training Loss: 0.640770 	2608s
# EarlyStopping counter: 4 out of 50
# Epoch: 135/600 	Training Loss: 0.635267 	2626s
# EarlyStopping counter: 5 out of 50
# Epoch: 136/600 	Training Loss: 0.636524 	2643s
# EarlyStopping counter: 6 out of 50
# Epoch: 137/600 	Training Loss: 0.640181 	2661s
# EarlyStopping counter: 7 out of 50
# Epoch: 138/600 	Training Loss: 0.634625 	2678s
# EarlyStopping counter: 8 out of 50
# Epoch: 139/600 	Training Loss: 0.637525 	2696s
# EarlyStopping counter: 9 out of 50
# Epoch: 140/600 	Training Loss: 0.634781 	2713s
# Epoch: 141/600 	Training Loss: 0.635764 	2731s
# EarlyStopping counter: 1 out of 50
# Epoch: 142/600 	Training Loss: 0.636031 	2748s
# Epoch: 143/600 	Training Loss: 0.637966 	2765s
# EarlyStopping counter: 1 out of 50
# Epoch: 144/600 	Training Loss: 0.634752 	2783s
# Epoch: 145/600 	Training Loss: 0.629785 	2800s
# EarlyStopping counter: 1 out of 50
# Epoch: 146/600 	Training Loss: 0.629346 	2818s
# EarlyStopping counter: 2 out of 50
# Epoch: 147/600 	Training Loss: 0.641228 	2835s
# EarlyStopping counter: 3 out of 50
# Epoch: 148/600 	Training Loss: 0.633508 	2853s
# EarlyStopping counter: 4 out of 50
# Epoch: 149/600 	Training Loss: 0.632162 	2870s
# EarlyStopping counter: 5 out of 50
# Epoch: 150/600 	Training Loss: 0.627521 	2887s
# EarlyStopping counter: 6 out of 50
# Epoch: 151/600 	Training Loss: 0.628450 	2905s
# EarlyStopping counter: 7 out of 50
# Epoch: 152/600 	Training Loss: 0.632309 	2922s
# EarlyStopping counter: 8 out of 50
# Epoch: 153/600 	Training Loss: 0.628051 	2940s
# EarlyStopping counter: 9 out of 50
# Epoch: 154/600 	Training Loss: 0.627582 	2957s
# EarlyStopping counter: 10 out of 50
# Epoch: 155/600 	Training Loss: 0.629761 	2975s
# Epoch: 156/600 	Training Loss: 0.625405 	2993s
# EarlyStopping counter: 1 out of 50
# Epoch: 157/600 	Training Loss: 0.631226 	3010s
# EarlyStopping counter: 2 out of 50
# Epoch: 158/600 	Training Loss: 0.625916 	3028s
# EarlyStopping counter: 3 out of 50
# Epoch: 159/600 	Training Loss: 0.629436 	3045s
# EarlyStopping counter: 4 out of 50
# Epoch: 160/600 	Training Loss: 0.624231 	3063s
# EarlyStopping counter: 5 out of 50
# Epoch: 161/600 	Training Loss: 0.626867 	3080s
# EarlyStopping counter: 6 out of 50
# Epoch: 162/600 	Training Loss: 0.627257 	3098s
# EarlyStopping counter: 7 out of 50
# Epoch: 163/600 	Training Loss: 0.625003 	3115s
# Epoch: 164/600 	Training Loss: 0.625178 	3133s
# EarlyStopping counter: 1 out of 50
# Epoch: 165/600 	Training Loss: 0.622092 	3150s
# EarlyStopping counter: 2 out of 50
# Epoch: 166/600 	Training Loss: 0.624498 	3168s
# EarlyStopping counter: 3 out of 50
# Epoch: 167/600 	Training Loss: 0.626534 	3185s
# Epoch: 168/600 	Training Loss: 0.625922 	3203s
# EarlyStopping counter: 1 out of 50
# Epoch: 169/600 	Training Loss: 0.623491 	3220s
# EarlyStopping counter: 2 out of 50
# Epoch: 170/600 	Training Loss: 0.620143 	3238s
# EarlyStopping counter: 3 out of 50
# Epoch: 171/600 	Training Loss: 0.623228 	3256s
# EarlyStopping counter: 4 out of 50
# Epoch: 172/600 	Training Loss: 0.619159 	3274s
# Epoch: 173/600 	Training Loss: 0.616874 	3291s
# EarlyStopping counter: 1 out of 50
# Epoch: 174/600 	Training Loss: 0.622409 	3309s
# Epoch: 175/600 	Training Loss: 0.621726 	3327s
# EarlyStopping counter: 1 out of 50
# Epoch: 176/600 	Training Loss: 0.617982 	3344s
# EarlyStopping counter: 2 out of 50
# Epoch: 177/600 	Training Loss: 0.620215 	3362s
# EarlyStopping counter: 3 out of 50
# Epoch: 178/600 	Training Loss: 0.623758 	3379s
# EarlyStopping counter: 4 out of 50
# Epoch: 179/600 	Training Loss: 0.618489 	3397s
# EarlyStopping counter: 5 out of 50
# Epoch: 180/600 	Training Loss: 0.613138 	3414s
# Epoch: 181/600 	Training Loss: 0.618843 	3432s
# EarlyStopping counter: 1 out of 50
# Epoch: 182/600 	Training Loss: 0.617744 	3449s
# EarlyStopping counter: 2 out of 50
# Epoch: 183/600 	Training Loss: 0.617001 	3466s
# EarlyStopping counter: 3 out of 50
# Epoch: 184/600 	Training Loss: 0.611950 	3484s
# EarlyStopping counter: 4 out of 50
# Epoch: 185/600 	Training Loss: 0.620038 	3501s
# EarlyStopping counter: 5 out of 50
# Epoch: 186/600 	Training Loss: 0.616676 	3519s
# EarlyStopping counter: 6 out of 50
# Epoch: 187/600 	Training Loss: 0.612750 	3536s
# EarlyStopping counter: 7 out of 50
# Epoch: 188/600 	Training Loss: 0.613955 	3554s
# EarlyStopping counter: 8 out of 50
# Epoch: 189/600 	Training Loss: 0.613716 	3571s
# EarlyStopping counter: 9 out of 50
# Epoch: 190/600 	Training Loss: 0.619898 	3589s
# EarlyStopping counter: 10 out of 50
# Epoch: 191/600 	Training Loss: 0.617524 	3606s
# EarlyStopping counter: 11 out of 50
# Epoch: 192/600 	Training Loss: 0.610408 	3624s
# Epoch: 193/600 	Training Loss: 0.615331 	3641s
# EarlyStopping counter: 1 out of 50
# Epoch: 194/600 	Training Loss: 0.613730 	3659s
# EarlyStopping counter: 2 out of 50
# Epoch: 195/600 	Training Loss: 0.611065 	3676s
# EarlyStopping counter: 3 out of 50
# Epoch: 196/600 	Training Loss: 0.610308 	3693s
# EarlyStopping counter: 4 out of 50
# Epoch: 197/600 	Training Loss: 0.610434 	3711s
# EarlyStopping counter: 5 out of 50
# Epoch: 198/600 	Training Loss: 0.609140 	3728s
# Epoch: 199/600 	Training Loss: 0.611640 	3746s
# EarlyStopping counter: 1 out of 50
# Epoch: 200/600 	Training Loss: 0.612051 	3763s
# Epoch: 201/600 	Training Loss: 0.607602 	3781s
# EarlyStopping counter: 1 out of 50
# Epoch: 202/600 	Training Loss: 0.612375 	3798s
# EarlyStopping counter: 2 out of 50
# Epoch: 203/600 	Training Loss: 0.612972 	3816s
# EarlyStopping counter: 3 out of 50
# Epoch: 204/600 	Training Loss: 0.606621 	3833s
# EarlyStopping counter: 4 out of 50
# Epoch: 205/600 	Training Loss: 0.611584 	3851s
# EarlyStopping counter: 5 out of 50
# Epoch: 206/600 	Training Loss: 0.605126 	3868s
# Epoch: 207/600 	Training Loss: 0.604357 	3886s
# EarlyStopping counter: 1 out of 50
# Epoch: 208/600 	Training Loss: 0.608187 	3903s
# EarlyStopping counter: 2 out of 50
# Epoch: 209/600 	Training Loss: 0.616377 	3921s
# EarlyStopping counter: 3 out of 50
# Epoch: 210/600 	Training Loss: 0.609507 	3938s
# EarlyStopping counter: 4 out of 50
# Epoch: 211/600 	Training Loss: 0.609280 	3956s
# EarlyStopping counter: 5 out of 50
# Epoch: 212/600 	Training Loss: 0.608938 	3973s
# EarlyStopping counter: 6 out of 50
# Epoch: 213/600 	Training Loss: 0.605396 	3991s
# EarlyStopping counter: 7 out of 50
# Epoch: 214/600 	Training Loss: 0.603796 	4008s
# EarlyStopping counter: 8 out of 50
# Epoch: 215/600 	Training Loss: 0.606591 	4026s
# EarlyStopping counter: 9 out of 50
# Epoch: 216/600 	Training Loss: 0.600778 	4043s
# EarlyStopping counter: 10 out of 50
# Epoch: 217/600 	Training Loss: 0.605253 	4061s
# EarlyStopping counter: 11 out of 50
# Epoch: 218/600 	Training Loss: 0.604880 	4143s
# EarlyStopping counter: 12 out of 50
# Epoch: 219/600 	Training Loss: 0.603821 	4239s
# EarlyStopping counter: 13 out of 50
# Epoch: 220/600 	Training Loss: 0.612612 	4257s
# EarlyStopping counter: 14 out of 50
# Epoch: 221/600 	Training Loss: 0.603023 	4274s
# Epoch: 222/600 	Training Loss: 0.600828 	4291s
# EarlyStopping counter: 1 out of 50
# Epoch: 223/600 	Training Loss: 0.606384 	4309s
# EarlyStopping counter: 2 out of 50
# Epoch: 224/600 	Training Loss: 0.600213 	4326s
# EarlyStopping counter: 3 out of 50
# Epoch: 225/600 	Training Loss: 0.599097 	4344s
# EarlyStopping counter: 4 out of 50
# Epoch: 226/600 	Training Loss: 0.602123 	4361s
# EarlyStopping counter: 5 out of 50
# Epoch: 227/600 	Training Loss: 0.604292 	4379s
# EarlyStopping counter: 6 out of 50
# Epoch: 228/600 	Training Loss: 0.605758 	4396s
# EarlyStopping counter: 7 out of 50
# Epoch: 229/600 	Training Loss: 0.604681 	4414s
# Epoch: 230/600 	Training Loss: 0.606559 	4431s
# EarlyStopping counter: 1 out of 50
# Epoch: 231/600 	Training Loss: 0.604557 	4449s
# EarlyStopping counter: 2 out of 50
# Epoch: 232/600 	Training Loss: 0.601486 	4466s
# EarlyStopping counter: 3 out of 50
# Epoch: 233/600 	Training Loss: 0.609895 	4484s
# EarlyStopping counter: 4 out of 50
# Epoch: 234/600 	Training Loss: 0.598100 	4501s
# EarlyStopping counter: 5 out of 50
# Epoch: 235/600 	Training Loss: 0.600038 	4519s
# EarlyStopping counter: 6 out of 50
# Epoch: 236/600 	Training Loss: 0.593722 	4536s
# EarlyStopping counter: 7 out of 50
# Epoch: 237/600 	Training Loss: 0.600292 	4554s
# EarlyStopping counter: 8 out of 50
# Epoch: 238/600 	Training Loss: 0.600722 	4571s
# EarlyStopping counter: 9 out of 50
# Epoch: 239/600 	Training Loss: 0.598098 	4589s
# EarlyStopping counter: 10 out of 50
# Epoch: 240/600 	Training Loss: 0.598001 	4607s
# Epoch: 241/600 	Training Loss: 0.598033 	4625s
# EarlyStopping counter: 1 out of 50
# Epoch: 242/600 	Training Loss: 0.597062 	4643s
# EarlyStopping counter: 2 out of 50
# Epoch: 243/600 	Training Loss: 0.606086 	4660s
# EarlyStopping counter: 3 out of 50
# Epoch: 244/600 	Training Loss: 0.597699 	4678s
# EarlyStopping counter: 4 out of 50
# Epoch: 245/600 	Training Loss: 0.597224 	4695s
# EarlyStopping counter: 5 out of 50
# Epoch: 246/600 	Training Loss: 0.595939 	4713s
# EarlyStopping counter: 6 out of 50
# Epoch: 247/600 	Training Loss: 0.596064 	4730s
# EarlyStopping counter: 7 out of 50
# Epoch: 248/600 	Training Loss: 0.600064 	4748s
# EarlyStopping counter: 8 out of 50
# Epoch: 249/600 	Training Loss: 0.601975 	4765s
# EarlyStopping counter: 9 out of 50
# Epoch: 250/600 	Training Loss: 0.593084 	4783s
# EarlyStopping counter: 10 out of 50
# Epoch: 251/600 	Training Loss: 0.597993 	4800s
# EarlyStopping counter: 11 out of 50
# Epoch: 252/600 	Training Loss: 0.596477 	4818s
# EarlyStopping counter: 12 out of 50
# Epoch: 253/600 	Training Loss: 0.592261 	4835s
# EarlyStopping counter: 13 out of 50
# Epoch: 254/600 	Training Loss: 0.593911 	4853s
# EarlyStopping counter: 14 out of 50
# Epoch: 255/600 	Training Loss: 0.592853 	4870s
# EarlyStopping counter: 15 out of 50
# Epoch: 256/600 	Training Loss: 0.592627 	4887s
# EarlyStopping counter: 16 out of 50
# Epoch: 257/600 	Training Loss: 0.602595 	4905s
# EarlyStopping counter: 17 out of 50
# Epoch: 258/600 	Training Loss: 0.596836 	4922s
# EarlyStopping counter: 18 out of 50
# Epoch: 259/600 	Training Loss: 0.593816 	4940s
# EarlyStopping counter: 19 out of 50
# Epoch: 260/600 	Training Loss: 0.592930 	4957s
# Epoch: 261/600 	Training Loss: 0.595385 	4975s
# EarlyStopping counter: 1 out of 50
# Epoch: 262/600 	Training Loss: 0.597719 	4992s
# EarlyStopping counter: 2 out of 50
# Epoch: 263/600 	Training Loss: 0.596520 	5009s
# EarlyStopping counter: 3 out of 50
# Epoch: 264/600 	Training Loss: 0.597215 	5027s
# Epoch: 265/600 	Training Loss: 0.592243 	5044s
# Epoch: 266/600 	Training Loss: 0.589979 	5062s
# EarlyStopping counter: 1 out of 50
# Epoch: 267/600 	Training Loss: 0.592171 	5079s
# EarlyStopping counter: 2 out of 50
# Epoch: 268/600 	Training Loss: 0.591306 	5097s
# EarlyStopping counter: 3 out of 50
# Epoch: 269/600 	Training Loss: 0.587855 	5114s
# EarlyStopping counter: 4 out of 50
# Epoch: 270/600 	Training Loss: 0.590313 	5132s
# EarlyStopping counter: 5 out of 50
# Epoch: 271/600 	Training Loss: 0.589427 	5149s
# Epoch: 272/600 	Training Loss: 0.591491 	5167s
# EarlyStopping counter: 1 out of 50
# Epoch: 273/600 	Training Loss: 0.589283 	5184s
# Epoch: 274/600 	Training Loss: 0.589025 	5202s
# EarlyStopping counter: 1 out of 50
# Epoch: 275/600 	Training Loss: 0.589550 	5219s
# EarlyStopping counter: 2 out of 50
# Epoch: 276/600 	Training Loss: 0.590075 	5236s
# EarlyStopping counter: 3 out of 50
# Epoch: 277/600 	Training Loss: 0.589748 	5254s
# EarlyStopping counter: 4 out of 50
# Epoch: 278/600 	Training Loss: 0.595656 	5271s
# EarlyStopping counter: 5 out of 50
# Epoch: 279/600 	Training Loss: 0.592382 	5289s
# EarlyStopping counter: 6 out of 50
# Epoch: 280/600 	Training Loss: 0.591600 	5306s
# EarlyStopping counter: 7 out of 50
# Epoch: 281/600 	Training Loss: 0.588178 	5323s
# EarlyStopping counter: 8 out of 50
# Epoch: 282/600 	Training Loss: 0.592616 	5341s
# EarlyStopping counter: 9 out of 50
# Epoch: 283/600 	Training Loss: 0.589458 	5358s
# EarlyStopping counter: 10 out of 50
# Epoch: 284/600 	Training Loss: 0.589562 	5376s
# EarlyStopping counter: 11 out of 50
# Epoch: 285/600 	Training Loss: 0.589381 	5393s
# EarlyStopping counter: 12 out of 50
# Epoch: 286/600 	Training Loss: 0.583993 	5410s
# EarlyStopping counter: 13 out of 50
# Epoch: 287/600 	Training Loss: 0.585300 	5428s
# Epoch: 288/600 	Training Loss: 0.587910 	5445s
# EarlyStopping counter: 1 out of 50
# Epoch: 289/600 	Training Loss: 0.586772 	5463s
# EarlyStopping counter: 2 out of 50
# Epoch: 290/600 	Training Loss: 0.587604 	5480s
# EarlyStopping counter: 3 out of 50
# Epoch: 291/600 	Training Loss: 0.592835 	5498s
# EarlyStopping counter: 4 out of 50
# Epoch: 292/600 	Training Loss: 0.596430 	5515s
# EarlyStopping counter: 5 out of 50
# Epoch: 293/600 	Training Loss: 0.583172 	5532s
# EarlyStopping counter: 6 out of 50
# Epoch: 294/600 	Training Loss: 0.588759 	5550s
# Epoch: 295/600 	Training Loss: 0.590107 	5567s
# EarlyStopping counter: 1 out of 50
# Epoch: 296/600 	Training Loss: 0.584378 	5585s
# EarlyStopping counter: 2 out of 50
# Epoch: 297/600 	Training Loss: 0.582258 	5602s
# EarlyStopping counter: 3 out of 50
# Epoch: 298/600 	Training Loss: 0.585583 	5619s
# EarlyStopping counter: 4 out of 50
# Epoch: 299/600 	Training Loss: 0.585065 	5637s
# EarlyStopping counter: 5 out of 50
# Epoch: 300/600 	Training Loss: 0.581325 	5655s
# EarlyStopping counter: 6 out of 50
# Epoch: 301/600 	Training Loss: 0.589163 	5672s
# Epoch: 302/600 	Training Loss: 0.588608 	5690s
# EarlyStopping counter: 1 out of 50
# Epoch: 303/600 	Training Loss: 0.583848 	5707s
# EarlyStopping counter: 2 out of 50
# Epoch: 304/600 	Training Loss: 0.586802 	5725s
# EarlyStopping counter: 3 out of 50
# Epoch: 305/600 	Training Loss: 0.587020 	5742s
# EarlyStopping counter: 4 out of 50
# Epoch: 306/600 	Training Loss: 0.581924 	5760s
# EarlyStopping counter: 5 out of 50
# Epoch: 307/600 	Training Loss: 0.583798 	5777s
# EarlyStopping counter: 6 out of 50
# Epoch: 308/600 	Training Loss: 0.586701 	5795s
# EarlyStopping counter: 7 out of 50
# Epoch: 309/600 	Training Loss: 0.590850 	5812s
# EarlyStopping counter: 8 out of 50
# Epoch: 310/600 	Training Loss: 0.586607 	5829s
# EarlyStopping counter: 9 out of 50
# Epoch: 311/600 	Training Loss: 0.580765 	5847s
# EarlyStopping counter: 10 out of 50
# Epoch: 312/600 	Training Loss: 0.585030 	5864s
# Epoch: 313/600 	Training Loss: 0.588476 	5881s
# EarlyStopping counter: 1 out of 50
# Epoch: 314/600 	Training Loss: 0.583395 	5899s
# EarlyStopping counter: 2 out of 50
# Epoch: 315/600 	Training Loss: 0.584803 	5917s
# EarlyStopping counter: 3 out of 50
# Epoch: 316/600 	Training Loss: 0.582399 	5934s
# EarlyStopping counter: 4 out of 50
# Epoch: 317/600 	Training Loss: 0.586999 	5952s
# Epoch: 318/600 	Training Loss: 0.587726 	5969s
# EarlyStopping counter: 1 out of 50
# Epoch: 319/600 	Training Loss: 0.582791 	5986s
# EarlyStopping counter: 2 out of 50
# Epoch: 320/600 	Training Loss: 0.591994 	6004s
# EarlyStopping counter: 3 out of 50
# Epoch: 321/600 	Training Loss: 0.579022 	6021s
# EarlyStopping counter: 4 out of 50
# Epoch: 322/600 	Training Loss: 0.584522 	6039s
# EarlyStopping counter: 5 out of 50
# Epoch: 323/600 	Training Loss: 0.583074 	6056s
# EarlyStopping counter: 6 out of 50
# Epoch: 324/600 	Training Loss: 0.579515 	6074s
# EarlyStopping counter: 7 out of 50
# Epoch: 325/600 	Training Loss: 0.583298 	6091s
# EarlyStopping counter: 8 out of 50
# Epoch: 326/600 	Training Loss: 0.583718 	6108s
# EarlyStopping counter: 9 out of 50
# Epoch: 327/600 	Training Loss: 0.583320 	6126s
# EarlyStopping counter: 10 out of 50
# Epoch: 328/600 	Training Loss: 0.580436 	6143s
# EarlyStopping counter: 11 out of 50
# Epoch: 329/600 	Training Loss: 0.579893 	6161s
# EarlyStopping counter: 12 out of 50
# Epoch: 330/600 	Training Loss: 0.579179 	6178s
# EarlyStopping counter: 13 out of 50
# Epoch: 331/600 	Training Loss: 0.579136 	6196s
# EarlyStopping counter: 14 out of 50
# Epoch: 332/600 	Training Loss: 0.577013 	6213s
# EarlyStopping counter: 15 out of 50
# Epoch: 333/600 	Training Loss: 0.581619 	6230s
# EarlyStopping counter: 16 out of 50
# Epoch: 334/600 	Training Loss: 0.579784 	6248s
# EarlyStopping counter: 17 out of 50
# Epoch: 335/600 	Training Loss: 0.589302 	6265s
# EarlyStopping counter: 18 out of 50
# Epoch: 336/600 	Training Loss: 0.575108 	6283s
# EarlyStopping counter: 19 out of 50
# Epoch: 337/600 	Training Loss: 0.579159 	6300s
# EarlyStopping counter: 20 out of 50
# Epoch: 338/600 	Training Loss: 0.576850 	6318s
# EarlyStopping counter: 21 out of 50
# Epoch: 339/600 	Training Loss: 0.583380 	6335s
# EarlyStopping counter: 22 out of 50
# Epoch: 340/600 	Training Loss: 0.573255 	6353s
# EarlyStopping counter: 23 out of 50
# Epoch: 341/600 	Training Loss: 0.577812 	6371s
# EarlyStopping counter: 24 out of 50
# Epoch: 342/600 	Training Loss: 0.583045 	6388s
# EarlyStopping counter: 25 out of 50
# Epoch: 343/600 	Training Loss: 0.577930 	6406s
# EarlyStopping counter: 26 out of 50
# Epoch: 344/600 	Training Loss: 0.573987 	6423s
# Epoch: 345/600 	Training Loss: 0.576432 	6441s
# EarlyStopping counter: 1 out of 50
# Epoch: 346/600 	Training Loss: 0.577714 	6458s
# EarlyStopping counter: 2 out of 50
# Epoch: 347/600 	Training Loss: 0.575133 	6476s
# EarlyStopping counter: 3 out of 50
# Epoch: 348/600 	Training Loss: 0.574640 	6493s
# Epoch: 349/600 	Training Loss: 0.574210 	6511s
# EarlyStopping counter: 1 out of 50
# Epoch: 350/600 	Training Loss: 0.573323 	6528s
# Epoch: 351/600 	Training Loss: 0.587779 	6546s
# EarlyStopping counter: 1 out of 50
# Epoch: 352/600 	Training Loss: 0.583245 	6564s
# EarlyStopping counter: 2 out of 50
# Epoch: 353/600 	Training Loss: 0.575258 	6581s
# EarlyStopping counter: 3 out of 50
# Epoch: 354/600 	Training Loss: 0.572698 	6599s
# Epoch: 355/600 	Training Loss: 0.580410 	6616s
# EarlyStopping counter: 1 out of 50
# Epoch: 356/600 	Training Loss: 0.573678 	6634s
# EarlyStopping counter: 2 out of 50
# Epoch: 357/600 	Training Loss: 0.573827 	6651s
# EarlyStopping counter: 3 out of 50
# Epoch: 358/600 	Training Loss: 0.578244 	6669s
# EarlyStopping counter: 4 out of 50
# Epoch: 359/600 	Training Loss: 0.574452 	6686s
# EarlyStopping counter: 5 out of 50
# Epoch: 360/600 	Training Loss: 0.576655 	6704s
# EarlyStopping counter: 6 out of 50
# Epoch: 361/600 	Training Loss: 0.578508 	6721s
# EarlyStopping counter: 7 out of 50
# Epoch: 362/600 	Training Loss: 0.573805 	6739s
# EarlyStopping counter: 8 out of 50
# Epoch: 363/600 	Training Loss: 0.571562 	6756s
# EarlyStopping counter: 9 out of 50
# Epoch: 364/600 	Training Loss: 0.568881 	6774s
# EarlyStopping counter: 10 out of 50
# Epoch: 365/600 	Training Loss: 0.568927 	6791s
# EarlyStopping counter: 11 out of 50
# Epoch: 366/600 	Training Loss: 0.580959 	6809s
# EarlyStopping counter: 12 out of 50
# Epoch: 367/600 	Training Loss: 0.573571 	6826s
# EarlyStopping counter: 13 out of 50
# Epoch: 368/600 	Training Loss: 0.574214 	6844s
# EarlyStopping counter: 14 out of 50
# Epoch: 369/600 	Training Loss: 0.579552 	6862s
# EarlyStopping counter: 15 out of 50
# Epoch: 370/600 	Training Loss: 0.571473 	6879s
# EarlyStopping counter: 16 out of 50
# Epoch: 371/600 	Training Loss: 0.579232 	6897s
# EarlyStopping counter: 17 out of 50
# Epoch: 372/600 	Training Loss: 0.571523 	6914s
# EarlyStopping counter: 18 out of 50
# Epoch: 373/600 	Training Loss: 0.572876 	6932s
# EarlyStopping counter: 19 out of 50
# Epoch: 374/600 	Training Loss: 0.569249 	6950s
# EarlyStopping counter: 20 out of 50
# Epoch: 375/600 	Training Loss: 0.573646 	6967s
# EarlyStopping counter: 21 out of 50
# Epoch: 376/600 	Training Loss: 0.574834 	6985s
# EarlyStopping counter: 22 out of 50
# Epoch: 377/600 	Training Loss: 0.570396 	7002s
# EarlyStopping counter: 23 out of 50
# Epoch: 378/600 	Training Loss: 0.576615 	7020s
# EarlyStopping counter: 24 out of 50
# Epoch: 379/600 	Training Loss: 0.574633 	7037s
# EarlyStopping counter: 25 out of 50
# Epoch: 380/600 	Training Loss: 0.567364 	7055s
# Epoch: 381/600 	Training Loss: 0.571079 	7072s
# EarlyStopping counter: 1 out of 50
# Epoch: 382/600 	Training Loss: 0.574218 	7090s
# Epoch: 383/600 	Training Loss: 0.574193 	7107s
# EarlyStopping counter: 1 out of 50
# Epoch: 384/600 	Training Loss: 0.571071 	7125s
# EarlyStopping counter: 2 out of 50
# Epoch: 385/600 	Training Loss: 0.571216 	7142s
# EarlyStopping counter: 3 out of 50
# Epoch: 386/600 	Training Loss: 0.567399 	7160s
# EarlyStopping counter: 4 out of 50
# Epoch: 387/600 	Training Loss: 0.569262 	7178s
# EarlyStopping counter: 5 out of 50
# Epoch: 388/600 	Training Loss: 0.566497 	7195s
# EarlyStopping counter: 6 out of 50
# Epoch: 389/600 	Training Loss: 0.568591 	7213s
# EarlyStopping counter: 7 out of 50
# Epoch: 390/600 	Training Loss: 0.569421 	7230s
# EarlyStopping counter: 8 out of 50
# Epoch: 391/600 	Training Loss: 0.566534 	7248s
# EarlyStopping counter: 9 out of 50
# Epoch: 392/600 	Training Loss: 0.568267 	7266s
# EarlyStopping counter: 10 out of 50
# Epoch: 393/600 	Training Loss: 0.568787 	7283s
# EarlyStopping counter: 11 out of 50
# Epoch: 394/600 	Training Loss: 0.569984 	7301s
# EarlyStopping counter: 12 out of 50
# Epoch: 395/600 	Training Loss: 0.568686 	7318s
# EarlyStopping counter: 13 out of 50
# Epoch: 396/600 	Training Loss: 0.572352 	7336s
# EarlyStopping counter: 14 out of 50
# Epoch: 397/600 	Training Loss: 0.570945 	7353s
# EarlyStopping counter: 15 out of 50
# Epoch: 398/600 	Training Loss: 0.566665 	7371s
# EarlyStopping counter: 16 out of 50
# Epoch: 399/600 	Training Loss: 0.567840 	7388s
# EarlyStopping counter: 17 out of 50
# Epoch: 400/600 	Training Loss: 0.566910 	7406s
# EarlyStopping counter: 18 out of 50
# Epoch: 401/600 	Training Loss: 0.572404 	7424s
# EarlyStopping counter: 19 out of 50
# Epoch: 402/600 	Training Loss: 0.573195 	7441s
# EarlyStopping counter: 20 out of 50
# Epoch: 403/600 	Training Loss: 0.569286 	7459s
# EarlyStopping counter: 21 out of 50
# Epoch: 404/600 	Training Loss: 0.567231 	7477s
# EarlyStopping counter: 22 out of 50
# Epoch: 405/600 	Training Loss: 0.570336 	7494s
# EarlyStopping counter: 23 out of 50
# Epoch: 406/600 	Training Loss: 0.566792 	7512s
# EarlyStopping counter: 24 out of 50
# Epoch: 407/600 	Training Loss: 0.570778 	7529s
# EarlyStopping counter: 25 out of 50
# Epoch: 408/600 	Training Loss: 0.564394 	7547s
# EarlyStopping counter: 26 out of 50
# Epoch: 409/600 	Training Loss: 0.567342 	7564s
# EarlyStopping counter: 27 out of 50
# Epoch: 410/600 	Training Loss: 0.567599 	7582s
# EarlyStopping counter: 28 out of 50
# Epoch: 411/600 	Training Loss: 0.564310 	7599s
# EarlyStopping counter: 29 out of 50
# Epoch: 412/600 	Training Loss: 0.567559 	7617s
# EarlyStopping counter: 30 out of 50
# Epoch: 413/600 	Training Loss: 0.566537 	7634s
# EarlyStopping counter: 31 out of 50
# Epoch: 414/600 	Training Loss: 0.564232 	7652s
# EarlyStopping counter: 32 out of 50
# Epoch: 415/600 	Training Loss: 0.563682 	7669s
# Epoch: 416/600 	Training Loss: 0.576810 	7687s
# EarlyStopping counter: 1 out of 50
# Epoch: 417/600 	Training Loss: 0.563388 	7704s
# EarlyStopping counter: 2 out of 50
# Epoch: 418/600 	Training Loss: 0.566398 	7722s
# EarlyStopping counter: 3 out of 50
# Epoch: 419/600 	Training Loss: 0.569174 	7739s
# Epoch: 420/600 	Training Loss: 0.564210 	7757s
# EarlyStopping counter: 1 out of 50
# Epoch: 421/600 	Training Loss: 0.571080 	7774s
# EarlyStopping counter: 2 out of 50
# Epoch: 422/600 	Training Loss: 0.568233 	7792s
# EarlyStopping counter: 3 out of 50
# Epoch: 423/600 	Training Loss: 0.568732 	7809s
# EarlyStopping counter: 4 out of 50
# Epoch: 424/600 	Training Loss: 0.564962 	7827s
# EarlyStopping counter: 5 out of 50
# Epoch: 425/600 	Training Loss: 0.568438 	7845s
# EarlyStopping counter: 6 out of 50
# Epoch: 426/600 	Training Loss: 0.567620 	7862s
# EarlyStopping counter: 7 out of 50
# Epoch: 427/600 	Training Loss: 0.566835 	7880s
# EarlyStopping counter: 8 out of 50
# Epoch: 428/600 	Training Loss: 0.565866 	7897s
# EarlyStopping counter: 9 out of 50
# Epoch: 429/600 	Training Loss: 0.565120 	7915s
# EarlyStopping counter: 10 out of 50
# Epoch: 430/600 	Training Loss: 0.566939 	7932s
# EarlyStopping counter: 11 out of 50
# Epoch: 431/600 	Training Loss: 0.562319 	7950s
# EarlyStopping counter: 12 out of 50
# Epoch: 432/600 	Training Loss: 0.560295 	7967s
# EarlyStopping counter: 13 out of 50
# Epoch: 433/600 	Training Loss: 0.567866 	7985s
# EarlyStopping counter: 14 out of 50
# Epoch: 434/600 	Training Loss: 0.563223 	8003s
# Epoch: 435/600 	Training Loss: 0.566479 	8020s
# EarlyStopping counter: 1 out of 50
# Epoch: 436/600 	Training Loss: 0.562603 	8038s
# Epoch: 437/600 	Training Loss: 0.570676 	8055s
# EarlyStopping counter: 1 out of 50
# Epoch: 438/600 	Training Loss: 0.564320 	8073s
# EarlyStopping counter: 2 out of 50
# Epoch: 439/600 	Training Loss: 0.561192 	8090s
# EarlyStopping counter: 3 out of 50
# Epoch: 440/600 	Training Loss: 0.568541 	8108s
# EarlyStopping counter: 4 out of 50
# Epoch: 441/600 	Training Loss: 0.565864 	8126s
# EarlyStopping counter: 5 out of 50
# Epoch: 442/600 	Training Loss: 0.562044 	8143s
# EarlyStopping counter: 6 out of 50
# Epoch: 443/600 	Training Loss: 0.566084 	8161s
# EarlyStopping counter: 7 out of 50
# Epoch: 444/600 	Training Loss: 0.562055 	8178s
# EarlyStopping counter: 8 out of 50
# Epoch: 445/600 	Training Loss: 0.560813 	8196s
# EarlyStopping counter: 9 out of 50
# Epoch: 446/600 	Training Loss: 0.559745 	8214s
# Epoch: 447/600 	Training Loss: 0.563481 	8231s
# EarlyStopping counter: 1 out of 50
# Epoch: 448/600 	Training Loss: 0.565568 	8249s
# EarlyStopping counter: 2 out of 50
# Epoch: 449/600 	Training Loss: 0.563438 	8266s
# EarlyStopping counter: 3 out of 50
# Epoch: 450/600 	Training Loss: 0.559415 	8284s
# EarlyStopping counter: 4 out of 50
# Epoch: 451/600 	Training Loss: 0.560412 	8302s
# EarlyStopping counter: 5 out of 50
# Epoch: 452/600 	Training Loss: 0.563125 	8319s
# EarlyStopping counter: 6 out of 50
# Epoch: 453/600 	Training Loss: 0.563438 	8337s
# EarlyStopping counter: 7 out of 50
# Epoch: 454/600 	Training Loss: 0.566646 	8354s
# EarlyStopping counter: 8 out of 50
# Epoch: 455/600 	Training Loss: 0.566065 	8372s
# EarlyStopping counter: 9 out of 50
# Epoch: 456/600 	Training Loss: 0.565737 	8389s
# EarlyStopping counter: 10 out of 50
# Epoch: 457/600 	Training Loss: 0.566584 	8407s
# EarlyStopping counter: 11 out of 50
# Epoch: 458/600 	Training Loss: 0.564140 	8425s
# Epoch: 459/600 	Training Loss: 0.562063 	8442s
# EarlyStopping counter: 1 out of 50
# Epoch: 460/600 	Training Loss: 0.562479 	8460s
# Epoch: 461/600 	Training Loss: 0.560783 	8478s
# EarlyStopping counter: 1 out of 50
# Epoch: 462/600 	Training Loss: 0.557468 	8495s
# Epoch: 463/600 	Training Loss: 0.564449 	8513s
# EarlyStopping counter: 1 out of 50
# Epoch: 464/600 	Training Loss: 0.560394 	8530s
# EarlyStopping counter: 2 out of 50
# Epoch: 465/600 	Training Loss: 0.565969 	8548s
# EarlyStopping counter: 3 out of 50
# Epoch: 466/600 	Training Loss: 0.560022 	8565s
# EarlyStopping counter: 4 out of 50
# Epoch: 467/600 	Training Loss: 0.558666 	8583s
# EarlyStopping counter: 5 out of 50
# Epoch: 468/600 	Training Loss: 0.562121 	8600s
# EarlyStopping counter: 6 out of 50
# Epoch: 469/600 	Training Loss: 0.559550 	8618s
# EarlyStopping counter: 7 out of 50
# Epoch: 470/600 	Training Loss: 0.553109 	8635s
# EarlyStopping counter: 8 out of 50
# Epoch: 471/600 	Training Loss: 0.560234 	8653s
# EarlyStopping counter: 9 out of 50
# Epoch: 472/600 	Training Loss: 0.556300 	8670s
# EarlyStopping counter: 10 out of 50
# Epoch: 473/600 	Training Loss: 0.561299 	8688s
# EarlyStopping counter: 11 out of 50
# Epoch: 474/600 	Training Loss: 0.560126 	8705s
# EarlyStopping counter: 12 out of 50
# Epoch: 475/600 	Training Loss: 0.561805 	8722s
# EarlyStopping counter: 13 out of 50
# Epoch: 476/600 	Training Loss: 0.562466 	8740s
# EarlyStopping counter: 14 out of 50
# Epoch: 477/600 	Training Loss: 0.556024 	8757s
# EarlyStopping counter: 15 out of 50
# Epoch: 478/600 	Training Loss: 0.565950 	8775s
# EarlyStopping counter: 16 out of 50
# Epoch: 479/600 	Training Loss: 0.557262 	8793s
# EarlyStopping counter: 17 out of 50
# Epoch: 480/600 	Training Loss: 0.560536 	8810s
# EarlyStopping counter: 18 out of 50
# Epoch: 481/600 	Training Loss: 0.560273 	8828s
# Epoch: 482/600 	Training Loss: 0.564251 	8845s
# EarlyStopping counter: 1 out of 50
# Epoch: 483/600 	Training Loss: 0.557880 	8862s
# EarlyStopping counter: 2 out of 50
# Epoch: 484/600 	Training Loss: 0.558554 	8880s
# EarlyStopping counter: 3 out of 50
# Epoch: 485/600 	Training Loss: 0.556043 	8897s
# EarlyStopping counter: 4 out of 50
# Epoch: 486/600 	Training Loss: 0.556673 	8915s
# Epoch: 487/600 	Training Loss: 0.554166 	8932s
# EarlyStopping counter: 1 out of 50
# Epoch: 488/600 	Training Loss: 0.561274 	8950s
# Epoch: 489/600 	Training Loss: 0.554717 	8968s
# EarlyStopping counter: 1 out of 50
# Epoch: 490/600 	Training Loss: 0.557668 	8985s
# EarlyStopping counter: 2 out of 50
# Epoch: 491/600 	Training Loss: 0.557135 	9003s
# EarlyStopping counter: 3 out of 50
# Epoch: 492/600 	Training Loss: 0.558073 	9020s
# EarlyStopping counter: 4 out of 50
# Epoch: 493/600 	Training Loss: 0.557786 	9037s
# EarlyStopping counter: 5 out of 50
# Epoch: 494/600 	Training Loss: 0.558963 	9055s
# EarlyStopping counter: 6 out of 50
# Epoch: 495/600 	Training Loss: 0.555543 	9072s
# EarlyStopping counter: 7 out of 50
# Epoch: 496/600 	Training Loss: 0.563583 	9090s
# EarlyStopping counter: 8 out of 50
# Epoch: 497/600 	Training Loss: 0.560445 	9107s
# EarlyStopping counter: 9 out of 50
# Epoch: 498/600 	Training Loss: 0.556978 	9125s
# EarlyStopping counter: 10 out of 50
# Epoch: 499/600 	Training Loss: 0.554283 	9142s
# Epoch: 500/600 	Training Loss: 0.562358 	9159s
# EarlyStopping counter: 1 out of 50
# Epoch: 501/600 	Training Loss: 0.555206 	9177s
# EarlyStopping counter: 2 out of 50
# Epoch: 502/600 	Training Loss: 0.557531 	9194s
# EarlyStopping counter: 3 out of 50
# Epoch: 503/600 	Training Loss: 0.559318 	9212s
# EarlyStopping counter: 4 out of 50
# Epoch: 504/600 	Training Loss: 0.561311 	9229s
# EarlyStopping counter: 5 out of 50
# Epoch: 505/600 	Training Loss: 0.553111 	9246s
# EarlyStopping counter: 6 out of 50
# Epoch: 506/600 	Training Loss: 0.555934 	9264s
# EarlyStopping counter: 7 out of 50
# Epoch: 507/600 	Training Loss: 0.562948 	9281s
# EarlyStopping counter: 8 out of 50
# Epoch: 508/600 	Training Loss: 0.556227 	9299s
# EarlyStopping counter: 9 out of 50
# Epoch: 509/600 	Training Loss: 0.560661 	9316s
# EarlyStopping counter: 10 out of 50
# Epoch: 510/600 	Training Loss: 0.561479 	9334s
# EarlyStopping counter: 11 out of 50
# Epoch: 511/600 	Training Loss: 0.555213 	9351s
# EarlyStopping counter: 12 out of 50
# Epoch: 512/600 	Training Loss: 0.560639 	9369s
# EarlyStopping counter: 13 out of 50
# Epoch: 513/600 	Training Loss: 0.560003 	9386s
# EarlyStopping counter: 14 out of 50
# Epoch: 514/600 	Training Loss: 0.557854 	9404s
# EarlyStopping counter: 15 out of 50
# Epoch: 515/600 	Training Loss: 0.554453 	9421s
# EarlyStopping counter: 16 out of 50
# Epoch: 516/600 	Training Loss: 0.554906 	9438s
# EarlyStopping counter: 17 out of 50
# Epoch: 517/600 	Training Loss: 0.562567 	9456s
# EarlyStopping counter: 18 out of 50
# Epoch: 518/600 	Training Loss: 0.560650 	9473s
# EarlyStopping counter: 19 out of 50
# Epoch: 519/600 	Training Loss: 0.555586 	9490s
# EarlyStopping counter: 20 out of 50
# Epoch: 520/600 	Training Loss: 0.552814 	9508s
# EarlyStopping counter: 21 out of 50
# Epoch: 521/600 	Training Loss: 0.557890 	9525s
# EarlyStopping counter: 22 out of 50
# Epoch: 522/600 	Training Loss: 0.551303 	9542s
# EarlyStopping counter: 23 out of 50
# Epoch: 523/600 	Training Loss: 0.553610 	9560s
# EarlyStopping counter: 24 out of 50
# Epoch: 524/600 	Training Loss: 0.554713 	9577s
# EarlyStopping counter: 25 out of 50
# Epoch: 525/600 	Training Loss: 0.557535 	9595s
# EarlyStopping counter: 26 out of 50
# Epoch: 526/600 	Training Loss: 0.550706 	9612s
# EarlyStopping counter: 27 out of 50
# Epoch: 527/600 	Training Loss: 0.557896 	9630s
# EarlyStopping counter: 28 out of 50
# Epoch: 528/600 	Training Loss: 0.550290 	9647s
# EarlyStopping counter: 29 out of 50
# Epoch: 529/600 	Training Loss: 0.553665 	9665s
# EarlyStopping counter: 30 out of 50
# Epoch: 530/600 	Training Loss: 0.557823 	9682s
# EarlyStopping counter: 31 out of 50
# Epoch: 531/600 	Training Loss: 0.550522 	9699s
# EarlyStopping counter: 32 out of 50
# Epoch: 532/600 	Training Loss: 0.551885 	9717s
# EarlyStopping counter: 33 out of 50
# Epoch: 533/600 	Training Loss: 0.555638 	9735s
# EarlyStopping counter: 34 out of 50
# Epoch: 534/600 	Training Loss: 0.557657 	9752s
# EarlyStopping counter: 35 out of 50
# Epoch: 535/600 	Training Loss: 0.552627 	9769s
# EarlyStopping counter: 36 out of 50
# Epoch: 536/600 	Training Loss: 0.558444 	9787s
# EarlyStopping counter: 37 out of 50
# Epoch: 537/600 	Training Loss: 0.561196 	9804s
# EarlyStopping counter: 38 out of 50
# Epoch: 538/600 	Training Loss: 0.551155 	9822s
# Epoch: 539/600 	Training Loss: 0.556064 	9839s
# EarlyStopping counter: 1 out of 50
# Epoch: 540/600 	Training Loss: 0.549372 	9857s
# EarlyStopping counter: 2 out of 50
# Epoch: 541/600 	Training Loss: 0.557099 	9874s
# EarlyStopping counter: 3 out of 50
# Epoch: 542/600 	Training Loss: 0.557177 	9892s
# EarlyStopping counter: 4 out of 50
# Epoch: 543/600 	Training Loss: 0.552809 	9909s
# EarlyStopping counter: 5 out of 50
# Epoch: 544/600 	Training Loss: 0.557299 	9927s
# EarlyStopping counter: 6 out of 50
# Epoch: 545/600 	Training Loss: 0.551172 	9944s
# EarlyStopping counter: 7 out of 50
# Epoch: 546/600 	Training Loss: 0.557537 	9962s
# EarlyStopping counter: 8 out of 50
# Epoch: 547/600 	Training Loss: 0.556128 	9979s
# EarlyStopping counter: 9 out of 50
# Epoch: 548/600 	Training Loss: 0.555549 	9997s
# EarlyStopping counter: 10 out of 50
# Epoch: 549/600 	Training Loss: 0.549434 	10014s
# EarlyStopping counter: 11 out of 50
# Epoch: 550/600 	Training Loss: 0.554350 	10031s
# EarlyStopping counter: 12 out of 50
# Epoch: 551/600 	Training Loss: 0.556350 	10049s
# EarlyStopping counter: 13 out of 50
# Epoch: 552/600 	Training Loss: 0.553217 	10066s
# EarlyStopping counter: 14 out of 50
# Epoch: 553/600 	Training Loss: 0.553266 	10083s
# EarlyStopping counter: 15 out of 50
# Epoch: 554/600 	Training Loss: 0.557003 	10101s
# EarlyStopping counter: 16 out of 50
# Epoch: 555/600 	Training Loss: 0.555469 	10118s
# EarlyStopping counter: 17 out of 50
# Epoch: 556/600 	Training Loss: 0.551768 	10136s
# EarlyStopping counter: 18 out of 50
# Epoch: 557/600 	Training Loss: 0.552084 	10153s
# EarlyStopping counter: 19 out of 50
# Epoch: 558/600 	Training Loss: 0.555590 	10171s
# EarlyStopping counter: 20 out of 50
# Epoch: 559/600 	Training Loss: 0.552248 	10188s
# EarlyStopping counter: 21 out of 50
# Epoch: 560/600 	Training Loss: 0.555197 	10206s
# EarlyStopping counter: 22 out of 50
# Epoch: 561/600 	Training Loss: 0.549143 	10223s
# Epoch: 562/600 	Training Loss: 0.552432 	10240s
# EarlyStopping counter: 1 out of 50
# Epoch: 563/600 	Training Loss: 0.552423 	10258s
# EarlyStopping counter: 2 out of 50
# Epoch: 564/600 	Training Loss: 0.552597 	10275s
# EarlyStopping counter: 3 out of 50
# Epoch: 565/600 	Training Loss: 0.549760 	10293s
# EarlyStopping counter: 4 out of 50
# Epoch: 566/600 	Training Loss: 0.551291 	10310s
# EarlyStopping counter: 5 out of 50
# Epoch: 567/600 	Training Loss: 0.549206 	10328s
# EarlyStopping counter: 6 out of 50
# Epoch: 568/600 	Training Loss: 0.552750 	10345s
# EarlyStopping counter: 7 out of 50
# Epoch: 569/600 	Training Loss: 0.546833 	10363s
# EarlyStopping counter: 8 out of 50
# Epoch: 570/600 	Training Loss: 0.549097 	10380s
# EarlyStopping counter: 9 out of 50
# Epoch: 571/600 	Training Loss: 0.549341 	10398s
# EarlyStopping counter: 10 out of 50
# Epoch: 572/600 	Training Loss: 0.548066 	10415s
# EarlyStopping counter: 11 out of 50
# Epoch: 573/600 	Training Loss: 0.548293 	10433s
# EarlyStopping counter: 12 out of 50
# Epoch: 574/600 	Training Loss: 0.558382 	10450s
# EarlyStopping counter: 13 out of 50
# Epoch: 575/600 	Training Loss: 0.551948 	10468s
# EarlyStopping counter: 14 out of 50
# Epoch: 576/600 	Training Loss: 0.545288 	10485s
# EarlyStopping counter: 15 out of 50
# Epoch: 577/600 	Training Loss: 0.557569 	10503s
# EarlyStopping counter: 16 out of 50
# Epoch: 578/600 	Training Loss: 0.546599 	10520s
# EarlyStopping counter: 17 out of 50
# Epoch: 579/600 	Training Loss: 0.548966 	10538s
# EarlyStopping counter: 18 out of 50
# Epoch: 580/600 	Training Loss: 0.546329 	10555s
# EarlyStopping counter: 19 out of 50
# Epoch: 581/600 	Training Loss: 0.551551 	10573s
# EarlyStopping counter: 20 out of 50
# Epoch: 582/600 	Training Loss: 0.548821 	10590s
# EarlyStopping counter: 21 out of 50
# Epoch: 583/600 	Training Loss: 0.546838 	10607s
# EarlyStopping counter: 22 out of 50
# Epoch: 584/600 	Training Loss: 0.548625 	10625s
# EarlyStopping counter: 23 out of 50
# Epoch: 585/600 	Training Loss: 0.549658 	10642s
# EarlyStopping counter: 24 out of 50
# Epoch: 586/600 	Training Loss: 0.545599 	10660s
# EarlyStopping counter: 25 out of 50
# Epoch: 587/600 	Training Loss: 0.545636 	10677s
# Epoch: 588/600 	Training Loss: 0.552722 	10695s
# EarlyStopping counter: 1 out of 50
# Epoch: 589/600 	Training Loss: 0.550032 	10713s
# EarlyStopping counter: 2 out of 50
# Epoch: 590/600 	Training Loss: 0.551660 	10730s
# EarlyStopping counter: 3 out of 50
# Epoch: 591/600 	Training Loss: 0.551503 	10748s
# EarlyStopping counter: 4 out of 50
# Epoch: 592/600 	Training Loss: 0.549446 	10765s
# EarlyStopping counter: 5 out of 50
# Epoch: 593/600 	Training Loss: 0.544754 	10783s
# EarlyStopping counter: 6 out of 50
# Epoch: 594/600 	Training Loss: 0.550310 	10800s
# EarlyStopping counter: 7 out of 50
# Epoch: 595/600 	Training Loss: 0.549285 	10818s
# EarlyStopping counter: 8 out of 50
# Epoch: 596/600 	Training Loss: 0.546608 	10835s
# EarlyStopping counter: 9 out of 50
# Epoch: 597/600 	Training Loss: 0.550194 	10852s
# EarlyStopping counter: 10 out of 50
# Epoch: 598/600 	Training Loss: 0.550063 	10870s
# EarlyStopping counter: 11 out of 50
# Epoch: 599/600 	Training Loss: 0.548114 	10887s
# Epoch: 600/600 	Training Loss: 0.548494 	10905s
# best_testloss:0.604	 epoch:598
# EarlyStopping counter: 1 out of 50

# %%
zoomin = 20
zoomout = 600
plotTraining(lossTrainArr, lossTestArr, LrCArr, bestLoss, zoomin, zoomout)

# %%
# create testdataset

damaged_img_path = 'testdataset/damaged_image' 

if lidar_mode == 'sparse':
    lidar_path = 'testdataset/lidar_tensor/sparse'
else:
    lidar_path = 'testdataset/lidar_tensor/dense'

label_path = 'testdataset/ori_image'

damaged_img_list = sorted(glob.glob(damaged_img_path + '/*'))
lidar_list = sorted(glob.glob(lidar_path + '/*'))
label_list = sorted(glob.glob(label_path + '/*'))

learning_rate = 1e-4
batch_size = 32

TestDataset = CreateDatasets(label_list, damaged_img_list, lidar_list)
new_testloader = DataLoader(dataset=TestDataset, batch_size=batch_size, shuffle=False, num_workers=0, drop_last=True)

# load model
removal_layer = nn.Sequential()

encoder_img = SimpleAutoencoder()
encoder_img.decoder = removal_layer


encoder_lidar = SimpleAutoencoder()
encoder_lidar.decoder = removal_layer


decoder = SimpleAutoencoder()
decoder.encoder = removal_layer

channelAdjust = WeightsGenerator()

fusion_net = TwoEncoderOneDecoder_fusion_4(encoder_img, encoder_lidar, decoder, channelAdjust)
# for name, value in test_model_best.named_parameters():
#     print(name)

# test_model_last.load_state_dict(torch.load('model_save/damage_{}/last_model_{}.pth'.format(damage_label, experimentIndex)))


fusion_net.load_state_dict(
    torch.load('model_save/fusion/10_fusion_4_best_model_600_32_20230529_222630.pth')
)
fusion_net.eval()
# Out:
# TwoEncoderOneDecoder_fusion_4(
#   (encoder1): SimpleAutoencoder(
#     (encoder): Encoder(
#       (downconv1): Sequential(
#         (0): Conv2d(1, 32, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#         (1): ReLU()
#         (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       )
#       (downconv2): Sequential(
#         (0): Conv2d(32, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#         (1): ReLU()
#         (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       )
#       (encoderBlock1): Sequential(
#         (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): ReLU()
#         (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#       (encoderBlock2): Sequential(
#         (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): ReLU()
#         (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#     )
#     (decoder): Sequential()
#   )
#   (encoder2): SimpleAutoencoder(
#     (encoder): Encoder(
#       (downconv1): Sequential(
#         (0): Conv2d(1, 32, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#         (1): ReLU()
#         (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       )
#       (downconv2): Sequential(
#         (0): Conv2d(32, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#         (1): ReLU()
#         (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       )
#       (encoderBlock1): Sequential(
#         (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): ReLU()
#         (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#       (encoderBlock2): Sequential(
#         (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): ReLU()
#         (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#     )
#     (decoder): Sequential()
#   )
#   (decoder): SimpleAutoencoder(
#     (encoder): Sequential()
#     (decoder): Decoder(
#       (upconv1): Sequential(
#         (0): ConvTranspose2d(64, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#         (1): ReLU()
#       )
#       (upconv2): Sequential(
#         (0): ConvTranspose2d(64, 32, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#         (1): ReLU()
#       )
#       (decoderBlock1): Sequential(
#         (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): ReLU()
#         (2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#       (upconv3): Sequential(
#         (0): ConvTranspose2d(32, 1, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): ReLU()
#       )
#       (decoderBlock2): Sequential(
#         (0): Conv2d(1, 1, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): ReLU()
#         (2): Conv2d(1, 1, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#     )
#   )
#   (weights): WeightsGenerator(
#     (layer1): Sequential(
#       (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): ReLU()
#       (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#     (layer2): Sequential(
#       (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): ReLU()
#       (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#   )
# )

# %%
dataiter = iter(new_testloader)
num_iterations = 10  # Change this to the desired number of iterations

criterion = nn.MSELoss()
criterion.to(device)

for _ in range(num_iterations):
    label, damaged_img, lidar = next(dataiter)
    output = fusion_net(damaged_img, lidar)


    batch_size = 32
    count = 0

    for j in range (batch_size):
        img1 = label[j]
        img3 = output[j]
        mse = criterion(img1,img3)
        mse = round(mse.item(),6)
        count = count+mse

    mse_mean = round(count,3)
    print(mse_mean)
# Out:
# 0.595
# 0.538
# 0.613
# 1.323
# 0.945
# 0.716
# 0.328
# 0.292
# 0.386
# 0.514

# %%
dataiter = iter(new_testloader)
num_iterations = 10

for j in range(num_iterations):
    label, damaged_img, lidar = next(dataiter)
    output = fusion_net(damaged_img, lidar)
    
    for i in range(32):
        img1 = label[i]
        img4 = output[i].detach().numpy()
        img4 = img4.transpose(1, 2, 0)
        name = '%02d' %i

        plt.xticks([])
        plt.yticks([])
        plt.imshow(img4, cmap='gray')
        # plt.subplots_adjust(top = 1, bottom = 0, right = 1, left = 0, hspace = 0, wspace = 0)
        # plt.margins(0,0)

        plt.savefig('fig_save/Fusion 2-1/{}_{:02}.png'.format(j,i),bbox_inches = 'tight',transparent = True)

# %%
-------------------------------------------------------------------

# %%
# create testdataset
damage_severity = '3'
damaged_img_path = 'deepEmsemblesDataset/Salt/damaged_image_{}'.format(damage_severity) 


lidar_path = 'deepEmsemblesDataset/lidar_tensor'



label_path = 'deepEmsemblesDataset/ori_image'

damaged_img_list = sorted(glob.glob(damaged_img_path + '/*'))
lidar_list = sorted(glob.glob(lidar_path + '/*'))
label_list = sorted(glob.glob(label_path + '/*'))

learning_rate = 1e-4
batch_size = 32

TestDataset = CreateDatasets(label_list, damaged_img_list, lidar_list)
new_testloader = DataLoader(dataset=TestDataset, batch_size=batch_size, shuffle=False, num_workers=0, drop_last=True)


# load model
removal_layer = nn.Sequential()

encoder_img = SimpleAutoencoder()
encoder_img.decoder = removal_layer


encoder_lidar = SimpleAutoencoder()
encoder_lidar.decoder = removal_layer


decoder = SimpleAutoencoder()
decoder.encoder = removal_layer

channelAdjust = WeightsGenerator()

fusion_net = TwoEncoderOneDecoder_fusion_4(encoder_img, encoder_lidar, decoder, channelAdjust)
# for name, value in test_model_best.named_parameters():
#     print(name)

# test_model_last.load_state_dict(torch.load('model_save/damage_{}/last_model_{}.pth'.format(damage_label, experimentIndex)))


fusion_net.load_state_dict(
    torch.load('model_save/fusion/10_fusion_4_best_model_600_32_20230529_222630.pth')
)
fusion_net.eval()
# Out:
# TwoEncoderOneDecoder_fusion_4(
#   (encoder1): SimpleAutoencoder(
#     (encoder): Encoder(
#       (downconv1): Sequential(
#         (0): Conv2d(1, 32, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#         (1): ReLU()
#         (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       )
#       (downconv2): Sequential(
#         (0): Conv2d(32, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#         (1): ReLU()
#         (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       )
#       (encoderBlock1): Sequential(
#         (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): ReLU()
#         (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#       (encoderBlock2): Sequential(
#         (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): ReLU()
#         (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#     )
#     (decoder): Sequential()
#   )
#   (encoder2): SimpleAutoencoder(
#     (encoder): Encoder(
#       (downconv1): Sequential(
#         (0): Conv2d(1, 32, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#         (1): ReLU()
#         (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       )
#       (downconv2): Sequential(
#         (0): Conv2d(32, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#         (1): ReLU()
#         (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       )
#       (encoderBlock1): Sequential(
#         (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): ReLU()
#         (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#       (encoderBlock2): Sequential(
#         (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): ReLU()
#         (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#     )
#     (decoder): Sequential()
#   )
#   (decoder): SimpleAutoencoder(
#     (encoder): Sequential()
#     (decoder): Decoder(
#       (upconv1): Sequential(
#         (0): ConvTranspose2d(64, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#         (1): ReLU()
#       )
#       (upconv2): Sequential(
#         (0): ConvTranspose2d(64, 32, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#         (1): ReLU()
#       )
#       (decoderBlock1): Sequential(
#         (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): ReLU()
#         (2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#       (upconv3): Sequential(
#         (0): ConvTranspose2d(32, 1, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): ReLU()
#       )
#       (decoderBlock2): Sequential(
#         (0): Conv2d(1, 1, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): ReLU()
#         (2): Conv2d(1, 1, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#     )
#   )
#   (weights): WeightsGenerator(
#     (layer1): Sequential(
#       (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): ReLU()
#       (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#     (layer2): Sequential(
#       (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): ReLU()
#       (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     )
#   )
# )

# %%
dataiter = iter(new_testloader)
num_iterations = 1  # Change this to the desired number of iterations

criterion = nn.MSELoss()
criterion.to(device)

for _ in range(num_iterations):
    label, damaged_img, lidar = next(dataiter)
    output = fusion_net(damaged_img, lidar)


    batch_size = 32
    count = 0

    for j in range (batch_size):
        img1 = label[j]
        img3 = output[j]
        mse = criterion(img1,img3)
        mse = round(mse.item(),6)
        count = count+mse

    mse_mean = round(count,3)
    print(mse_mean)
# Out:
# [W NNPACK.cpp:79] Could not initialize NNPACK! Reason: Unsupported hardware.
# 3.736

# %%
dataiter = iter(new_testloader)
num_iterations = 1

for j in range(num_iterations):
    label, damaged_img, lidar = next(dataiter)
    output = fusion_net(damaged_img, lidar)
    
    for i in range(32):
        img1 = label[i]
        img4 = output[i].detach().numpy()
        img4 = img4.transpose(1, 2, 0)
        name = '%02d' %i

        plt.xticks([])
        plt.yticks([])
        plt.imshow(img4, cmap='gray')
        # plt.subplots_adjust(top = 1, bottom = 0, right = 1, left = 0, hspace = 0, wspace = 0)
        # plt.margins(0,0)

        # plt.savefig('fig_save/Fusion 3/{}_{:02}.png'.format(j,i),bbox_inches = 'tight',transparent = True)

# %%
dataiter = iter(new_testloader)
label, damaged_img, lidar = next(dataiter)
label, damaged_img, lidar = next(dataiter)
label, damaged_img, lidar = next(dataiter)
label, damaged_img, lidar = next(dataiter)
label, damaged_img, lidar = next(dataiter)
label, damaged_img, lidar = next(dataiter)
label, damaged_img, lidar = next(dataiter)
label, damaged_img, lidar = next(dataiter)




output = fusion_net(damaged_img, lidar)

# %%
# prep images for display
i = 31
# for i in range(32):

img1 = label[i].numpy()
img1 = img1.transpose(1, 2, 0)
img2 = damaged_img[i].numpy()
img2 = img2.transpose(1, 2, 0)
img3 = lidar[i].detach().numpy()
img3 = img3.transpose(1, 2, 0)
img4 = output[i].detach().numpy()
img4 = img4.transpose(1, 2, 0)


ax = plt.subplot(1, 4, 1)
plt.xticks([])
plt.yticks([])
# ax.set_title('label')
plt.imshow(img1,cmap='gray')

ax = plt.subplot(1, 4, 2)
plt.xticks([])
plt.yticks([])
# ax.set_title('damaged image')
plt.imshow(img2,cmap='gray')

ax = plt.subplot(1, 4, 3)
plt.xticks([])
plt.yticks([])
# ax.set_title('lidar')
plt.imshow(img3)

ax = plt.subplot(1, 4, 4)
plt.xticks([])
plt.yticks([])
#  ax.set_title('reconstructed image')
plt.imshow(img4, cmap='gray')

    # plt.savefig('fig_save/{}.png'.format(i))
    
plt.show()

# %%
import cv2
from PIL import Image
from torchvision import transforms
from matplotlib import pyplot as plt


toPIL = transforms.ToPILImage()

# prep images for display
for i in range(32):
# i = 31

    img1 = label[i]
    img2 = damaged_img[i]
    img3 = lidar[i]
    img4 = output[i]
    # print(img1.shape, img3.shape)
    # print(type(img1),type(img3))
    # im1 = toPIL(img1)
    img4 = img4[0]
    max_value = torch.max(img4)
    min_value = torch.min(img4)
    print(max_value,min_value)



    img4_normalized = (img4 - min_value) / (max_value - min_value)


    im4 = toPIL(img4_normalized)
    im3 = toPIL(img3)
    name = '%02d' %i

# im1.save('RecosntructedImages/ori_img/{}.png'.format(name))
# im2.save('RecosntructedImages/masked_img/{}.png'.format(name))
# im4.save('output_save/5_main_fusion_3_dense/A/{}.png'.format(name))
# im3.save('output_save/lidar_sparse_testing/{}.png'.format(name))
# im4.save('{}.png'.format(name))

# import numpy as np
# import cv2

# for i in range(32):
#     if i ==13:
#         img1 = label[i].numpy()
#         img1 = img1.transpose(1, 2, 0)
#         img2 = damaged_img[i].numpy()
#         img2 = img2.transpose(1, 2, 0)
#         img3 = lidar[i].detach().numpy()
#         img3 = img3.transpose(1, 2, 0)
#         img4 = output[i].detach().numpy()
#         img4 = img4.transpose(1, 2, 0)

#         name = '%02d' %i
#         filepath = 'output_save/test/{}.png'.format(name)

#         # 调用函数将灰度图像保存为RGB图像的PNG
#         # cv2.imwrite(filepath, img4)
#         plt.xticks([])
#         plt.yticks([])
#         plt.imshow(img4, cmap='gray')
#         plt.savefig(filepath)
#         plt.colorbar()
#         plt.show()
# Out:
# tensor(1.0590, grad_fn=<MaxBackward1>) tensor(-0.0068, grad_fn=<MinBackward1>)
# tensor(1.1087, grad_fn=<MaxBackward1>) tensor(0.0157, grad_fn=<MinBackward1>)
# tensor(1.1730, grad_fn=<MaxBackward1>) tensor(0.0492, grad_fn=<MinBackward1>)
# tensor(1.2108, grad_fn=<MaxBackward1>) tensor(0.0889, grad_fn=<MinBackward1>)
# tensor(1.1027, grad_fn=<MaxBackward1>) tensor(0.0243, grad_fn=<MinBackward1>)
# tensor(1.0759, grad_fn=<MaxBackward1>) tensor(0.0110, grad_fn=<MinBackward1>)
# tensor(1.0808, grad_fn=<MaxBackward1>) tensor(-0.0420, grad_fn=<MinBackward1>)
# tensor(1.1386, grad_fn=<MaxBackward1>) tensor(0.0065, grad_fn=<MinBackward1>)
# tensor(1.1145, grad_fn=<MaxBackward1>) tensor(-0.0084, grad_fn=<MinBackward1>)
# tensor(1.1468, grad_fn=<MaxBackward1>) tensor(-0.0678, grad_fn=<MinBackward1>)
# tensor(1.1297, grad_fn=<MaxBackward1>) tensor(0.0129, grad_fn=<MinBackward1>)
# tensor(1.1884, grad_fn=<MaxBackward1>) tensor(-0.0378, grad_fn=<MinBackward1>)
# tensor(1.1725, grad_fn=<MaxBackward1>) tensor(0.0098, grad_fn=<MinBackward1>)
# tensor(1.2034, grad_fn=<MaxBackward1>) tensor(0.0052, grad_fn=<MinBackward1>)
# tensor(1.1897, grad_fn=<MaxBackward1>) tensor(-0.0379, grad_fn=<MinBackward1>)
# tensor(1.0158, grad_fn=<MaxBackward1>) tensor(-0.0865, grad_fn=<MinBackward1>)
# tensor(1.1563, grad_fn=<MaxBackward1>) tensor(0.0439, grad_fn=<MinBackward1>)
# tensor(1.1152, grad_fn=<MaxBackward1>) tensor(-0.0401, grad_fn=<MinBackward1>)
# tensor(1.1378, grad_fn=<MaxBackward1>) tensor(0.0118, grad_fn=<MinBackward1>)
# tensor(1.0568, grad_fn=<MaxBackward1>) tensor(-0.0113, grad_fn=<MinBackward1>)
# tensor(1.1285, grad_fn=<MaxBackward1>) tensor(0.0018, grad_fn=<MinBackward1>)
# tensor(1.0817, grad_fn=<MaxBackward1>) tensor(-0.0624, grad_fn=<MinBackward1>)
# tensor(1.0866, grad_fn=<MaxBackward1>) tensor(0.0049, grad_fn=<MinBackward1>)
# tensor(1.1885, grad_fn=<MaxBackward1>) tensor(-0.0627, grad_fn=<MinBackward1>)
# tensor(1.2119, grad_fn=<MaxBackward1>) tensor(0.0021, grad_fn=<MinBackward1>)
# tensor(0.9890, grad_fn=<MaxBackward1>) tensor(-0.0130, grad_fn=<MinBackward1>)
# tensor(1.1017, grad_fn=<MaxBackward1>) tensor(0.0346, grad_fn=<MinBackward1>)
# tensor(1.1487, grad_fn=<MaxBackward1>) tensor(-0.0351, grad_fn=<MinBackward1>)
# tensor(1.1557, grad_fn=<MaxBackward1>) tensor(0.0440, grad_fn=<MinBackward1>)
# tensor(1.1426, grad_fn=<MaxBackward1>) tensor(0.0385, grad_fn=<MinBackward1>)
# tensor(0.9970, grad_fn=<MaxBackward1>) tensor(-0.0692, grad_fn=<MinBackward1>)
# tensor(1.1206, grad_fn=<MaxBackward1>) tensor(-0.0156, grad_fn=<MinBackward1>)

# %%
# MSE for all damages
criterion = nn.MSELoss()
criterion.to(device)

for i, batch in enumerate(new_testloader):# i -->index of batch
    count = 0
    for j in range (batch_size):
        img1 = label[i]
        img3 = output[i]
        mse = criterion(img1,img3)
        mse = round(mse.item(),6)
        count = count+mse

    mse_mean = round(count,3)
    print(mse_mean)
# Out:
# 0.887
# 0.423
# 0.791
# 0.71
# 0.462
# 1.071
# 0.235
# 0.578

# %%
# # regional mse

# batch_size = 32

# def create_mask(image_shape, block_size, num_blocks):
#     mask = np.ones(image_shape, dtype=np.float32) 
#     block_size_px = (int(image_shape[0] * block_size), int(image_shape[1] * block_size))
#     np.random.seed(6)

#     for _ in range(num_blocks):
#         top_left = np.random.randint(0, image_shape[0] - block_size_px[0] + 1), np.random.randint(0, image_shape[1] - block_size_px[1] + 1)
#         bottom_right = top_left[0] + block_size_px[0], top_left[1] + block_size_px[1]
#         mask[top_left[0]:bottom_right[0], top_left[1]:bottom_right[1]] = 0
        
#     return mask


# block_size = 0.2  # 方块大小为原图大小的百分比
# num_blocks = 16  # 方块数量

# count = 0

# for j in range(label.size(0)):
#     ori_img_np = label[j][0].detach().numpy()
#     output_np = output[j][0].detach().numpy()
#     mask = create_mask(ori_img_np.shape[:2], block_size, num_blocks)
#     local_mse = np.mean(np.square(output_np - ori_img_np) * mask)
#     count = count+local_mse
# local_mse = round(count/batch_size, 6)

# # baseline
# for j in range(label.size(0)):
#     ori_img_np = label[j][0].detach().numpy()
#     output_np = output[j][0].detach().numpy()
#     mask = create_mask(ori_img_np.shape[:2], block_size, num_blocks)
#     local_mse = np.mean(np.square(output_np - ori_img_np) * mask)
#     count = count+local_mse
# local_mse = round(count/batch_size, 6)

# print(local_mse)
# Out:
# 0.003846

# %%
import cv2
import os
import numpy

masked_region_list = []
original_image_list = []

image_path = 'testdataset/ori_image'
images = sorted(glob.glob(image_path + '/*'))[0:32]
damage_label = 'A'

def create_mask(image_shape, block_size, num_blocks):
    mask = np.ones(image_shape, dtype=np.float32) 
    block_size_px = (int(image_shape[0] * block_size), int(image_shape[1] * block_size))
    np.random.seed(6)
    masked_region = []

    for _ in range(num_blocks):
        top_left = np.random.randint(0, image_shape[0] - block_size_px[0] + 1), np.random.randint(0, image_shape[1] - block_size_px[1] + 1)
        bottom_right = top_left[0] + block_size_px[0], top_left[1] + block_size_px[1]
        mask[top_left[0]:bottom_right[0], top_left[1]:bottom_right[1]] = 0
        masked_region.append((top_left, bottom_right))
        
    return mask, masked_region


for i in range(len(images)):
    image = cv2.imread(images[i])
    image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    ori_img_name = os.path.basename(images[i])

    block_size = 0.2  # 方块大小为原图大小的百分比
    num_blocks = 16  # 方块数量
    mask, masked_region = create_mask(image.shape[:2], block_size, num_blocks)
    masked_region_list.append(masked_region)
    original_image_list.append(image)
    damaged_img1 = image * mask
    # cv2.imwrite(f'testdataset/damaged_image/{damage_label}_{ori_img_name}', damaged_img1)

regional_mse_list = []

for i in range(len(images)):
    original_image = original_image_list[i]
    masked_region = masked_region_list[i]
    original_image = (original_image-np.min(original_image))/(np.max(original_image)-np.min(original_image))
    

    
    # Obtain the output reconstructed image
    output_image = output[i][0].detach().numpy()  # Replace this with the code to get the output image from your image reconstruction network
    # output_image = (output_image-np.min(output_image))/(np.max(output_image)-np.min(output_image))
    
    mse = 0
    num_pixels = 0

    for region in masked_region:
        top_left, bottom_right = region
        original_pixels = original_image[top_left[0]:bottom_right[0], top_left[1]:bottom_right[1]]
        output_pixels = output_image[top_left[0]:bottom_right[0], top_left[1]:bottom_right[1]]
        diff = original_pixels.astype(np.float32) - output_pixels.astype(np.float32)
        mse += np.sum(diff ** 2)
        num_pixels += original_pixels.size

    mse /= num_pixels
    regional_mse_list.append(mse)

print(np.mean(regional_mse_list))
# Out:
# 0.03342867927756742

# %%
# SSIM

import torch
from skimage.metrics import structural_similarity as ssim
import glob


metric_value_list = []
batch_size = 32


for i, batch in enumerate(new_testloader):
    label, damaged_img, lidar = batch
    count = 0
    for j in range(label.size(0)):
        ori_img_np = label[j][0].detach().cpu().numpy()
        output_np = output[j][0].detach().cpu().numpy()
        ssim_img, diff = ssim(ori_img_np, output_np, full=True, data_range=1.0)
        count = count + ssim_img
    ssim_img = round(count / label.size(0), 3)
    print(ssim_img)
#     metric_value_list.append(ssim_img)

# print(metric_value_list)
# Out:
# 0.475
# 0.183
# 0.171
# 0.161
# 0.162
# 0.169
# 0.168
# 0.171

# %%
# LLIPS metrics

import lpips

loss_fn = lpips.LPIPS(net='alex')


for i, batch in enumerate(new_testloader):  # i -->index of batch
    label, damaged_img, lidar = batch
    count = 0
    for j in range(label.size(0)):
        # ori_img_np = ori_img[j][0].detach().numpy()
        # output_np = output[j][0].detach().numpy()
        lpips_img = loss_fn.forward(label, output)
        sum_result = (torch.sum(lpips_img)).item()
        count = count+sum_result
        # count = count.item()
    lpips_img = round(count/label.size(0),3)
    print(lpips_img)
#     metric_value_list.append(lpips_img)

# print(f'scuccess: {metric_value_list}')
# Out:
# Setting up [LPIPS] perceptual loss: trunk [alex], v[0.1], spatial [off]
# Loading model from: /usr/local/Anaconda3-2021.11-Linux-x86_64/envs/pytorch/lib/python3.8/site-packages/lpips/weights/v0.1/alex.pth
# 12.367
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [15], line 14
#      10 count = 0
#      11 for j in range(label.size(0)):
#      12     # ori_img_np = ori_img[j][0].detach().numpy()
#      13     # output_np = output[j][0].detach().numpy()
# ---> 14     lpips_img = loss_fn.forward(label, output)
#      15     sum_result = (torch.sum(lpips_img)).item()
#      16     count = count+sum_result
#
# File /usr/local/Anaconda3-2021.11-Linux-x86_64/envs/pytorch/lib/python3.8/site-packages/lpips/lpips.py:89, in LPIPS.forward(self, in0, in1, retPerLayer, normalize)
#      87 # v0.0 - original release had a bug, where input was not scaled
#      88 in0_input, in1_input = (self.scaling_layer(in0), self.scaling_layer(in1)) if self.version=='0.1' else (in0, in1)
# ---> 89 outs0, outs1 = self.net.forward(in0_input), self.net.forward(in1_input)
#      90 feats0, feats1, diffs = {}, {}, {}
#      92 for kk in range(self.L):
#
# File /usr/local/Anaconda3-2021.11-Linux-x86_64/envs/pytorch/lib/python3.8/site-packages/lpips/pretrained_networks.py:89, in alexnet.forward(self, X)
#      87 h = self.slice4(h)
#      88 h_relu4 = h
# ---> 89 h = self.slice5(h)
#      90 h_relu5 = h
#      91 alexnet_outputs = namedtuple("AlexnetOutputs", ['relu1', 'relu2', 'relu3', 'relu4', 'relu5'])
#
# File /usr/local/Anaconda3-2021.11-Linux-x86_64/envs/pytorch/lib/python3.8/site-packages/torch/nn/modules/module.py:1102, in Module._call_impl(self, *input, **kwargs)
#    1098 # If we don't have any hooks, we want to skip the rest of the logic in
#    1099 # this function, and just call forward.
#    1100 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102     return forward_call(*input, **kwargs)
#    1103 # Do not call functions when jit is used
#    1104 full_backward_hooks, non_full_backward_hooks = [], []
#
# File /usr/local/Anaconda3-2021.11-Linux-x86_64/envs/pytorch/lib/python3.8/site-packages/torch/nn/modules/container.py:141, in Sequential.forward(self, input)
#     139 def forward(self, input):
#     140     for module in self:
# --> 141         input = module(input)
#     142     return input
#
# File /usr/local/Anaconda3-2021.11-Linux-x86_64/envs/pytorch/lib/python3.8/site-packages/torch/nn/modules/module.py:1102, in Module._call_impl(self, *input, **kwargs)
#    1098 # If we don't have any hooks, we want to skip the rest of the logic in
#    1099 # this function, and just call forward.
#    1100 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102     return forward_call(*input, **kwargs)
#    1103 # Do not call functions when jit is used
#    1104 full_backward_hooks, non_full_backward_hooks = [], []
#
# File /usr/local/Anaconda3-2021.11-Linux-x86_64/envs/pytorch/lib/python3.8/site-packages/torch/nn/modules/conv.py:446, in Conv2d.forward(self, input)
#     445 def forward(self, input: Tensor) -> Tensor:
# --> 446     return self._conv_forward(input, self.weight, self.bias)
#
# File /usr/local/Anaconda3-2021.11-Linux-x86_64/envs/pytorch/lib/python3.8/site-packages/torch/nn/modules/conv.py:442, in Conv2d._conv_forward(self, input, weight, bias)
#     438 if self.padding_mode != 'zeros':
#     439     return F.conv2d(F.pad(input, self._reversed_padding_repeated_twice, mode=self.padding_mode),
#     440                     weight, bias, self.stride,
#     441                     _pair(0), self.dilation, self.groups)
# --> 442 return F.conv2d(input, weight, bias, self.stride,
#     443                 self.padding, self.dilation, self.groups)
#
# KeyboardInterrupt:
