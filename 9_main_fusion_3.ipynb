# %%
# the input of the image encoder is original image
# encoder decoder fixed

ori_channeladjust_best_model_best_model_600_32_20230524_131649 --- dense lidar

new one!!!:
channeladjust_best_model_best_model_600_32_20230529_160039

# %%
from matplotlib import pyplot as plt
from torch.utils.data import DataLoader
from sensorFusionDataset.creatDataset_2_encoder import CreateDatasets
from sensorFusionDataset.data_split import split_dataset
from sensorFusionNetwork.simpleAutoencoder import SimpleAutoencoder, TwoEncoderOneDecoder, EncoderFusion, TwoEncoderOneDecoderAfterTraning
from testLoop import test_loop_fusion
from trainLoop import train_loop_fusion
from visualization import plot_losses, plot_metrics,plotTraining
from earlystopping import EarlyStopping

import h5py as h5
from datetime import datetime
import copy
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import glob
import time

local_time =time.strftime("%Y-%m-%d %H:%M:%S", time.localtime())[-8:-1]
now = datetime.now()
dt_string = now.strftime("%Y%m%d_%H%M%S")
# CPU OR GPU
device = 'cuda' if torch.cuda.is_available() else 'cpu'

damaged_img_path = 'image_gray_200_original' 

lidar_mode = 'sparse'

if lidar_mode == 'sparse':
    lidar_path = 'lidar_tesor_200_sparse'
else:
    lidar_path = 'lidar_tesor_200_dense'

label_path = 'image_gray_200_original'

damaged_img_list = sorted(glob.glob(damaged_img_path + '/*'))[0:7200]
lidar_list = sorted(glob.glob(lidar_path + '/*'))[0:7200]
label_list = sorted(glob.glob(label_path + '/*'))[0:7200]


batch_size = 32
learning_rate = 1e-4
epochs = 600

MyDataset = CreateDatasets(label_list, damaged_img_list, lidar_list)#, img_size=img_size
train_dataset, test_dataset, val_dataset = split_dataset(MyDataset, 0.7, 0.2)
train_loader = DataLoader(dataset=train_dataset, batch_size=batch_size, shuffle=True, num_workers=0,
                          drop_last=True)
test_loader = DataLoader(dataset=test_dataset, batch_size=batch_size, shuffle=True, num_workers=0,
                         drop_last=True)
val_loader = DataLoader(dataset=val_dataset, batch_size=batch_size, shuffle=False, num_workers=0,
                        drop_last=True)

patience = 50	# 当验证集损失在连续20次训练周期中都没有得到降低时，停止模型训练，以防止模型过拟合
save_path = 'fusion_model/'
early_stopping = EarlyStopping(save_path = save_path, patience = patience)	

criterion = nn.MSELoss()




# new_model = SimpleAutoencoder()
# new_model.to(device)
# new_model.load_state_dict(torch.load('denoising_model/best_model_300_32_0.0004_20230422_153250.pth'))

# for name, value in new_model.named_parameters():
#     #print (name) # print(model.state_dict().keys())
#     if name.startswith('decoder'):
#         value.requires_grad = False
        
# params = filter(lambda p: p.requires_grad, new_model.parameters())
# optimizer = torch.optim.Adam(params, lr=learning_rate)

# criterion = nn.MSELoss()
# criterion.to(device)

training_loss = []
training_baseloss = []
test_loss = []
testing_baseloss = []
hisLrC = []
min_loss=10000

print (f'loading fertig! {device}' )
# Out:
# loading fertig! cuda

# %%
# retraining with the channel adjust
# loading model
removal_layer = nn.Sequential()

encoder_img = SimpleAutoencoder()
encoder_img.load_state_dict(torch.load('model_save/ori2ori/ori2ori_best_model_600_32_20230518_044338.pth'))
encoder_img.decoder = removal_layer


encoder_lidar = SimpleAutoencoder()
if lidar_mode == 'sparse':
    encoder_lidar.load_state_dict(torch.load('model_save/lidar2img/sparse_FIX_best_model_600_32_20230518_063828.pth'))
else:
    encoder_lidar.load_state_dict(torch.load('model_save/lidar2img/dense_FIX_best_model_600_32_20230518_154020.pth'))
encoder_lidar.decoder = removal_layer


decoder = SimpleAutoencoder()
decoder.load_state_dict(torch.load('model_save/ori2ori/ori2ori_best_model_600_32_20230518_044338.pth'))
# decoder.load_state_dict(torch.load('denoising_model/best_model_300_32_0.0004_20230422_153250.pth'))
decoder.encoder = removal_layer

channelAdjust = EncoderFusion()
# channelAdjust.to(device)

fusion_net = TwoEncoderOneDecoder(encoder_img, encoder_lidar, decoder, channelAdjust)
fusion_net.to(device)

for name, value in fusion_net.named_parameters():
    # print (name) # print(model.state_dict().keys())
    if name.startswith('decoder'):
        value.requires_grad = False
    if name.startswith('encoder'):
        value.requires_grad = False

params = filter(lambda p: p.requires_grad, fusion_net.parameters())


learning_rate = 0.0004  # 2e-4 batchsize=30
optimizer = torch.optim.Adam(params, lr=learning_rate)

criterion = nn.MSELoss()
criterion.to(device)


start_time = time.time()
for epoch in range(1, epochs + 1):
    # monitor training loss
    ##############################
    # start training the model #
    ##############################
    hisLrC.append(epoch)
    train_epoch_loss, train_epoch_baseloss = train_loop_fusion(train_loader, fusion_net, criterion, optimizer, device)
    training_loss.append(train_epoch_loss)
    # training_baseloss.append(train_epoch_baseloss)
    print('Epoch: {}/{} \tTraining Loss: {:.6f} \t{:.0f}s'.format(epoch, epochs, train_epoch_loss,
                                                                  time.time() - start_time))

    ##############################
    # start testing the model #
    ##############################
    with torch.no_grad():
        test_epoch_loss, test_epoch_baseloss = test_loop_fusion(test_loader, fusion_net, criterion, device)
        test_loss.append(test_epoch_loss)
        # testing_baseloss.append(test_epoch_baseloss)
        
    # type(train_epoch_loss)) ---> float
    # writer.add_scalars('loss', {'training loss': train_epoch_loss, 'test loss': test_epoch_loss}, epoch)

        
    if test_epoch_loss < min_loss:
        min_loss = test_epoch_loss
        best_model_wts = copy.deepcopy(fusion_net.state_dict())
       

    if epoch == epochs:
        torch.save(best_model_wts, 'model_save/fusion/input_ori_fixed_endecoder_best_model_{}_{}_{}.pth'.format(epochs, batch_size,dt_string))
        print('best_testloss:{:.3f}\t epoch:{}'.format(min_loss, test_loss.index(min_loss)))     

    # 早停止
    date = dt_string
    early_stopping(test_epoch_loss, fusion_net, date)
    #达到早停止条件时，early_stop会被置为True
    if early_stopping.early_stop:
        torch.save(best_model_wts, 'model_save/fusion/channeladjust_best_model_best_model_{}_{}_{}.pth'.format(epochs, batch_size,dt_string))
        # torch.save(fusion_net.state_dict(), 'Experiment2_sequence_inverse/fusion_model/last_model_{}_{}_{}.pth'.format(epochs, batch_size,dt_string))
        print('best_testloss:{:.3f}\t epoch:{}'.format(min_loss, test_loss.index(min_loss)))  
        print("Early stopping")
        break #跳出迭代，结束训练    
    
# train_baseline = sum(training_baseloss)/len(training_baseloss)
# test_baseline = sum(testing_baseloss)/len(training_baseloss)
# psnr_baseline = np.mean(psnr_base_list)

# train_baseline=train_baseline.item()
# test_baseline =test_baseline.item()
last_trainingloss = training_loss[-1]
last_testloss = test_loss[-1]


# write the dataset in one existed h5-file
now = datetime.now()
dt_string = now.strftime("%Y%m%d_%H%M%S")

lossTrainArr = np.array(training_loss)
lossTestArr = np.array(test_loss)
bestLoss = np.array([min_loss])
LrCArr = np.array(hisLrC)

h5f =h5.File(f"log/recording_{dt_string}.hdf5","w")
# h5f = h5.File('train/train.h5', 'r+') # write in an exsited h5 file
g1 = h5f.create_group('log1')
g1.attrs['data']=now.strftime("%Y-%m-%d")
# g1.attrs['model']=ModelWts
# g1.attrs['optLrOrg']=str(optLrOrg)+'={:3.1e}'.format(optLrOrg) 
# g1.attrs['lrAdstep']= str(lrAdstep)
# g1.attrs['optimizer']= str(optimizer)[:4]

g1.create_dataset('lossTrain', data=lossTrainArr)
g1.create_dataset('lossTest', data=lossTestArr)
g1.create_dataset('bestLoss', data=bestLoss)
g1.create_dataset('LrCArr', data=LrCArr)
h5f.close()

# print('train_baseline:{:.3f} \t test_baseline:{:.3f} \t last trainingloss:{:.3f} \t last testloss:{:.3f}'.format(train_baseline, test_baseline,last_trainingloss,last_testloss))
# Out:
# Epoch: 1/600 	Training Loss: 0.284323 	21s
# Epoch: 2/600 	Training Loss: 0.053488 	44s
# Epoch: 3/600 	Training Loss: 0.040346 	67s
# Epoch: 4/600 	Training Loss: 0.034673 	90s
# Epoch: 5/600 	Training Loss: 0.031331 	111s
# Epoch: 6/600 	Training Loss: 0.027867 	129s
# Epoch: 7/600 	Training Loss: 0.026889 	146s
# Epoch: 8/600 	Training Loss: 0.024913 	163s
# EarlyStopping counter: 1 out of 50
# Epoch: 9/600 	Training Loss: 0.023987 	180s
# Epoch: 10/600 	Training Loss: 0.021948 	197s
# Epoch: 11/600 	Training Loss: 0.075265 	215s
# EarlyStopping counter: 1 out of 50
# Epoch: 12/600 	Training Loss: 0.035513 	232s
# EarlyStopping counter: 2 out of 50
# Epoch: 13/600 	Training Loss: 0.025668 	249s
# EarlyStopping counter: 3 out of 50
# Epoch: 14/600 	Training Loss: 0.022191 	266s
# EarlyStopping counter: 4 out of 50
# Epoch: 15/600 	Training Loss: 0.019715 	285s
# Epoch: 16/600 	Training Loss: 0.018083 	302s
# Epoch: 17/600 	Training Loss: 0.016829 	320s
# Epoch: 18/600 	Training Loss: 0.015969 	337s
# Epoch: 19/600 	Training Loss: 0.015058 	355s
# Epoch: 20/600 	Training Loss: 0.014566 	372s
# Epoch: 21/600 	Training Loss: 0.013951 	389s
# Epoch: 22/600 	Training Loss: 0.013357 	407s
# Epoch: 23/600 	Training Loss: 0.013226 	424s
# Epoch: 24/600 	Training Loss: 0.012575 	442s
# EarlyStopping counter: 1 out of 50
# Epoch: 25/600 	Training Loss: 0.012535 	459s
# Epoch: 26/600 	Training Loss: 0.011902 	476s
# EarlyStopping counter: 1 out of 50
# Epoch: 27/600 	Training Loss: 0.012929 	494s
# Epoch: 28/600 	Training Loss: 0.011547 	511s
# Epoch: 29/600 	Training Loss: 0.011506 	529s
# Epoch: 30/600 	Training Loss: 0.011607 	546s
# Epoch: 31/600 	Training Loss: 0.010906 	563s
# Epoch: 32/600 	Training Loss: 0.011063 	581s
# EarlyStopping counter: 1 out of 50
# Epoch: 33/600 	Training Loss: 0.011055 	598s
# Epoch: 34/600 	Training Loss: 0.011391 	615s
# EarlyStopping counter: 1 out of 50
# Epoch: 35/600 	Training Loss: 0.010278 	633s
# Epoch: 36/600 	Training Loss: 0.010429 	650s
# EarlyStopping counter: 1 out of 50
# Epoch: 37/600 	Training Loss: 0.011257 	668s
# Epoch: 38/600 	Training Loss: 0.009950 	685s
# EarlyStopping counter: 1 out of 50
# Epoch: 39/600 	Training Loss: 0.011615 	703s
# Epoch: 40/600 	Training Loss: 0.009761 	720s
# Epoch: 41/600 	Training Loss: 0.009868 	738s
# EarlyStopping counter: 1 out of 50
# Epoch: 42/600 	Training Loss: 0.009818 	755s
# EarlyStopping counter: 2 out of 50
# Epoch: 43/600 	Training Loss: 0.009907 	773s
# EarlyStopping counter: 3 out of 50
# Epoch: 44/600 	Training Loss: 0.009954 	790s
# EarlyStopping counter: 4 out of 50
# Epoch: 45/600 	Training Loss: 0.009710 	807s
# Epoch: 46/600 	Training Loss: 0.009747 	825s
# EarlyStopping counter: 1 out of 50
# Epoch: 47/600 	Training Loss: 0.009832 	842s
# EarlyStopping counter: 2 out of 50
# Epoch: 48/600 	Training Loss: 0.009371 	860s
# Epoch: 49/600 	Training Loss: 0.010017 	877s
# EarlyStopping counter: 1 out of 50
# Epoch: 50/600 	Training Loss: 0.009528 	894s
# Epoch: 51/600 	Training Loss: 0.009356 	912s
# EarlyStopping counter: 1 out of 50
# Epoch: 52/600 	Training Loss: 0.009444 	929s
# EarlyStopping counter: 2 out of 50
# Epoch: 53/600 	Training Loss: 0.009447 	947s
# EarlyStopping counter: 3 out of 50
# Epoch: 54/600 	Training Loss: 0.009341 	964s
# EarlyStopping counter: 4 out of 50
# Epoch: 55/600 	Training Loss: 0.009100 	982s
# EarlyStopping counter: 5 out of 50
# Epoch: 56/600 	Training Loss: 0.009754 	1000s
# EarlyStopping counter: 6 out of 50
# Epoch: 57/600 	Training Loss: 0.009003 	1017s
# EarlyStopping counter: 7 out of 50
# Epoch: 58/600 	Training Loss: 0.008997 	1035s
# Epoch: 59/600 	Training Loss: 0.010957 	1052s
# EarlyStopping counter: 1 out of 50
# Epoch: 60/600 	Training Loss: 0.008851 	1070s
# Epoch: 61/600 	Training Loss: 0.008873 	1087s
# Epoch: 62/600 	Training Loss: 0.009036 	1105s
# EarlyStopping counter: 1 out of 50
# Epoch: 63/600 	Training Loss: 0.009406 	1122s
# EarlyStopping counter: 2 out of 50
# Epoch: 64/600 	Training Loss: 0.008756 	1139s
# Epoch: 65/600 	Training Loss: 0.009069 	1157s
# EarlyStopping counter: 1 out of 50
# Epoch: 66/600 	Training Loss: 0.008977 	1174s
# EarlyStopping counter: 2 out of 50
# Epoch: 67/600 	Training Loss: 0.008843 	1192s
# Epoch: 68/600 	Training Loss: 0.008729 	1209s
# EarlyStopping counter: 1 out of 50
# Epoch: 69/600 	Training Loss: 0.009602 	1226s
# Epoch: 70/600 	Training Loss: 0.008730 	1244s
# EarlyStopping counter: 1 out of 50
# Epoch: 71/600 	Training Loss: 0.008856 	1261s
# EarlyStopping counter: 2 out of 50
# Epoch: 72/600 	Training Loss: 0.008690 	1278s
# EarlyStopping counter: 3 out of 50
# Epoch: 73/600 	Training Loss: 0.008871 	1296s
# EarlyStopping counter: 4 out of 50
# Epoch: 74/600 	Training Loss: 0.008764 	1313s
# EarlyStopping counter: 5 out of 50
# Epoch: 75/600 	Training Loss: 0.008670 	1331s
# Epoch: 76/600 	Training Loss: 0.008715 	1348s
# EarlyStopping counter: 1 out of 50
# Epoch: 77/600 	Training Loss: 0.008753 	1365s
# EarlyStopping counter: 2 out of 50
# Epoch: 78/600 	Training Loss: 0.008891 	1383s
# EarlyStopping counter: 3 out of 50
# Epoch: 79/600 	Training Loss: 0.008852 	1400s
# Epoch: 80/600 	Training Loss: 0.008407 	1417s
# EarlyStopping counter: 1 out of 50
# Epoch: 81/600 	Training Loss: 0.009038 	1435s
# EarlyStopping counter: 2 out of 50
# Epoch: 82/600 	Training Loss: 0.008529 	1452s
# Epoch: 83/600 	Training Loss: 0.008487 	1470s
# EarlyStopping counter: 1 out of 50
# Epoch: 84/600 	Training Loss: 0.008502 	1487s
# EarlyStopping counter: 2 out of 50
# Epoch: 85/600 	Training Loss: 0.008628 	1505s
# EarlyStopping counter: 3 out of 50
# Epoch: 86/600 	Training Loss: 0.008597 	1522s
# Epoch: 87/600 	Training Loss: 0.008611 	1540s
# EarlyStopping counter: 1 out of 50
# Epoch: 88/600 	Training Loss: 0.008434 	1557s
# EarlyStopping counter: 2 out of 50
# Epoch: 89/600 	Training Loss: 0.008513 	1575s
# EarlyStopping counter: 3 out of 50
# Epoch: 90/600 	Training Loss: 0.008412 	1592s
# EarlyStopping counter: 4 out of 50
# Epoch: 91/600 	Training Loss: 0.008495 	1610s
# EarlyStopping counter: 5 out of 50
# Epoch: 92/600 	Training Loss: 0.008468 	1627s
# EarlyStopping counter: 6 out of 50
# Epoch: 93/600 	Training Loss: 0.008623 	1645s
# EarlyStopping counter: 7 out of 50
# Epoch: 94/600 	Training Loss: 0.008312 	1662s
# Epoch: 95/600 	Training Loss: 0.008831 	1680s
# EarlyStopping counter: 1 out of 50
# Epoch: 96/600 	Training Loss: 0.008197 	1697s
# EarlyStopping counter: 2 out of 50
# Epoch: 97/600 	Training Loss: 0.008392 	1714s
# EarlyStopping counter: 3 out of 50
# Epoch: 98/600 	Training Loss: 0.008861 	1732s
# Epoch: 99/600 	Training Loss: 0.008169 	1749s
# EarlyStopping counter: 1 out of 50
# Epoch: 100/600 	Training Loss: 0.008218 	1766s
# EarlyStopping counter: 2 out of 50
# Epoch: 101/600 	Training Loss: 0.009024 	1784s
# Epoch: 102/600 	Training Loss: 0.008173 	1801s
# Epoch: 103/600 	Training Loss: 0.008305 	1819s
# EarlyStopping counter: 1 out of 50
# Epoch: 104/600 	Training Loss: 0.008374 	1836s
# EarlyStopping counter: 2 out of 50
# Epoch: 105/600 	Training Loss: 0.008222 	1854s
# EarlyStopping counter: 3 out of 50
# Epoch: 106/600 	Training Loss: 0.008257 	1871s
# Epoch: 107/600 	Training Loss: 0.008516 	1888s
# EarlyStopping counter: 1 out of 50
# Epoch: 108/600 	Training Loss: 0.008303 	1906s
# EarlyStopping counter: 2 out of 50
# Epoch: 109/600 	Training Loss: 0.008360 	1924s
# EarlyStopping counter: 3 out of 50
# Epoch: 110/600 	Training Loss: 0.008222 	1941s
# EarlyStopping counter: 4 out of 50
# Epoch: 111/600 	Training Loss: 0.008329 	1959s
# EarlyStopping counter: 5 out of 50
# Epoch: 112/600 	Training Loss: 0.008304 	1976s
# EarlyStopping counter: 6 out of 50
# Epoch: 113/600 	Training Loss: 0.008150 	1993s
# EarlyStopping counter: 7 out of 50
# Epoch: 114/600 	Training Loss: 0.008182 	2011s
# EarlyStopping counter: 8 out of 50
# Epoch: 115/600 	Training Loss: 0.008322 	2028s
# EarlyStopping counter: 9 out of 50
# Epoch: 116/600 	Training Loss: 0.008301 	2046s
# EarlyStopping counter: 10 out of 50
# Epoch: 117/600 	Training Loss: 0.008117 	2063s
# EarlyStopping counter: 11 out of 50
# Epoch: 118/600 	Training Loss: 0.008400 	2080s
# Epoch: 119/600 	Training Loss: 0.008060 	2098s
# EarlyStopping counter: 1 out of 50
# Epoch: 120/600 	Training Loss: 0.008101 	2115s
# EarlyStopping counter: 2 out of 50
# Epoch: 121/600 	Training Loss: 0.008267 	2133s
# EarlyStopping counter: 3 out of 50
# Epoch: 122/600 	Training Loss: 0.008301 	2150s
# EarlyStopping counter: 4 out of 50
# Epoch: 123/600 	Training Loss: 0.008022 	2168s
# EarlyStopping counter: 5 out of 50
# Epoch: 124/600 	Training Loss: 0.008196 	2185s
# EarlyStopping counter: 6 out of 50
# Epoch: 125/600 	Training Loss: 0.008149 	2203s
# EarlyStopping counter: 7 out of 50
# Epoch: 126/600 	Training Loss: 0.008128 	2220s
# Epoch: 127/600 	Training Loss: 0.008196 	2238s
# EarlyStopping counter: 1 out of 50
# Epoch: 128/600 	Training Loss: 0.008235 	2255s
# EarlyStopping counter: 2 out of 50
# Epoch: 129/600 	Training Loss: 0.008126 	2273s
# EarlyStopping counter: 3 out of 50
# Epoch: 130/600 	Training Loss: 0.008193 	2290s
# EarlyStopping counter: 4 out of 50
# Epoch: 131/600 	Training Loss: 0.008025 	2308s
# EarlyStopping counter: 5 out of 50
# Epoch: 132/600 	Training Loss: 0.008139 	2325s
# Epoch: 133/600 	Training Loss: 0.008114 	2342s
# EarlyStopping counter: 1 out of 50
# Epoch: 134/600 	Training Loss: 0.008141 	2360s
# EarlyStopping counter: 2 out of 50
# Epoch: 135/600 	Training Loss: 0.008075 	2377s
# EarlyStopping counter: 3 out of 50
# Epoch: 136/600 	Training Loss: 0.008242 	2394s
# EarlyStopping counter: 4 out of 50
# Epoch: 137/600 	Training Loss: 0.008033 	2412s
# EarlyStopping counter: 5 out of 50
# Epoch: 138/600 	Training Loss: 0.008115 	2429s
# EarlyStopping counter: 6 out of 50
# Epoch: 139/600 	Training Loss: 0.007994 	2446s
# EarlyStopping counter: 7 out of 50
# Epoch: 140/600 	Training Loss: 0.008274 	2463s
# EarlyStopping counter: 8 out of 50
# Epoch: 141/600 	Training Loss: 0.007934 	2481s
# Epoch: 142/600 	Training Loss: 0.008017 	2498s
# EarlyStopping counter: 1 out of 50
# Epoch: 143/600 	Training Loss: 0.008228 	2515s
# EarlyStopping counter: 2 out of 50
# Epoch: 144/600 	Training Loss: 0.007995 	2533s
# EarlyStopping counter: 3 out of 50
# Epoch: 145/600 	Training Loss: 0.008254 	2550s
# EarlyStopping counter: 4 out of 50
# Epoch: 146/600 	Training Loss: 0.007929 	2567s
# Epoch: 147/600 	Training Loss: 0.008003 	2585s
# EarlyStopping counter: 1 out of 50
# Epoch: 148/600 	Training Loss: 0.008076 	2602s
# EarlyStopping counter: 2 out of 50
# Epoch: 149/600 	Training Loss: 0.008107 	2620s
# EarlyStopping counter: 3 out of 50
# Epoch: 150/600 	Training Loss: 0.007895 	2637s
# Epoch: 151/600 	Training Loss: 0.008078 	2654s
# EarlyStopping counter: 1 out of 50
# Epoch: 152/600 	Training Loss: 0.008048 	2672s
# EarlyStopping counter: 2 out of 50
# Epoch: 153/600 	Training Loss: 0.008041 	2689s
# EarlyStopping counter: 3 out of 50
# Epoch: 154/600 	Training Loss: 0.007954 	2707s
# EarlyStopping counter: 4 out of 50
# Epoch: 155/600 	Training Loss: 0.008001 	2724s
# EarlyStopping counter: 5 out of 50
# Epoch: 156/600 	Training Loss: 0.008072 	2741s
# EarlyStopping counter: 6 out of 50
# Epoch: 157/600 	Training Loss: 0.008096 	2758s
# EarlyStopping counter: 7 out of 50
# Epoch: 158/600 	Training Loss: 0.007958 	2776s
# Epoch: 159/600 	Training Loss: 0.008102 	2793s
# EarlyStopping counter: 1 out of 50
# Epoch: 160/600 	Training Loss: 0.007994 	2811s
# EarlyStopping counter: 2 out of 50
# Epoch: 161/600 	Training Loss: 0.007866 	2828s
# Epoch: 162/600 	Training Loss: 0.008126 	2846s
# EarlyStopping counter: 1 out of 50
# Epoch: 163/600 	Training Loss: 0.007916 	2863s
# EarlyStopping counter: 2 out of 50
# Epoch: 164/600 	Training Loss: 0.008007 	2880s
# EarlyStopping counter: 3 out of 50
# Epoch: 165/600 	Training Loss: 0.008021 	2898s
# EarlyStopping counter: 4 out of 50
# Epoch: 166/600 	Training Loss: 0.008243 	2915s
# Epoch: 167/600 	Training Loss: 0.007845 	2932s
# EarlyStopping counter: 1 out of 50
# Epoch: 168/600 	Training Loss: 0.007862 	2949s
# EarlyStopping counter: 2 out of 50
# Epoch: 169/600 	Training Loss: 0.007967 	2967s
# EarlyStopping counter: 3 out of 50
# Epoch: 170/600 	Training Loss: 0.008009 	2984s
# EarlyStopping counter: 4 out of 50
# Epoch: 171/600 	Training Loss: 0.007956 	3001s
# EarlyStopping counter: 5 out of 50
# Epoch: 172/600 	Training Loss: 0.007860 	3019s
# EarlyStopping counter: 6 out of 50
# Epoch: 173/600 	Training Loss: 0.008251 	3036s
# EarlyStopping counter: 7 out of 50
# Epoch: 174/600 	Training Loss: 0.007899 	3053s
# EarlyStopping counter: 8 out of 50
# Epoch: 175/600 	Training Loss: 0.007912 	3071s
# EarlyStopping counter: 9 out of 50
# Epoch: 176/600 	Training Loss: 0.008112 	3088s
# EarlyStopping counter: 10 out of 50
# Epoch: 177/600 	Training Loss: 0.007878 	3105s
# EarlyStopping counter: 11 out of 50
# Epoch: 178/600 	Training Loss: 0.007955 	3123s
# EarlyStopping counter: 12 out of 50
# Epoch: 179/600 	Training Loss: 0.007895 	3140s
# EarlyStopping counter: 13 out of 50
# Epoch: 180/600 	Training Loss: 0.007892 	3158s
# EarlyStopping counter: 14 out of 50
# Epoch: 181/600 	Training Loss: 0.007876 	3175s
# EarlyStopping counter: 15 out of 50
# Epoch: 182/600 	Training Loss: 0.008009 	3192s
# Epoch: 183/600 	Training Loss: 0.007874 	3210s
# EarlyStopping counter: 1 out of 50
# Epoch: 184/600 	Training Loss: 0.008022 	3227s
# EarlyStopping counter: 2 out of 50
# Epoch: 185/600 	Training Loss: 0.007807 	3244s
# EarlyStopping counter: 3 out of 50
# Epoch: 186/600 	Training Loss: 0.007850 	3261s
# EarlyStopping counter: 4 out of 50
# Epoch: 187/600 	Training Loss: 0.008057 	3279s
# EarlyStopping counter: 5 out of 50
# Epoch: 188/600 	Training Loss: 0.008128 	3296s
# Epoch: 189/600 	Training Loss: 0.007805 	3313s
# EarlyStopping counter: 1 out of 50
# Epoch: 190/600 	Training Loss: 0.007928 	3330s
# EarlyStopping counter: 2 out of 50
# Epoch: 191/600 	Training Loss: 0.007967 	3348s
# EarlyStopping counter: 3 out of 50
# Epoch: 192/600 	Training Loss: 0.007869 	3365s
# EarlyStopping counter: 4 out of 50
# Epoch: 193/600 	Training Loss: 0.007875 	3383s
# EarlyStopping counter: 5 out of 50
# Epoch: 194/600 	Training Loss: 0.007979 	3400s
# EarlyStopping counter: 6 out of 50
# Epoch: 195/600 	Training Loss: 0.007869 	3417s
# EarlyStopping counter: 7 out of 50
# Epoch: 196/600 	Training Loss: 0.007862 	3435s
# EarlyStopping counter: 8 out of 50
# Epoch: 197/600 	Training Loss: 0.007964 	3452s
# EarlyStopping counter: 9 out of 50
# Epoch: 198/600 	Training Loss: 0.007786 	3470s
# Epoch: 199/600 	Training Loss: 0.007827 	3488s
# EarlyStopping counter: 1 out of 50
# Epoch: 200/600 	Training Loss: 0.007976 	3505s
# EarlyStopping counter: 2 out of 50
# Epoch: 201/600 	Training Loss: 0.007829 	3522s
# EarlyStopping counter: 3 out of 50
# Epoch: 202/600 	Training Loss: 0.007938 	3540s
# EarlyStopping counter: 4 out of 50
# Epoch: 203/600 	Training Loss: 0.007899 	3557s
# Epoch: 204/600 	Training Loss: 0.007827 	3574s
# EarlyStopping counter: 1 out of 50
# Epoch: 205/600 	Training Loss: 0.008094 	3592s
# EarlyStopping counter: 2 out of 50
# Epoch: 206/600 	Training Loss: 0.007723 	3609s
# Epoch: 207/600 	Training Loss: 0.007815 	3626s
# EarlyStopping counter: 1 out of 50
# Epoch: 208/600 	Training Loss: 0.008068 	3643s
# EarlyStopping counter: 2 out of 50
# Epoch: 209/600 	Training Loss: 0.007747 	3661s
# EarlyStopping counter: 3 out of 50
# Epoch: 210/600 	Training Loss: 0.007864 	3678s
# EarlyStopping counter: 4 out of 50
# Epoch: 211/600 	Training Loss: 0.007752 	3695s
# EarlyStopping counter: 5 out of 50
# Epoch: 212/600 	Training Loss: 0.007948 	3713s
# EarlyStopping counter: 6 out of 50
# Epoch: 213/600 	Training Loss: 0.007835 	3730s
# EarlyStopping counter: 7 out of 50
# Epoch: 214/600 	Training Loss: 0.007876 	3747s
# EarlyStopping counter: 8 out of 50
# Epoch: 215/600 	Training Loss: 0.007942 	3765s
# EarlyStopping counter: 9 out of 50
# Epoch: 216/600 	Training Loss: 0.007773 	3783s
# EarlyStopping counter: 10 out of 50
# Epoch: 217/600 	Training Loss: 0.007821 	3801s
# EarlyStopping counter: 11 out of 50
# Epoch: 218/600 	Training Loss: 0.007866 	3818s
# EarlyStopping counter: 12 out of 50
# Epoch: 219/600 	Training Loss: 0.007880 	3835s
# EarlyStopping counter: 13 out of 50
# Epoch: 220/600 	Training Loss: 0.007782 	3852s
# EarlyStopping counter: 14 out of 50
# Epoch: 221/600 	Training Loss: 0.007787 	3870s
# EarlyStopping counter: 15 out of 50
# Epoch: 222/600 	Training Loss: 0.007987 	3887s
# EarlyStopping counter: 16 out of 50
# Epoch: 223/600 	Training Loss: 0.007795 	3904s
# EarlyStopping counter: 17 out of 50
# Epoch: 224/600 	Training Loss: 0.007956 	3922s
# EarlyStopping counter: 18 out of 50
# Epoch: 225/600 	Training Loss: 0.007840 	3939s
# EarlyStopping counter: 19 out of 50
# Epoch: 226/600 	Training Loss: 0.007836 	3956s
# EarlyStopping counter: 20 out of 50
# Epoch: 227/600 	Training Loss: 0.007766 	3973s
# EarlyStopping counter: 21 out of 50
# Epoch: 228/600 	Training Loss: 0.007872 	3991s
# EarlyStopping counter: 22 out of 50
# Epoch: 229/600 	Training Loss: 0.008001 	4008s
# EarlyStopping counter: 23 out of 50
# Epoch: 230/600 	Training Loss: 0.007749 	4026s
# EarlyStopping counter: 24 out of 50
# Epoch: 231/600 	Training Loss: 0.007747 	4043s
# EarlyStopping counter: 25 out of 50
# Epoch: 232/600 	Training Loss: 0.007793 	4060s
# EarlyStopping counter: 26 out of 50
# Epoch: 233/600 	Training Loss: 0.007857 	4078s
# Epoch: 234/600 	Training Loss: 0.007778 	4095s
# EarlyStopping counter: 1 out of 50
# Epoch: 235/600 	Training Loss: 0.007861 	4113s
# EarlyStopping counter: 2 out of 50
# Epoch: 236/600 	Training Loss: 0.007888 	4130s
# EarlyStopping counter: 3 out of 50
# Epoch: 237/600 	Training Loss: 0.007811 	4148s
# EarlyStopping counter: 4 out of 50
# Epoch: 238/600 	Training Loss: 0.007845 	4165s
# EarlyStopping counter: 5 out of 50
# Epoch: 239/600 	Training Loss: 0.007725 	4277s
# EarlyStopping counter: 6 out of 50
# Epoch: 240/600 	Training Loss: 0.007825 	4296s
# EarlyStopping counter: 7 out of 50
# Epoch: 241/600 	Training Loss: 0.007880 	4313s
# EarlyStopping counter: 8 out of 50
# Epoch: 242/600 	Training Loss: 0.007735 	4331s
# EarlyStopping counter: 9 out of 50
# Epoch: 243/600 	Training Loss: 0.007823 	4348s
# EarlyStopping counter: 10 out of 50
# Epoch: 244/600 	Training Loss: 0.008018 	4366s
# EarlyStopping counter: 11 out of 50
# Epoch: 245/600 	Training Loss: 0.007810 	4383s
# EarlyStopping counter: 12 out of 50
# Epoch: 246/600 	Training Loss: 0.007753 	4401s
# EarlyStopping counter: 13 out of 50
# Epoch: 247/600 	Training Loss: 0.007769 	4418s
# EarlyStopping counter: 14 out of 50
# Epoch: 248/600 	Training Loss: 0.007862 	4436s
# EarlyStopping counter: 15 out of 50
# Epoch: 249/600 	Training Loss: 0.007817 	4453s
# EarlyStopping counter: 16 out of 50
# Epoch: 250/600 	Training Loss: 0.007994 	4471s
# EarlyStopping counter: 17 out of 50
# Epoch: 251/600 	Training Loss: 0.007676 	4489s
# Epoch: 252/600 	Training Loss: 0.007800 	4506s
# EarlyStopping counter: 1 out of 50
# Epoch: 253/600 	Training Loss: 0.007750 	4524s
# EarlyStopping counter: 2 out of 50
# Epoch: 254/600 	Training Loss: 0.007811 	4541s
# EarlyStopping counter: 3 out of 50
# Epoch: 255/600 	Training Loss: 0.007726 	4559s
# EarlyStopping counter: 4 out of 50
# Epoch: 256/600 	Training Loss: 0.007891 	4576s
# EarlyStopping counter: 5 out of 50
# Epoch: 257/600 	Training Loss: 0.007716 	4594s
# EarlyStopping counter: 6 out of 50
# Epoch: 258/600 	Training Loss: 0.007778 	4611s
# EarlyStopping counter: 7 out of 50
# Epoch: 259/600 	Training Loss: 0.007739 	4629s
# EarlyStopping counter: 8 out of 50
# Epoch: 260/600 	Training Loss: 0.007837 	4646s
# EarlyStopping counter: 9 out of 50
# Epoch: 261/600 	Training Loss: 0.007799 	4664s
# EarlyStopping counter: 10 out of 50
# Epoch: 262/600 	Training Loss: 0.007779 	4681s
# EarlyStopping counter: 11 out of 50
# Epoch: 263/600 	Training Loss: 0.007756 	4699s
# EarlyStopping counter: 12 out of 50
# Epoch: 264/600 	Training Loss: 0.007859 	4716s
# EarlyStopping counter: 13 out of 50
# Epoch: 265/600 	Training Loss: 0.007754 	4734s
# EarlyStopping counter: 14 out of 50
# Epoch: 266/600 	Training Loss: 0.007733 	4751s
# EarlyStopping counter: 15 out of 50
# Epoch: 267/600 	Training Loss: 0.007794 	4769s
# EarlyStopping counter: 16 out of 50
# Epoch: 268/600 	Training Loss: 0.007725 	4786s
# EarlyStopping counter: 17 out of 50
# Epoch: 269/600 	Training Loss: 0.007819 	4803s
# EarlyStopping counter: 18 out of 50
# Epoch: 270/600 	Training Loss: 0.007924 	4821s
# EarlyStopping counter: 19 out of 50
# Epoch: 271/600 	Training Loss: 0.007665 	4838s
# EarlyStopping counter: 20 out of 50
# Epoch: 272/600 	Training Loss: 0.008020 	4855s
# EarlyStopping counter: 21 out of 50
# Epoch: 273/600 	Training Loss: 0.008303 	4873s
# EarlyStopping counter: 22 out of 50
# Epoch: 274/600 	Training Loss: 0.007711 	4890s
# EarlyStopping counter: 23 out of 50
# Epoch: 275/600 	Training Loss: 0.007748 	4908s
# EarlyStopping counter: 24 out of 50
# Epoch: 276/600 	Training Loss: 0.007727 	4925s
# EarlyStopping counter: 25 out of 50
# Epoch: 277/600 	Training Loss: 0.007891 	4943s
# EarlyStopping counter: 26 out of 50
# Epoch: 278/600 	Training Loss: 0.007779 	4960s
# EarlyStopping counter: 27 out of 50
# Epoch: 279/600 	Training Loss: 0.007897 	4978s
# EarlyStopping counter: 28 out of 50
# Epoch: 280/600 	Training Loss: 0.007682 	4995s
# EarlyStopping counter: 29 out of 50
# Epoch: 281/600 	Training Loss: 0.007714 	5013s
# EarlyStopping counter: 30 out of 50
# Epoch: 282/600 	Training Loss: 0.007766 	5030s
# EarlyStopping counter: 31 out of 50
# Epoch: 283/600 	Training Loss: 0.008104 	5048s
# EarlyStopping counter: 32 out of 50
# Epoch: 284/600 	Training Loss: 0.007709 	5065s
# EarlyStopping counter: 33 out of 50
# Epoch: 285/600 	Training Loss: 0.007672 	5083s
# EarlyStopping counter: 34 out of 50
# Epoch: 286/600 	Training Loss: 0.007873 	5100s
# EarlyStopping counter: 35 out of 50
# Epoch: 287/600 	Training Loss: 0.007677 	5118s
# EarlyStopping counter: 36 out of 50
# Epoch: 288/600 	Training Loss: 0.007776 	5135s
# EarlyStopping counter: 37 out of 50
# Epoch: 289/600 	Training Loss: 0.007687 	5153s
# EarlyStopping counter: 38 out of 50
# Epoch: 290/600 	Training Loss: 0.008126 	5170s
# EarlyStopping counter: 39 out of 50
# Epoch: 291/600 	Training Loss: 0.007631 	5187s
# EarlyStopping counter: 40 out of 50
# Epoch: 292/600 	Training Loss: 0.007832 	5205s
# EarlyStopping counter: 41 out of 50
# Epoch: 293/600 	Training Loss: 0.007698 	5222s
# EarlyStopping counter: 42 out of 50
# Epoch: 294/600 	Training Loss: 0.007740 	5239s
# EarlyStopping counter: 43 out of 50
# Epoch: 295/600 	Training Loss: 0.007881 	5257s
# EarlyStopping counter: 44 out of 50
# Epoch: 296/600 	Training Loss: 0.007749 	5274s
# EarlyStopping counter: 45 out of 50
# Epoch: 297/600 	Training Loss: 0.007700 	5292s
# Epoch: 298/600 	Training Loss: 0.007893 	5309s
# EarlyStopping counter: 1 out of 50
# Epoch: 299/600 	Training Loss: 0.007700 	5327s
# EarlyStopping counter: 2 out of 50
# Epoch: 300/600 	Training Loss: 0.007703 	5344s
# EarlyStopping counter: 3 out of 50
# Epoch: 301/600 	Training Loss: 0.007774 	5362s
# EarlyStopping counter: 4 out of 50
# Epoch: 302/600 	Training Loss: 0.007654 	5379s
# EarlyStopping counter: 5 out of 50
# Epoch: 303/600 	Training Loss: 0.007741 	5396s
# EarlyStopping counter: 6 out of 50
# Epoch: 304/600 	Training Loss: 0.007863 	5414s
# EarlyStopping counter: 7 out of 50
# Epoch: 305/600 	Training Loss: 0.007762 	5431s
# EarlyStopping counter: 8 out of 50
# Epoch: 306/600 	Training Loss: 0.007804 	5449s
# EarlyStopping counter: 9 out of 50
# Epoch: 307/600 	Training Loss: 0.007660 	5466s
# EarlyStopping counter: 10 out of 50
# Epoch: 308/600 	Training Loss: 0.007770 	5484s
# EarlyStopping counter: 11 out of 50
# Epoch: 309/600 	Training Loss: 0.007740 	5501s
# EarlyStopping counter: 12 out of 50
# Epoch: 310/600 	Training Loss: 0.007686 	5518s
# EarlyStopping counter: 13 out of 50
# Epoch: 311/600 	Training Loss: 0.007743 	5536s
# EarlyStopping counter: 14 out of 50
# Epoch: 312/600 	Training Loss: 0.007919 	5554s
# EarlyStopping counter: 15 out of 50
# Epoch: 313/600 	Training Loss: 0.007707 	5571s
# EarlyStopping counter: 16 out of 50
# Epoch: 314/600 	Training Loss: 0.007702 	5588s
# EarlyStopping counter: 17 out of 50
# Epoch: 315/600 	Training Loss: 0.007687 	5606s
# EarlyStopping counter: 18 out of 50
# Epoch: 316/600 	Training Loss: 0.007760 	5623s
# EarlyStopping counter: 19 out of 50
# Epoch: 317/600 	Training Loss: 0.007690 	5641s
# EarlyStopping counter: 20 out of 50
# Epoch: 318/600 	Training Loss: 0.007796 	5658s
# EarlyStopping counter: 21 out of 50
# Epoch: 319/600 	Training Loss: 0.007695 	5676s
# EarlyStopping counter: 22 out of 50
# Epoch: 320/600 	Training Loss: 0.007715 	5693s
# Epoch: 321/600 	Training Loss: 0.007748 	5710s
# EarlyStopping counter: 1 out of 50
# Epoch: 322/600 	Training Loss: 0.007788 	5728s
# EarlyStopping counter: 2 out of 50
# Epoch: 323/600 	Training Loss: 0.007655 	5745s
# EarlyStopping counter: 3 out of 50
# Epoch: 324/600 	Training Loss: 0.007776 	5763s
# EarlyStopping counter: 4 out of 50
# Epoch: 325/600 	Training Loss: 0.007783 	5780s
# EarlyStopping counter: 5 out of 50
# Epoch: 326/600 	Training Loss: 0.007714 	5798s
# EarlyStopping counter: 6 out of 50
# Epoch: 327/600 	Training Loss: 0.007713 	5815s
# EarlyStopping counter: 7 out of 50
# Epoch: 328/600 	Training Loss: 0.007737 	5832s
# EarlyStopping counter: 8 out of 50
# Epoch: 329/600 	Training Loss: 0.007634 	5850s
# EarlyStopping counter: 9 out of 50
# Epoch: 330/600 	Training Loss: 0.007745 	5867s
# EarlyStopping counter: 10 out of 50
# Epoch: 331/600 	Training Loss: 0.007783 	5885s
# EarlyStopping counter: 11 out of 50
# Epoch: 332/600 	Training Loss: 0.007621 	5902s
# EarlyStopping counter: 12 out of 50
# Epoch: 333/600 	Training Loss: 0.007772 	5920s
# EarlyStopping counter: 13 out of 50
# Epoch: 334/600 	Training Loss: 0.007704 	5937s
# EarlyStopping counter: 14 out of 50
# Epoch: 335/600 	Training Loss: 0.007658 	5954s
# EarlyStopping counter: 15 out of 50
# Epoch: 336/600 	Training Loss: 0.007706 	5972s
# EarlyStopping counter: 16 out of 50
# Epoch: 337/600 	Training Loss: 0.008338 	5989s
# EarlyStopping counter: 17 out of 50
# Epoch: 338/600 	Training Loss: 0.007656 	6006s
# EarlyStopping counter: 18 out of 50
# Epoch: 339/600 	Training Loss: 0.007717 	6024s
# EarlyStopping counter: 19 out of 50
# Epoch: 340/600 	Training Loss: 0.007860 	6041s
# EarlyStopping counter: 20 out of 50
# Epoch: 341/600 	Training Loss: 0.007631 	6058s
# EarlyStopping counter: 21 out of 50
# Epoch: 342/600 	Training Loss: 0.007746 	6076s
# EarlyStopping counter: 22 out of 50
# Epoch: 343/600 	Training Loss: 0.007663 	6093s
# EarlyStopping counter: 23 out of 50
# Epoch: 344/600 	Training Loss: 0.007755 	6110s
# EarlyStopping counter: 24 out of 50
# Epoch: 345/600 	Training Loss: 0.007667 	6128s
# EarlyStopping counter: 25 out of 50
# Epoch: 346/600 	Training Loss: 0.007712 	6145s
# EarlyStopping counter: 26 out of 50
# Epoch: 347/600 	Training Loss: 0.007665 	6163s
# EarlyStopping counter: 27 out of 50
# Epoch: 348/600 	Training Loss: 0.007712 	6180s
# EarlyStopping counter: 28 out of 50
# Epoch: 349/600 	Training Loss: 0.007829 	6197s
# EarlyStopping counter: 29 out of 50
# Epoch: 350/600 	Training Loss: 0.007614 	6215s
# EarlyStopping counter: 30 out of 50
# Epoch: 351/600 	Training Loss: 0.007663 	6232s
# EarlyStopping counter: 31 out of 50
# Epoch: 352/600 	Training Loss: 0.007682 	6249s
# EarlyStopping counter: 32 out of 50
# Epoch: 353/600 	Training Loss: 0.008231 	6267s
# EarlyStopping counter: 33 out of 50
# Epoch: 354/600 	Training Loss: 0.007649 	6284s
# EarlyStopping counter: 34 out of 50
# Epoch: 355/600 	Training Loss: 0.007712 	6301s
# EarlyStopping counter: 35 out of 50
# Epoch: 356/600 	Training Loss: 0.007720 	6319s
# EarlyStopping counter: 36 out of 50
# Epoch: 357/600 	Training Loss: 0.007678 	6336s
# EarlyStopping counter: 37 out of 50
# Epoch: 358/600 	Training Loss: 0.007782 	6353s
# EarlyStopping counter: 38 out of 50
# Epoch: 359/600 	Training Loss: 0.007721 	6371s
# EarlyStopping counter: 39 out of 50
# Epoch: 360/600 	Training Loss: 0.007680 	6388s
# EarlyStopping counter: 40 out of 50
# Epoch: 361/600 	Training Loss: 0.007694 	6405s
# EarlyStopping counter: 41 out of 50
# Epoch: 362/600 	Training Loss: 0.007699 	6423s
# EarlyStopping counter: 42 out of 50
# Epoch: 363/600 	Training Loss: 0.007763 	6440s
# EarlyStopping counter: 43 out of 50
# Epoch: 364/600 	Training Loss: 0.007668 	6458s
# EarlyStopping counter: 44 out of 50
# Epoch: 365/600 	Training Loss: 0.007753 	6475s
# EarlyStopping counter: 45 out of 50
# Epoch: 366/600 	Training Loss: 0.007703 	6493s
# EarlyStopping counter: 46 out of 50
# Epoch: 367/600 	Training Loss: 0.007721 	6510s
# EarlyStopping counter: 47 out of 50
# Epoch: 368/600 	Training Loss: 0.007769 	6528s
# EarlyStopping counter: 48 out of 50
# Epoch: 369/600 	Training Loss: 0.007652 	6545s
# EarlyStopping counter: 49 out of 50
# Epoch: 370/600 	Training Loss: 0.007706 	6562s
# EarlyStopping counter: 50 out of 50
# best_testloss:0.008	 epoch:319
# Early stopping

# %%
zoomin = 20
zoomout = 370
plotTraining(lossTrainArr, lossTestArr, LrCArr, bestLoss, zoomin, zoomout)

# %%
# create testdataset

damaged_img_path = 'testdataset/damaged_image' 

if lidar_mode == 'sparse':
    lidar_path = 'testdataset/lidar_tensor/sparse'
else:
    lidar_path = 'testdataset/lidar_tensor/dense'

label_path = 'testdataset/ori_image'

damaged_img_list = sorted(glob.glob(damaged_img_path + '/*'))
lidar_list = sorted(glob.glob(lidar_path + '/*'))
label_list = sorted(glob.glob(label_path + '/*'))

learning_rate = 1e-4
batch_size = 32

TestDataset = CreateDatasets(label_list, damaged_img_list, lidar_list)
new_testloader = DataLoader(dataset=TestDataset, batch_size=batch_size, shuffle=False, num_workers=0, drop_last=True)

# load model
removal_layer = nn.Sequential()

encoder_img = SimpleAutoencoder()
encoder_img.decoder = removal_layer


encoder_lidar = SimpleAutoencoder()
encoder_lidar.decoder = removal_layer


decoder = SimpleAutoencoder()
decoder.encoder = removal_layer

channelAdjust = EncoderFusion()

test_model_best = TwoEncoderOneDecoder(encoder_img, encoder_lidar, decoder, channelAdjust)
# for name, value in test_model_best.named_parameters():
#     print(name)

# test_model_last.load_state_dict(torch.load('model_save/damage_{}/last_model_{}.pth'.format(damage_label, experimentIndex)))

if lidar_mode == 'sparse':
    test_model_best.load_state_dict(
    torch.load('model_save/fusion/channeladjust_best_model_best_model_600_32_20230529_160039.pth')
)
else:
    test_model_best.load_state_dict(
    torch.load('model_save/fusion/1.pth')
)

test_model_best.eval()


dataiter = iter(new_testloader)
label, damaged_img, lidar = next(dataiter)
# label, damaged_img, lidar = next(dataiter)
# label, damaged_img, lidar = next(dataiter)
# label, damaged_img, lidar = next(dataiter)
# label, damaged_img, lidar = next(dataiter)
# label, damaged_img, lidar = next(dataiter)
# label, damaged_img, lidar = next(dataiter)
# label, damaged_img, lidar = next(dataiter)




output = test_model_best(damaged_img, lidar)

# %%
# ##################################################
# # visualize one batch of the validation images #
# ##################################################
# # test_model.to(device)


# removal_layer = nn.Sequential()

# encoder_img = SimpleAutoencoder()
# encoder_img.decoder = removal_layer


# encoder_lidar = SimpleAutoencoder()
# encoder_lidar.decoder = removal_layer


# decoder = SimpleAutoencoder()
# decoder.encoder = removal_layer

# channelAdjust = EncoderFusion()

# test_model_best = TwoEncoderOneDecoder(encoder_img, encoder_lidar, decoder, channelAdjust)
# # for name, value in test_model_best.named_parameters():
# #     print(name)

# if lidar_mode == 'sparse':
#     test_model_best.load_state_dict(
#     torch.load('model_save/fusion/6_channeladjust_sparse_best_model_best_model_600_32_20230522_154333.pth')
# )
# else:
#     test_model_best.load_state_dict(
#     torch.load('model_save/fusion/3_dense_best_model_600_32_20230522_072759.pth')
# )

# test_model.to(device)
# test_model_last.eval()
test_model_best.eval()


# obtain one batch of test images
dataiter = iter(new_testloader)
# dataiter = iter(valloader)

label, damaged_img, lidar = next(dataiter)

# get sample outputs
output = test_model_best(damaged_img, lidar)

# prep images for display
# i = 31
for i in range(32):

    img1 = label[i].numpy()
    img1 = img1.transpose(1, 2, 0)
    img2 = damaged_img[i].numpy()
    img2 = img2.transpose(1, 2, 0)
    img3 = lidar[i].detach().numpy()
    img3 = img3.transpose(1, 2, 0)
    img4 = output[i].detach().numpy()
    img4 = img4.transpose(1, 2, 0)


    ax = plt.subplot(1, 4, 1)
    plt.xticks([])
    plt.yticks([])
    # ax.set_title('label')
    plt.imshow(img1,cmap='gray')

    ax = plt.subplot(1, 4, 2)
    plt.xticks([])
    plt.yticks([])
    # ax.set_title('damaged image')
    plt.imshow(img2,cmap='gray')

    ax = plt.subplot(1, 4, 3)
    plt.xticks([])
    plt.yticks([])
    # ax.set_title('lidar')
    plt.imshow(img3)

    ax = plt.subplot(1, 4, 4)
    plt.xticks([])
    plt.yticks([])
    #  ax.set_title('reconstructed image')
    plt.imshow(img4, cmap='gray')

    # plt.savefig('fig_save/{}.png'.format(i))
    
plt.show()

# %%
import cv2
from PIL import Image
from torchvision import transforms
from matplotlib import pyplot as plt


toPIL = transforms.ToPILImage()

# # prep images for display
# for i in range(32):
#     img1 = label[i]
#     img2 = damaged_img[i]
#     img3 = lidar[i]
#     img4 = output[i]
#     # print(img1.shape, img3.shape)
#     # print(type(img1),type(img3))
#     # im1 = toPIL(img1)
#     im4 = toPIL(img4)
#     im3 = toPIL(img3)
#     name = '%02d' %i

#     # im1.save('RecosntructedImages/ori_img/{}.png'.format(name))
#     # im2.save('RecosntructedImages/masked_img/{}.png'.format(name))
#     # im4.save('output_save/5_main_fusion_3_dense/A/{}.png'.format(name))
#     im3.save('output_save/lidar_sparse_testing/{}.png'.format(name))

    
import numpy as np
import cv2

for i in range(32):
    if i ==13:
        img1 = label[i].numpy()
        img1 = img1.transpose(1, 2, 0)
        img2 = damaged_img[i].numpy()
        img2 = img2.transpose(1, 2, 0)
        img3 = lidar[i].detach().numpy()
        img3 = img3.transpose(1, 2, 0)
        img4 = output[i].detach().numpy()
        img4 = img4.transpose(1, 2, 0)

        name = '%02d' %i
        filepath = 'output_save/test/{}.png'.format(name)

        # 调用函数将灰度图像保存为RGB图像的PNG
        # cv2.imwrite(filepath, img4)
        plt.xticks([])
        plt.yticks([])
        plt.imshow(img4, cmap='gray')
        plt.savefig(filepath)
        plt.show()

# %%
# MSE for all damages
criterion = nn.MSELoss()
criterion.to(device)

for i, batch in enumerate(new_testloader):# i -->index of batch
    count = 0
    for j in range (batch_size):
        img1 = label[i]
        img3 = output[i]
        mse = criterion(img1,img3)
        mse = round(mse.item(),6)
        count = count+mse

    mse_mean = round(count,6)
    print(mse_mean)
# Out:
# 3.195712
# 5.16768
# 2.736672
# 5.462848
# 4.709056
# 1.260096
# 2.558624
# 3.728448

# %%
# # regional mse

# batch_size = 32

# def create_mask(image_shape, block_size, num_blocks):
#     mask = np.ones(image_shape, dtype=np.float32) 
#     block_size_px = (int(image_shape[0] * block_size), int(image_shape[1] * block_size))
#     np.random.seed(6)

#     for _ in range(num_blocks):
#         top_left = np.random.randint(0, image_shape[0] - block_size_px[0] + 1), np.random.randint(0, image_shape[1] - block_size_px[1] + 1)
#         bottom_right = top_left[0] + block_size_px[0], top_left[1] + block_size_px[1]
#         mask[top_left[0]:bottom_right[0], top_left[1]:bottom_right[1]] = 0
        
#     return mask


# block_size = 0.2  # 方块大小为原图大小的百分比
# num_blocks = 16  # 方块数量

# count = 0

# for j in range(label.size(0)):
#     ori_img_np = label[j][0].detach().numpy()
#     output_np = output[j][0].detach().numpy()
#     mask = create_mask(ori_img_np.shape[:2], block_size, num_blocks)
#     local_mse = np.mean(np.square(output_np - ori_img_np) * mask)
#     count = count+local_mse
# local_mse = round(count/batch_size, 6)

# # baseline
# for j in range(label.size(0)):
#     ori_img_np = label[j][0].detach().numpy()
#     output_np = output[j][0].detach().numpy()
#     mask = create_mask(ori_img_np.shape[:2], block_size, num_blocks)
#     local_mse = np.mean(np.square(output_np - ori_img_np) * mask)
#     count = count+local_mse
# local_mse = round(count/batch_size, 6)

# print(local_mse)

# %%
import cv2
import os
import numpy

masked_region_list = []
original_image_list = []

image_path = 'testdataset/ori_image'
images = sorted(glob.glob(image_path + '/*'))[0:32]
damage_label = 'A'

def create_mask(image_shape, block_size, num_blocks):
    mask = np.ones(image_shape, dtype=np.float32) 
    block_size_px = (int(image_shape[0] * block_size), int(image_shape[1] * block_size))
    np.random.seed(6)
    masked_region = []

    for _ in range(num_blocks):
        top_left = np.random.randint(0, image_shape[0] - block_size_px[0] + 1), np.random.randint(0, image_shape[1] - block_size_px[1] + 1)
        bottom_right = top_left[0] + block_size_px[0], top_left[1] + block_size_px[1]
        mask[top_left[0]:bottom_right[0], top_left[1]:bottom_right[1]] = 0
        masked_region.append((top_left, bottom_right))
        
    return mask, masked_region


for i in range(len(images)):
    image = cv2.imread(images[i])
    image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    ori_img_name = os.path.basename(images[i])

    block_size = 0.2  # 方块大小为原图大小的百分比
    num_blocks = 16  # 方块数量
    mask, masked_region = create_mask(image.shape[:2], block_size, num_blocks)
    masked_region_list.append(masked_region)
    original_image_list.append(image)
    damaged_img1 = image * mask
    # cv2.imwrite(f'testdataset/damaged_image/{damage_label}_{ori_img_name}', damaged_img1)

regional_mse_list = []

for i in range(len(images)):
    original_image = original_image_list[i]
    masked_region = masked_region_list[i]
    original_image = (original_image-np.min(original_image))/(np.max(original_image)-np.min(original_image))
    

    
    # Obtain the output reconstructed image
    output_image = output[i][0].detach().numpy()  # Replace this with the code to get the output image from your image reconstruction network
    # output_image = (output_image-np.min(output_image))/(np.max(output_image)-np.min(output_image))
    
    mse = 0
    num_pixels = 0

    for region in masked_region:
        top_left, bottom_right = region
        original_pixels = original_image[top_left[0]:bottom_right[0], top_left[1]:bottom_right[1]]
        output_pixels = output_image[top_left[0]:bottom_right[0], top_left[1]:bottom_right[1]]
        diff = original_pixels.astype(np.float32) - output_pixels.astype(np.float32)
        mse += np.sum(diff ** 2)
        num_pixels += original_pixels.size

    mse /= num_pixels
    regional_mse_list.append(mse)

print(np.mean(regional_mse_list))
# Out:
# 0.23760913690974117

# %%
# import numpy as np
# batchsize = 32
# def mse(image1, image2, mask):
#     masked_image1 = image1 * mask
#     masked_image2 = image2 * mask
#     diff = masked_image1 - masked_image2
#     mse_value = np.mean(np.square(diff))
#     return mse_value

# def create_mask(image_shape, block_size, num_blocks):
#     mask = np.ones(image_shape, dtype=np.float32) 
#     block_size_px = (int(image_shape[0] * block_size), int(image_shape[1] * block_size))
#     np.random.seed(6)

#     for _ in range(num_blocks):
#         top_left = np.random.randint(0, image_shape[0] - block_size_px[0] + 1), np.random.randint(0, image_shape[1] - block_size_px[1] + 1)
#         bottom_right = top_left[0] + block_size_px[0], top_left[1] + block_size_px[1]
#         mask[top_left[0]:bottom_right[0], top_left[1]:bottom_right[1]] = 0
        
#     return mask

# count = 0
# shape = (200, 200)
# block_size = 0.2
# num_blocks =16
# mask = create_mask(shape, block_size, num_blocks)

# for j in range(batchsize):
#     original_image = label[j][0].detach().numpy()
#     output_image = output[j][0].detach().numpy()
#     mask_mse = mse(output_image, original_image, mask)
#     count += mask_mse
     
# print(count/batchsize)
# Out:
# 0.004185696510830894

# %%
# SSIM

import torch
from skimage.metrics import structural_similarity as ssim
import glob


metric_value_list = []
batch_size = 32


for i, batch in enumerate(new_testloader):
    label, damaged_img, lidar = batch
    count = 0
    for j in range(label.size(0)):
        ori_img_np = label[j][0].detach().cpu().numpy()
        output_np = output[j][0].detach().cpu().numpy()
        ssim_img, diff = ssim(ori_img_np, output_np, full=True, data_range=1.0)
        count = count + ssim_img
    ssim_img = round(count / label.size(0), 3)
    print(ssim_img)
#     metric_value_list.append(ssim_img)

# print(metric_value_list)
# Out:
# 0.446
# 0.109
# 0.103
# 0.095
# 0.098
# 0.099
# 0.102
# 0.105

# %%
# LLIPS metrics

import lpips

loss_fn = lpips.LPIPS(net='alex')


for i, batch in enumerate(new_testloader):  # i -->index of batch
    label, damaged_img, lidar = batch
    count = 0
    for j in range(label.size(0)):
        # ori_img_np = ori_img[j][0].detach().numpy()
        # output_np = output[j][0].detach().numpy()
        lpips_img = loss_fn.forward(label, output)
        sum_result = (torch.sum(lpips_img)).item()
        count = count+sum_result
        # count = count.item()
    lpips_img = round(count/label.size(0),3)
    print(lpips_img)
#     metric_value_list.append(lpips_img)

# print(f'scuccess: {metric_value_list}')
# Out:
# Setting up [LPIPS] perceptual loss: trunk [alex], v[0.1], spatial [off]
# Loading model from: /usr/local/Anaconda3-2021.11-Linux-x86_64/envs/pytorch/lib/python3.8/site-packages/lpips/weights/v0.1/alex.pth
# 15.819
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [12], in <cell line: 8>()
#      10 count = 0
#      11 for j in range(label.size(0)):
#      12     # ori_img_np = ori_img[j][0].detach().numpy()
#      13     # output_np = output[j][0].detach().numpy()
# ---> 14     lpips_img = loss_fn.forward(label, output)
#      15     sum_result = (torch.sum(lpips_img)).item()
#      16     count = count+sum_result
#
# File /usr/local/Anaconda3-2021.11-Linux-x86_64/envs/pytorch/lib/python3.8/site-packages/lpips/lpips.py:100, in LPIPS.forward(self, in0, in1, retPerLayer, normalize)
#      98         res = [upsample(self.lins[kk].model(diffs[kk]), out_HW=in0.shape[2:]) for kk in range(self.L)]
#      99     else:
# --> 100         res = [spatial_average(self.lins[kk].model(diffs[kk]), keepdim=True) for kk in range(self.L)]
#     101 else:
#     102     if(self.spatial):
#
# File /usr/local/Anaconda3-2021.11-Linux-x86_64/envs/pytorch/lib/python3.8/site-packages/lpips/lpips.py:100, in <listcomp>(.0)
#      98         res = [upsample(self.lins[kk].model(diffs[kk]), out_HW=in0.shape[2:]) for kk in range(self.L)]
#      99     else:
# --> 100         res = [spatial_average(self.lins[kk].model(diffs[kk]), keepdim=True) for kk in range(self.L)]
#     101 else:
#     102     if(self.spatial):
#
# File /usr/local/Anaconda3-2021.11-Linux-x86_64/envs/pytorch/lib/python3.8/site-packages/torch/nn/modules/module.py:1102, in Module._call_impl(self, *input, **kwargs)
#    1098 # If we don't have any hooks, we want to skip the rest of the logic in
#    1099 # this function, and just call forward.
#    1100 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102     return forward_call(*input, **kwargs)
#    1103 # Do not call functions when jit is used
#    1104 full_backward_hooks, non_full_backward_hooks = [], []
#
# File /usr/local/Anaconda3-2021.11-Linux-x86_64/envs/pytorch/lib/python3.8/site-packages/torch/nn/modules/container.py:141, in Sequential.forward(self, input)
#     139 def forward(self, input):
#     140     for module in self:
# --> 141         input = module(input)
#     142     return input
#
# File /usr/local/Anaconda3-2021.11-Linux-x86_64/envs/pytorch/lib/python3.8/site-packages/torch/nn/modules/module.py:1102, in Module._call_impl(self, *input, **kwargs)
#    1098 # If we don't have any hooks, we want to skip the rest of the logic in
#    1099 # this function, and just call forward.
#    1100 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102     return forward_call(*input, **kwargs)
#    1103 # Do not call functions when jit is used
#    1104 full_backward_hooks, non_full_backward_hooks = [], []
#
# File /usr/local/Anaconda3-2021.11-Linux-x86_64/envs/pytorch/lib/python3.8/site-packages/torch/nn/modules/conv.py:446, in Conv2d.forward(self, input)
#     445 def forward(self, input: Tensor) -> Tensor:
# --> 446     return self._conv_forward(input, self.weight, self.bias)
#
# File /usr/local/Anaconda3-2021.11-Linux-x86_64/envs/pytorch/lib/python3.8/site-packages/torch/nn/modules/conv.py:442, in Conv2d._conv_forward(self, input, weight, bias)
#     438 if self.padding_mode != 'zeros':
#     439     return F.conv2d(F.pad(input, self._reversed_padding_repeated_twice, mode=self.padding_mode),
#     440                     weight, bias, self.stride,
#     441                     _pair(0), self.dilation, self.groups)
# --> 442 return F.conv2d(input, weight, bias, self.stride,
#     443                 self.padding, self.dilation, self.groups)
#
# KeyboardInterrupt:

# %%
# edge detection metric

output_images_folder = 'output_images'  # Specify the folder to save the output images

for i in range(len(images)):
    original_image = original_image_list[i]
    masked_region = masked_region_list[i]

    # Obtain the output reconstructed image
    output_image = ...  # Replace this with the code to get the output image from your image reconstruction network

    for j, region in enumerate(masked_region):
        top_left, bottom_right = region
        region_name = f'region_{j+1}.png'
        region_image = output_image[top_left[0]:bottom_right[0], top_left[1]:bottom_right[1]]
        region_path = os.path.join(output_images_folder, region_name)
        cv2.imwrite(region_path, region_image)
