# %%
# early fusion at the input

# %%
from matplotlib import pyplot as plt
from torch.utils.data import DataLoader
from sensorFusionDataset.creatDataset_2_encoder import CreateDatasets
from sensorFusionDataset.data_split import split_dataset
from sensorFusionNetwork.simpleAutoencoder_late import SimpleAutoencoder
from testLoop import test_loop_fusion
from trainLoop import train_loop_fusion
from visualization import plot_losses, plot_metrics,plotTraining
from earlystopping import EarlyStopping

import h5py as h5
from datetime import datetime
import copy
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import glob
import time

local_time =time.strftime("%Y-%m-%d %H:%M:%S", time.localtime())[-8:-1]
now = datetime.now()
dt_string = now.strftime("%Y%m%d_%H%M%S")
# CPU OR GPU
device = 'cuda' if torch.cuda.is_available() else 'cpu'

damaged_img_path = 'image_gray_200_damaged' 

lidar_mode = 'sparse'

if lidar_mode == 'sparse':
    lidar_path = 'lidar_tesor_200_sparse'
else:
    lidar_path = 'lidar_tesor_200_dense'

label_path = 'image_gray_200_original'

damaged_img_list = sorted(glob.glob(damaged_img_path + '/*'))[0:7200]
lidar_list = sorted(glob.glob(lidar_path + '/*'))[0:7200]
label_list = sorted(glob.glob(label_path + '/*'))[0:7200]


batch_size = 32
learning_rate = 1e-4
epochs = 300

MyDataset = CreateDatasets(label_list, damaged_img_list, lidar_list)#, img_size=img_size
train_dataset, test_dataset, val_dataset = split_dataset(MyDataset, 0.7, 0.2)
train_loader = DataLoader(dataset=train_dataset, batch_size=batch_size, shuffle=True, num_workers=0,
                          drop_last=True)
test_loader = DataLoader(dataset=test_dataset, batch_size=batch_size, shuffle=True, num_workers=0,
                         drop_last=True)
val_loader = DataLoader(dataset=val_dataset, batch_size=batch_size, shuffle=False, num_workers=0,
                        drop_last=True)

patience = 50	# 当验证集损失在连续20次训练周期中都没有得到降低时，停止模型训练，以防止模型过拟合
save_path = 'fusion_model/'
early_stopping = EarlyStopping(save_path = save_path, patience = patience)	

criterion = nn.MSELoss()

training_loss = []
training_baseloss = []
test_loss = []
testing_baseloss = []
hisLrC = []
min_loss=10000

print (f'loading fertig! {device}' )
# Out:
# loading fertig! cuda

# %%
# retraining with the channel adjust
# loading model

fusion_net = SimpleAutoencoder()
fusion_net.to(device)

learning_rate = 0.0004  # 2e-4 batchsize=30
optimizer = torch.optim.Adam(fusion_net.parameters(), lr=learning_rate)

criterion = nn.MSELoss()
criterion.to(device)


start_time = time.time()
for epoch in range(1, epochs + 1):
    # monitor training loss
    ##############################
    # start training the model #
    ##############################
    hisLrC.append(epoch)
    train_epoch_loss, train_epoch_baseloss = train_loop_fusion(train_loader, fusion_net, criterion, optimizer, device)
    training_loss.append(train_epoch_loss)
    # training_baseloss.append(train_epoch_baseloss)
    print('Epoch: {}/{} \tTraining Loss: {:.6f} \t{:.0f}s'.format(epoch, epochs, train_epoch_loss,
                                                                  time.time() - start_time))

    ##############################
    # start testing the model #
    ##############################
    with torch.no_grad():
        test_epoch_loss, test_epoch_baseloss = test_loop_fusion(test_loader, fusion_net, criterion, device)
        test_loss.append(test_epoch_loss)
        # testing_baseloss.append(test_epoch_baseloss)
        
    # type(train_epoch_loss)) ---> float
    # writer.add_scalars('loss', {'training loss': train_epoch_loss, 'test loss': test_epoch_loss}, epoch)

        
    if test_epoch_loss < min_loss:
        min_loss = test_epoch_loss
        best_model_wts = copy.deepcopy(fusion_net.state_dict())
       

    if epoch == epochs:
        torch.save(best_model_wts, 'model_save/fusion/12_early_best_model_{}_{}_{}.pth'.format(epochs, batch_size,dt_string))
        print('best_testloss:{:.3f}\t epoch:{}'.format(min_loss, test_loss.index(min_loss)))     

    # 早停止
    date = dt_string
    early_stopping(test_epoch_loss, fusion_net, date)
    #达到早停止条件时，early_stop会被置为True
    if early_stopping.early_stop:
        torch.save(best_model_wts, 'model_save/fusion/12_early_best_model_{}_{}_{}.pth'.format(epochs, batch_size,dt_string))
        # torch.save(fusion_net.state_dict(), 'Experiment2_sequence_inverse/fusion_model/last_model_{}_{}_{}.pth'.format(epochs, batch_size,dt_string))
        print('best_testloss:{:.3f}\t epoch:{}'.format(min_loss, test_loss.index(min_loss)))  
        print("Early stopping")
        break #跳出迭代，结束训练    
    
# train_baseline = sum(training_baseloss)/len(training_baseloss)
# test_baseline = sum(testing_baseloss)/len(training_baseloss)
# psnr_baseline = np.mean(psnr_base_list)

# train_baseline=train_baseline.item()
# test_baseline =test_baseline.item()
last_trainingloss = training_loss[-1]
last_testloss = test_loss[-1]


# write the dataset in one existed h5-file
now = datetime.now()
dt_string = now.strftime("%Y%m%d_%H%M%S")

lossTrainArr = np.array(training_loss)
lossTestArr = np.array(test_loss)
bestLoss = np.array([min_loss])
LrCArr = np.array(hisLrC)

h5f =h5.File(f"log/recording_{dt_string}.hdf5","w")
# h5f = h5.File('train/train.h5', 'r+') # write in an exsited h5 file
g1 = h5f.create_group('log1')
g1.attrs['data']=now.strftime("%Y-%m-%d")
# g1.attrs['model']=ModelWts
# g1.attrs['optLrOrg']=str(optLrOrg)+'={:3.1e}'.format(optLrOrg) 
# g1.attrs['lrAdstep']= str(lrAdstep)
# g1.attrs['optimizer']= str(optimizer)[:4]

g1.create_dataset('lossTrain', data=lossTrainArr)
g1.create_dataset('lossTest', data=lossTestArr)
g1.create_dataset('bestLoss', data=bestLoss)
g1.create_dataset('LrCArr', data=LrCArr)
h5f.close()

# print('train_baseline:{:.3f} \t test_baseline:{:.3f} \t last trainingloss:{:.3f} \t last testloss:{:.3f}'.format(train_baseline, test_baseline,last_trainingloss,last_testloss))
# Out:
# Epoch: 1/300 	Training Loss: 1.640037 	22s
# Epoch: 2/300 	Training Loss: 1.353930 	45s
# Epoch: 3/300 	Training Loss: 1.246253 	68s
# Epoch: 4/300 	Training Loss: 1.158116 	91s
# Epoch: 5/300 	Training Loss: 1.119323 	114s
# Epoch: 6/300 	Training Loss: 1.065004 	137s
# Epoch: 7/300 	Training Loss: 1.019956 	160s
# Epoch: 8/300 	Training Loss: 0.974286 	183s
# Epoch: 9/300 	Training Loss: 0.939738 	207s
# Epoch: 10/300 	Training Loss: 0.915595 	230s
# Epoch: 11/300 	Training Loss: 0.875091 	252s
# Epoch: 12/300 	Training Loss: 0.831154 	276s
# Epoch: 13/300 	Training Loss: 0.796717 	299s
# Epoch: 14/300 	Training Loss: 0.773443 	322s
# Epoch: 15/300 	Training Loss: 0.748529 	345s
# EarlyStopping counter: 1 out of 50
# Epoch: 16/300 	Training Loss: 0.738707 	367s
# Epoch: 17/300 	Training Loss: 0.699503 	390s
# Epoch: 18/300 	Training Loss: 0.688058 	412s
# EarlyStopping counter: 1 out of 50
# Epoch: 19/300 	Training Loss: 0.686393 	435s
# EarlyStopping counter: 2 out of 50
# Epoch: 20/300 	Training Loss: 0.656450 	458s
# Epoch: 21/300 	Training Loss: 0.634921 	481s
# EarlyStopping counter: 1 out of 50
# Epoch: 22/300 	Training Loss: 0.622279 	504s
# Epoch: 23/300 	Training Loss: 0.620087 	527s
# Epoch: 24/300 	Training Loss: 0.618570 	550s
# EarlyStopping counter: 1 out of 50
# Epoch: 25/300 	Training Loss: 0.607153 	573s
# Epoch: 26/300 	Training Loss: 0.584295 	595s
# EarlyStopping counter: 1 out of 50
# Epoch: 27/300 	Training Loss: 0.569052 	618s
# Epoch: 28/300 	Training Loss: 0.558768 	641s
# Epoch: 29/300 	Training Loss: 0.568841 	665s
# EarlyStopping counter: 1 out of 50
# Epoch: 30/300 	Training Loss: 0.547145 	688s
# EarlyStopping counter: 2 out of 50
# Epoch: 31/300 	Training Loss: 0.534301 	711s
# Epoch: 32/300 	Training Loss: 0.531399 	734s
# EarlyStopping counter: 1 out of 50
# Epoch: 33/300 	Training Loss: 0.531035 	757s
# Epoch: 34/300 	Training Loss: 0.524453 	780s
# EarlyStopping counter: 1 out of 50
# Epoch: 35/300 	Training Loss: 0.513578 	803s
# Epoch: 36/300 	Training Loss: 0.507420 	826s
# EarlyStopping counter: 1 out of 50
# Epoch: 37/300 	Training Loss: 0.480327 	849s
# EarlyStopping counter: 2 out of 50
# Epoch: 38/300 	Training Loss: 0.487710 	872s
# Epoch: 39/300 	Training Loss: 0.493742 	895s
# EarlyStopping counter: 1 out of 50
# Epoch: 40/300 	Training Loss: 0.490179 	918s
# EarlyStopping counter: 2 out of 50
# Epoch: 41/300 	Training Loss: 0.486476 	941s
# Epoch: 42/300 	Training Loss: 0.463952 	964s
# EarlyStopping counter: 1 out of 50
# Epoch: 43/300 	Training Loss: 0.449058 	987s
# EarlyStopping counter: 2 out of 50
# Epoch: 44/300 	Training Loss: 0.466900 	1009s
# EarlyStopping counter: 3 out of 50
# Epoch: 45/300 	Training Loss: 0.452744 	1031s
# EarlyStopping counter: 4 out of 50
# Epoch: 46/300 	Training Loss: 0.437388 	1053s
# EarlyStopping counter: 5 out of 50
# Epoch: 47/300 	Training Loss: 0.445802 	1075s
# Epoch: 48/300 	Training Loss: 0.448403 	1097s
# EarlyStopping counter: 1 out of 50
# Epoch: 49/300 	Training Loss: 0.445662 	1120s
# EarlyStopping counter: 2 out of 50
# Epoch: 50/300 	Training Loss: 0.436111 	1142s
# EarlyStopping counter: 3 out of 50
# Epoch: 51/300 	Training Loss: 0.420150 	1164s
# Epoch: 52/300 	Training Loss: 0.422383 	1187s
# EarlyStopping counter: 1 out of 50
# Epoch: 53/300 	Training Loss: 0.429591 	1210s
# EarlyStopping counter: 2 out of 50
# Epoch: 54/300 	Training Loss: 0.419300 	1233s
# EarlyStopping counter: 3 out of 50
# Epoch: 55/300 	Training Loss: 0.405374 	1257s
# Epoch: 56/300 	Training Loss: 0.420128 	1279s
# EarlyStopping counter: 1 out of 50
# Epoch: 57/300 	Training Loss: 0.427266 	1302s
# Epoch: 58/300 	Training Loss: 0.412693 	1326s
# EarlyStopping counter: 1 out of 50
# Epoch: 59/300 	Training Loss: 0.397102 	1349s
# Epoch: 60/300 	Training Loss: 0.395537 	1372s
# EarlyStopping counter: 1 out of 50
# Epoch: 61/300 	Training Loss: 0.389818 	1395s
# EarlyStopping counter: 2 out of 50
# Epoch: 62/300 	Training Loss: 0.393557 	1418s
# Epoch: 63/300 	Training Loss: 0.386244 	1441s
# EarlyStopping counter: 1 out of 50
# Epoch: 64/300 	Training Loss: 0.396542 	1462s
# EarlyStopping counter: 2 out of 50
# Epoch: 65/300 	Training Loss: 0.390790 	1484s
# EarlyStopping counter: 3 out of 50
# Epoch: 66/300 	Training Loss: 0.374498 	1507s
# EarlyStopping counter: 4 out of 50
# Epoch: 67/300 	Training Loss: 0.373427 	1530s
# EarlyStopping counter: 5 out of 50
# Epoch: 68/300 	Training Loss: 0.376613 	1553s
# Epoch: 69/300 	Training Loss: 0.394735 	1577s
# EarlyStopping counter: 1 out of 50
# Epoch: 70/300 	Training Loss: 0.381785 	1599s
# EarlyStopping counter: 2 out of 50
# Epoch: 71/300 	Training Loss: 0.367360 	1622s
# EarlyStopping counter: 3 out of 50
# Epoch: 72/300 	Training Loss: 0.365907 	1644s
# EarlyStopping counter: 4 out of 50
# Epoch: 73/300 	Training Loss: 0.358681 	1667s
# Epoch: 74/300 	Training Loss: 0.365934 	1691s
# EarlyStopping counter: 1 out of 50
# Epoch: 75/300 	Training Loss: 0.356002 	1714s
# EarlyStopping counter: 2 out of 50
# Epoch: 76/300 	Training Loss: 0.391202 	1737s
# EarlyStopping counter: 3 out of 50
# Epoch: 77/300 	Training Loss: 0.372509 	1760s
# EarlyStopping counter: 4 out of 50
# Epoch: 78/300 	Training Loss: 0.352738 	1783s
# EarlyStopping counter: 5 out of 50
# Epoch: 79/300 	Training Loss: 0.360046 	1805s
# Epoch: 80/300 	Training Loss: 0.350849 	1827s
# Epoch: 81/300 	Training Loss: 0.349244 	1850s
# EarlyStopping counter: 1 out of 50
# Epoch: 82/300 	Training Loss: 0.346115 	1873s
# EarlyStopping counter: 2 out of 50
# Epoch: 83/300 	Training Loss: 0.348294 	1897s
# EarlyStopping counter: 3 out of 50
# EarlyStopping counter: 4 out of 50
# Epoch: 85/300 	Training Loss: 0.335107 	1942s
# EarlyStopping counter: 5 out of 50
# Epoch: 86/300 	Training Loss: 0.332700 	1965s
# EarlyStopping counter: 6 out of 50
# Epoch: 87/300 	Training Loss: 0.344379 	1988s
# EarlyStopping counter: 7 out of 50
# Epoch: 88/300 	Training Loss: 0.343777 	2010s
# EarlyStopping counter: 8 out of 50
# Epoch: 89/300 	Training Loss: 0.337121 	2033s
# EarlyStopping counter: 9 out of 50
# Epoch: 90/300 	Training Loss: 0.336798 	2054s
# Epoch: 91/300 	Training Loss: 0.335947 	2077s
# EarlyStopping counter: 1 out of 50
# Epoch: 92/300 	Training Loss: 0.327804 	2100s
# Epoch: 93/300 	Training Loss: 0.332767 	2123s
# EarlyStopping counter: 1 out of 50
# Epoch: 94/300 	Training Loss: 0.323314 	2146s
# Epoch: 95/300 	Training Loss: 0.321724 	2169s
# EarlyStopping counter: 1 out of 50
# Epoch: 96/300 	Training Loss: 0.319473 	2192s
# EarlyStopping counter: 2 out of 50
# Epoch: 97/300 	Training Loss: 0.329779 	2215s
# EarlyStopping counter: 3 out of 50
# Epoch: 98/300 	Training Loss: 0.336928 	2238s
# Epoch: 99/300 	Training Loss: 0.319765 	2261s
# EarlyStopping counter: 1 out of 50
# Epoch: 100/300 	Training Loss: 0.332862 	2285s
# EarlyStopping counter: 2 out of 50
# Epoch: 101/300 	Training Loss: 0.318921 	2308s
# EarlyStopping counter: 3 out of 50
# Epoch: 102/300 	Training Loss: 0.312654 	2330s
# EarlyStopping counter: 4 out of 50
# Epoch: 103/300 	Training Loss: 0.333315 	2353s
# EarlyStopping counter: 5 out of 50
# Epoch: 104/300 	Training Loss: 0.321357 	2376s
# EarlyStopping counter: 6 out of 50
# Epoch: 105/300 	Training Loss: 0.310913 	2399s
# Epoch: 106/300 	Training Loss: 0.330027 	2422s
# EarlyStopping counter: 1 out of 50
# Epoch: 107/300 	Training Loss: 0.309208 	2445s
# EarlyStopping counter: 2 out of 50
# Epoch: 108/300 	Training Loss: 0.304935 	2468s
# EarlyStopping counter: 3 out of 50
# Epoch: 109/300 	Training Loss: 0.305470 	2489s
# EarlyStopping counter: 4 out of 50
# Epoch: 110/300 	Training Loss: 0.312990 	2511s
# EarlyStopping counter: 5 out of 50
# Epoch: 111/300 	Training Loss: 0.314728 	2534s
# EarlyStopping counter: 6 out of 50
# Epoch: 112/300 	Training Loss: 0.305436 	2557s
# Epoch: 113/300 	Training Loss: 0.301044 	2579s
# EarlyStopping counter: 1 out of 50
# Epoch: 114/300 	Training Loss: 0.322951 	2611s
# EarlyStopping counter: 2 out of 50
# Epoch: 115/300 	Training Loss: 0.301748 	2780s
# EarlyStopping counter: 3 out of 50
# Epoch: 116/300 	Training Loss: 0.303547 	2803s
# EarlyStopping counter: 4 out of 50
# Epoch: 117/300 	Training Loss: 0.309089 	2826s
# EarlyStopping counter: 5 out of 50
# Epoch: 118/300 	Training Loss: 0.324461 	2847s
# EarlyStopping counter: 6 out of 50
# Epoch: 119/300 	Training Loss: 0.303520 	2870s
# EarlyStopping counter: 7 out of 50
# Epoch: 120/300 	Training Loss: 0.293611 	2893s
# EarlyStopping counter: 8 out of 50
# Epoch: 121/300 	Training Loss: 0.304352 	2916s
# Epoch: 122/300 	Training Loss: 0.297824 	2939s
# EarlyStopping counter: 1 out of 50
# Epoch: 123/300 	Training Loss: 0.304702 	2962s
# EarlyStopping counter: 2 out of 50
# Epoch: 124/300 	Training Loss: 0.296665 	2985s
# Epoch: 125/300 	Training Loss: 0.287688 	3009s
# EarlyStopping counter: 1 out of 50
# Epoch: 126/300 	Training Loss: 0.289061 	3032s
# EarlyStopping counter: 2 out of 50
# Epoch: 127/300 	Training Loss: 0.351593 	3055s
# EarlyStopping counter: 3 out of 50
# Epoch: 128/300 	Training Loss: 0.292896 	3078s
# Epoch: 129/300 	Training Loss: 0.291941 	3100s
# Epoch: 130/300 	Training Loss: 0.287931 	3123s
# EarlyStopping counter: 1 out of 50
# Epoch: 131/300 	Training Loss: 0.294684 	3146s
# EarlyStopping counter: 2 out of 50
# Epoch: 132/300 	Training Loss: 0.312826 	3168s
# Epoch: 133/300 	Training Loss: 0.291252 	3191s
# EarlyStopping counter: 1 out of 50
# Epoch: 134/300 	Training Loss: 0.285769 	3214s
# EarlyStopping counter: 2 out of 50
# Epoch: 135/300 	Training Loss: 0.288700 	3238s
# EarlyStopping counter: 3 out of 50
# Epoch: 136/300 	Training Loss: 0.283406 	3261s
# Epoch: 137/300 	Training Loss: 0.297295 	3284s
# EarlyStopping counter: 1 out of 50
# Epoch: 138/300 	Training Loss: 0.283575 	3307s
# EarlyStopping counter: 2 out of 50
# Epoch: 139/300 	Training Loss: 0.282653 	3330s
# EarlyStopping counter: 3 out of 50
# Epoch: 140/300 	Training Loss: 0.294934 	3353s
# EarlyStopping counter: 4 out of 50
# Epoch: 141/300 	Training Loss: 0.279723 	3376s
# EarlyStopping counter: 5 out of 50
# Epoch: 142/300 	Training Loss: 0.280265 	3399s
# EarlyStopping counter: 6 out of 50
# Epoch: 143/300 	Training Loss: 0.278617 	3422s
# EarlyStopping counter: 7 out of 50
# Epoch: 144/300 	Training Loss: 0.275921 	3444s
# EarlyStopping counter: 8 out of 50
# Epoch: 145/300 	Training Loss: 0.283634 	3467s
# EarlyStopping counter: 9 out of 50
# Epoch: 146/300 	Training Loss: 0.282194 	3489s
# EarlyStopping counter: 10 out of 50
# Epoch: 147/300 	Training Loss: 0.289936 	3511s
# EarlyStopping counter: 11 out of 50
# Epoch: 148/300 	Training Loss: 0.282118 	3533s
# EarlyStopping counter: 12 out of 50
# Epoch: 149/300 	Training Loss: 0.275192 	3555s
# EarlyStopping counter: 13 out of 50
# Epoch: 150/300 	Training Loss: 0.278313 	3577s
# EarlyStopping counter: 14 out of 50
# Epoch: 151/300 	Training Loss: 0.283418 	3600s
# EarlyStopping counter: 15 out of 50
# Epoch: 152/300 	Training Loss: 0.279798 	3622s
# EarlyStopping counter: 16 out of 50
# Epoch: 153/300 	Training Loss: 0.279312 	3645s
# Epoch: 154/300 	Training Loss: 0.273429 	3669s
# EarlyStopping counter: 1 out of 50
# Epoch: 155/300 	Training Loss: 0.275001 	3691s
# EarlyStopping counter: 2 out of 50
# Epoch: 156/300 	Training Loss: 0.267517 	3714s
# EarlyStopping counter: 3 out of 50
# Epoch: 157/300 	Training Loss: 0.277720 	3737s
# EarlyStopping counter: 4 out of 50
# Epoch: 158/300 	Training Loss: 0.277115 	3760s
# EarlyStopping counter: 5 out of 50
# Epoch: 159/300 	Training Loss: 0.293207 	3783s
# EarlyStopping counter: 6 out of 50
# Epoch: 160/300 	Training Loss: 0.270363 	3805s
# EarlyStopping counter: 7 out of 50
# Epoch: 161/300 	Training Loss: 0.267212 	3829s
# EarlyStopping counter: 8 out of 50
# Epoch: 162/300 	Training Loss: 0.263911 	3852s
# Epoch: 163/300 	Training Loss: 0.267294 	3874s
# EarlyStopping counter: 1 out of 50
# Epoch: 164/300 	Training Loss: 0.271697 	3896s
# EarlyStopping counter: 2 out of 50
# Epoch: 165/300 	Training Loss: 0.280870 	3919s
# EarlyStopping counter: 3 out of 50
# Epoch: 166/300 	Training Loss: 0.262885 	3942s
# EarlyStopping counter: 4 out of 50
# Epoch: 167/300 	Training Loss: 0.269853 	3965s
# EarlyStopping counter: 5 out of 50
# Epoch: 168/300 	Training Loss: 0.262929 	3988s
# EarlyStopping counter: 6 out of 50
# Epoch: 169/300 	Training Loss: 0.270383 	4011s
# EarlyStopping counter: 7 out of 50
# Epoch: 170/300 	Training Loss: 0.259979 	4034s
# EarlyStopping counter: 8 out of 50
# Epoch: 171/300 	Training Loss: 0.277188 	4057s
# EarlyStopping counter: 9 out of 50
# Epoch: 172/300 	Training Loss: 0.260383 	4081s
# Epoch: 173/300 	Training Loss: 0.256798 	4104s
# Epoch: 174/300 	Training Loss: 0.260095 	4127s
# EarlyStopping counter: 1 out of 50
# Epoch: 175/300 	Training Loss: 0.268912 	4150s
# EarlyStopping counter: 2 out of 50
# Epoch: 176/300 	Training Loss: 0.264537 	4173s
# EarlyStopping counter: 3 out of 50
# Epoch: 177/300 	Training Loss: 0.263320 	4195s
# EarlyStopping counter: 4 out of 50
# Epoch: 178/300 	Training Loss: 0.259853 	4218s
# EarlyStopping counter: 5 out of 50
# Epoch: 179/300 	Training Loss: 0.264188 	4242s
# EarlyStopping counter: 6 out of 50
# Epoch: 180/300 	Training Loss: 0.259143 	4265s
# EarlyStopping counter: 7 out of 50
# Epoch: 181/300 	Training Loss: 0.263310 	4288s
# EarlyStopping counter: 8 out of 50
# Epoch: 182/300 	Training Loss: 0.266742 	4311s
# EarlyStopping counter: 9 out of 50
# Epoch: 183/300 	Training Loss: 0.263815 	4334s
# EarlyStopping counter: 10 out of 50
# Epoch: 184/300 	Training Loss: 0.257824 	4357s
# EarlyStopping counter: 11 out of 50
# Epoch: 185/300 	Training Loss: 0.262927 	4380s
# EarlyStopping counter: 12 out of 50
# Epoch: 186/300 	Training Loss: 0.258424 	4403s
# EarlyStopping counter: 13 out of 50
# Epoch: 187/300 	Training Loss: 0.251003 	4427s
# EarlyStopping counter: 14 out of 50
# Epoch: 188/300 	Training Loss: 0.251810 	4450s
# EarlyStopping counter: 15 out of 50
# Epoch: 189/300 	Training Loss: 0.252587 	4473s
# EarlyStopping counter: 16 out of 50
# Epoch: 190/300 	Training Loss: 0.259369 	4496s
# Epoch: 191/300 	Training Loss: 0.253920 	4519s
# EarlyStopping counter: 1 out of 50
# Epoch: 192/300 	Training Loss: 0.262151 	4542s
# EarlyStopping counter: 2 out of 50
# Epoch: 193/300 	Training Loss: 0.249895 	4565s
# Epoch: 194/300 	Training Loss: 0.254301 	4588s
# EarlyStopping counter: 1 out of 50
# Epoch: 195/300 	Training Loss: 0.249699 	4611s
# EarlyStopping counter: 2 out of 50
# Epoch: 196/300 	Training Loss: 0.255231 	4634s
# Epoch: 197/300 	Training Loss: 0.256884 	4657s
# EarlyStopping counter: 1 out of 50
# Epoch: 198/300 	Training Loss: 0.245214 	4680s
# EarlyStopping counter: 2 out of 50
# Epoch: 199/300 	Training Loss: 0.248640 	4703s
# EarlyStopping counter: 3 out of 50
# Epoch: 200/300 	Training Loss: 0.260820 	4726s
# EarlyStopping counter: 4 out of 50
# Epoch: 201/300 	Training Loss: 0.257438 	4747s
# EarlyStopping counter: 5 out of 50
# Epoch: 202/300 	Training Loss: 0.247083 	4770s
# EarlyStopping counter: 6 out of 50
# Epoch: 203/300 	Training Loss: 0.245075 	4793s
# EarlyStopping counter: 7 out of 50
# Epoch: 204/300 	Training Loss: 0.278434 	4815s
# EarlyStopping counter: 8 out of 50
# Epoch: 205/300 	Training Loss: 0.249703 	4837s
# Epoch: 206/300 	Training Loss: 0.247157 	4860s
# EarlyStopping counter: 1 out of 50
# Epoch: 207/300 	Training Loss: 0.248698 	4883s
# EarlyStopping counter: 2 out of 50
# Epoch: 208/300 	Training Loss: 0.246304 	4907s
# EarlyStopping counter: 3 out of 50
# Epoch: 209/300 	Training Loss: 0.245120 	4930s
# EarlyStopping counter: 4 out of 50
# Epoch: 210/300 	Training Loss: 0.245879 	4953s
# EarlyStopping counter: 5 out of 50
# Epoch: 211/300 	Training Loss: 0.245548 	4977s
# EarlyStopping counter: 6 out of 50
# Epoch: 212/300 	Training Loss: 0.258494 	5000s
# EarlyStopping counter: 7 out of 50
# Epoch: 213/300 	Training Loss: 0.241183 	5023s
# EarlyStopping counter: 8 out of 50
# Epoch: 214/300 	Training Loss: 0.249476 	5046s
# EarlyStopping counter: 9 out of 50
# Epoch: 215/300 	Training Loss: 0.240675 	5068s
# EarlyStopping counter: 10 out of 50
# Epoch: 216/300 	Training Loss: 0.240733 	5091s
# Epoch: 217/300 	Training Loss: 0.243695 	5114s
# EarlyStopping counter: 1 out of 50
# Epoch: 218/300 	Training Loss: 0.242606 	5136s
# EarlyStopping counter: 2 out of 50
# Epoch: 219/300 	Training Loss: 0.245915 	5159s
# EarlyStopping counter: 3 out of 50
# Epoch: 220/300 	Training Loss: 0.239665 	5182s
# EarlyStopping counter: 4 out of 50
# Epoch: 221/300 	Training Loss: 0.261490 	5206s
# EarlyStopping counter: 5 out of 50
# Epoch: 222/300 	Training Loss: 0.241128 	5229s
# EarlyStopping counter: 6 out of 50
# Epoch: 223/300 	Training Loss: 0.237543 	5252s
# Epoch: 224/300 	Training Loss: 0.242947 	5275s
# EarlyStopping counter: 1 out of 50
# Epoch: 225/300 	Training Loss: 0.241166 	5299s
# EarlyStopping counter: 2 out of 50
# Epoch: 226/300 	Training Loss: 0.247663 	5322s
# EarlyStopping counter: 3 out of 50
# Epoch: 227/300 	Training Loss: 0.235335 	5345s
# EarlyStopping counter: 4 out of 50
# Epoch: 228/300 	Training Loss: 0.238665 	5368s
# EarlyStopping counter: 5 out of 50
# Epoch: 229/300 	Training Loss: 0.240706 	5391s
# EarlyStopping counter: 6 out of 50
# Epoch: 230/300 	Training Loss: 0.236532 	5414s
# EarlyStopping counter: 7 out of 50
# Epoch: 231/300 	Training Loss: 0.239040 	5436s
# EarlyStopping counter: 8 out of 50
# Epoch: 232/300 	Training Loss: 0.239503 	5460s
# EarlyStopping counter: 9 out of 50
# Epoch: 233/300 	Training Loss: 0.239508 	5483s
# EarlyStopping counter: 10 out of 50
# Epoch: 234/300 	Training Loss: 0.232042 	5506s
# EarlyStopping counter: 11 out of 50
# Epoch: 235/300 	Training Loss: 0.235165 	5529s
# EarlyStopping counter: 12 out of 50
# Epoch: 236/300 	Training Loss: 0.235003 	5552s
# EarlyStopping counter: 13 out of 50
# Epoch: 237/300 	Training Loss: 0.237063 	5575s
# EarlyStopping counter: 14 out of 50
# Epoch: 238/300 	Training Loss: 0.248720 	5598s
# EarlyStopping counter: 15 out of 50
# Epoch: 239/300 	Training Loss: 0.236468 	5621s
# EarlyStopping counter: 16 out of 50
# Epoch: 240/300 	Training Loss: 0.239785 	5644s
# EarlyStopping counter: 17 out of 50
# Epoch: 241/300 	Training Loss: 0.239196 	5668s
# EarlyStopping counter: 18 out of 50
# Epoch: 242/300 	Training Loss: 0.232248 	5691s
# Epoch: 243/300 	Training Loss: 0.228639 	5714s
# EarlyStopping counter: 1 out of 50
# Epoch: 244/300 	Training Loss: 0.235442 	5737s
# Epoch: 245/300 	Training Loss: 0.232771 	5760s
# EarlyStopping counter: 1 out of 50
# Epoch: 246/300 	Training Loss: 0.226742 	5782s
# EarlyStopping counter: 2 out of 50
# Epoch: 247/300 	Training Loss: 0.228704 	5804s
# EarlyStopping counter: 3 out of 50
# Epoch: 248/300 	Training Loss: 0.235776 	5827s
# EarlyStopping counter: 4 out of 50
# Epoch: 249/300 	Training Loss: 0.234831 	5850s
# EarlyStopping counter: 5 out of 50
# Epoch: 250/300 	Training Loss: 0.227400 	5873s
# EarlyStopping counter: 6 out of 50
# Epoch: 251/300 	Training Loss: 0.247282 	5897s
# EarlyStopping counter: 7 out of 50
# Epoch: 252/300 	Training Loss: 0.259201 	5920s
# EarlyStopping counter: 8 out of 50
# Epoch: 253/300 	Training Loss: 0.228985 	5942s
# EarlyStopping counter: 9 out of 50
# Epoch: 254/300 	Training Loss: 0.229915 	5964s
# EarlyStopping counter: 10 out of 50
# Epoch: 255/300 	Training Loss: 0.226450 	5986s
# Epoch: 256/300 	Training Loss: 0.228782 	6010s
# EarlyStopping counter: 1 out of 50
# Epoch: 257/300 	Training Loss: 0.246268 	6033s
# EarlyStopping counter: 2 out of 50
# Epoch: 258/300 	Training Loss: 0.380175 	6056s
# EarlyStopping counter: 3 out of 50
# Epoch: 259/300 	Training Loss: 0.270734 	6079s
# EarlyStopping counter: 4 out of 50
# Epoch: 260/300 	Training Loss: 0.242205 	6103s
# EarlyStopping counter: 5 out of 50
# Epoch: 261/300 	Training Loss: 0.240832 	6126s
# EarlyStopping counter: 6 out of 50
# Epoch: 262/300 	Training Loss: 0.232325 	6149s
# EarlyStopping counter: 7 out of 50
# Epoch: 263/300 	Training Loss: 0.229011 	6172s
# EarlyStopping counter: 8 out of 50
# Epoch: 264/300 	Training Loss: 0.232207 	6195s
# EarlyStopping counter: 9 out of 50
# Epoch: 265/300 	Training Loss: 0.255097 	6218s
# EarlyStopping counter: 10 out of 50
# Epoch: 266/300 	Training Loss: 0.231426 	6241s
# EarlyStopping counter: 11 out of 50
# Epoch: 267/300 	Training Loss: 0.225739 	6265s
# Epoch: 268/300 	Training Loss: 0.227906 	6287s
# EarlyStopping counter: 1 out of 50
# Epoch: 269/300 	Training Loss: 0.225316 	6310s
# EarlyStopping counter: 2 out of 50
# Epoch: 270/300 	Training Loss: 0.225012 	6332s
# Epoch: 271/300 	Training Loss: 0.219508 	6355s
# Epoch: 272/300 	Training Loss: 0.228756 	6378s
# EarlyStopping counter: 1 out of 50
# Epoch: 273/300 	Training Loss: 0.244178 	6401s
# EarlyStopping counter: 2 out of 50
# Epoch: 274/300 	Training Loss: 0.299073 	6425s
# EarlyStopping counter: 3 out of 50
# Epoch: 275/300 	Training Loss: 0.227139 	6448s
# EarlyStopping counter: 4 out of 50
# Epoch: 276/300 	Training Loss: 0.223275 	6471s
# EarlyStopping counter: 5 out of 50
# Epoch: 277/300 	Training Loss: 0.222367 	6493s
# EarlyStopping counter: 6 out of 50
# Epoch: 278/300 	Training Loss: 0.222299 	6517s
# EarlyStopping counter: 7 out of 50
# Epoch: 279/300 	Training Loss: 0.225481 	6630s
# EarlyStopping counter: 8 out of 50
# Epoch: 280/300 	Training Loss: 0.216604 	6768s
# EarlyStopping counter: 9 out of 50
# Epoch: 281/300 	Training Loss: 0.223058 	6791s
# EarlyStopping counter: 10 out of 50
# Epoch: 282/300 	Training Loss: 0.218111 	6814s
# EarlyStopping counter: 11 out of 50
# Epoch: 283/300 	Training Loss: 0.222681 	6837s
# EarlyStopping counter: 12 out of 50
# Epoch: 284/300 	Training Loss: 0.216867 	6861s
# EarlyStopping counter: 13 out of 50
# Epoch: 285/300 	Training Loss: 0.224164 	6884s
# EarlyStopping counter: 14 out of 50
# Epoch: 286/300 	Training Loss: 0.220002 	6907s
# EarlyStopping counter: 15 out of 50
# Epoch: 287/300 	Training Loss: 0.222213 	6930s
# EarlyStopping counter: 16 out of 50
# Epoch: 288/300 	Training Loss: 0.222101 	6952s
# EarlyStopping counter: 17 out of 50
# Epoch: 289/300 	Training Loss: 0.223417 	6975s
# EarlyStopping counter: 18 out of 50
# Epoch: 290/300 	Training Loss: 0.219140 	6998s
# EarlyStopping counter: 19 out of 50
# Epoch: 291/300 	Training Loss: 0.234674 	7021s
# EarlyStopping counter: 20 out of 50
# Epoch: 292/300 	Training Loss: 0.221818 	7044s
# EarlyStopping counter: 21 out of 50
# Epoch: 293/300 	Training Loss: 0.221010 	7067s
# EarlyStopping counter: 22 out of 50
# Epoch: 294/300 	Training Loss: 0.224594 	7090s
# EarlyStopping counter: 23 out of 50
# Epoch: 295/300 	Training Loss: 0.222096 	7113s
# EarlyStopping counter: 24 out of 50
# Epoch: 296/300 	Training Loss: 0.220619 	7137s
# EarlyStopping counter: 25 out of 50
# Epoch: 297/300 	Training Loss: 0.217488 	7159s
# EarlyStopping counter: 26 out of 50
# Epoch: 298/300 	Training Loss: 0.218375 	7181s
# EarlyStopping counter: 27 out of 50
# Epoch: 299/300 	Training Loss: 0.217142 	7203s
# EarlyStopping counter: 28 out of 50
# Epoch: 300/300 	Training Loss: 0.215974 	7225s
# best_testloss:0.283	 epoch:270
# EarlyStopping counter: 29 out of 50

# %%
zoomin = 0
zoomout = 6
plotTraining(lossTrainArr, lossTestArr, LrCArr, bestLoss, zoomin, zoomout)

# %%
# create testdataset

damaged_img_path = 'testdataset/damaged_image' 

if lidar_mode == 'sparse':
    lidar_path = 'testdataset/lidar_tensor/sparse'
else:
    lidar_path = 'testdataset/lidar_tensor/dense'

label_path = 'testdataset/ori_image'

damaged_img_list = sorted(glob.glob(damaged_img_path + '/*'))
lidar_list = sorted(glob.glob(lidar_path + '/*'))
label_list = sorted(glob.glob(label_path + '/*'))

learning_rate = 1e-4
batch_size = 32

TestDataset = CreateDatasets(label_list, damaged_img_list, lidar_list)
new_testloader = DataLoader(dataset=TestDataset, batch_size=batch_size, shuffle=False, num_workers=0, drop_last=True)

test_model_best = SimpleAutoencoder()
# for name, value in test_model_best.named_parameters():
#     print(name)

# test_model_last.load_state_dict(torch.load('model_save/damage_{}/last_model_{}.pth'.format(damage_label, experimentIndex)))

# if lidar_mode == 'sparse':
#     test_model_best.load_state_dict(
#     torch.load('model_save/fusion/3_sparse_best_model_600_32_20230521_174942.pth')
# )
# else:
#     test_model_best.load_state_dict(
#     torch.load('model_save/fusion/3_dense_best_model_600_32_20230522_072759.pth')
# )
# # test_model.to(device)
# test_model_last.eval()

test_model_best.load_state_dict(
    torch.load('model_save/fusion/13_late_best_model_300_32_20230531_133947.pth')
)
test_model_best.eval()


dataiter = iter(new_testloader)
label, damaged_img, lidar = next(dataiter)
# label, damaged_img, lidar = next(dataiter)
# label, damaged_img, lidar = next(dataiter)
# label, damaged_img, lidar = next(dataiter)
# label, damaged_img, lidar = next(dataiter)
# label, damaged_img, lidar = next(dataiter)
# label, damaged_img, lidar = next(dataiter)
# label, damaged_img, lidar = next(dataiter)




output = test_model_best(damaged_img, lidar)

# %%
##################################################
# visualize one batch of the validation images #
##################################################
# test_model.to(device)




# test_model.to(device)
# test_model_last.eval()
test_model_best.eval()


# obtain one batch of test images
dataiter = iter(new_testloader)
# dataiter = iter(valloader)

label, damaged_img, lidar = next(dataiter)

# get sample outputs
output = test_model_best(damaged_img, lidar)

# prep images for display
# i = 31
for i in range(32):

    img1 = label[i].numpy()
    img1 = img1.transpose(1, 2, 0)
    img2 = damaged_img[i].numpy()
    img2 = img2.transpose(1, 2, 0)
    img3 = lidar[i].detach().numpy()
    img3 = img3.transpose(1, 2, 0)
    img4 = output[i].detach().numpy()
    img4 = img4.transpose(1, 2, 0)


    ax = plt.subplot(1, 4, 1)
    plt.xticks([])
    plt.yticks([])
    # ax.set_title('label')
    plt.imshow(img1,cmap='gray')

    ax = plt.subplot(1, 4, 2)
    plt.xticks([])
    plt.yticks([])
    # ax.set_title('damaged image')
    plt.imshow(img2,cmap='gray')

    ax = plt.subplot(1, 4, 3)
    plt.xticks([])
    plt.yticks([])
    # ax.set_title('lidar')
    plt.imshow(img3)

    ax = plt.subplot(1, 4, 4)
    plt.xticks([])
    plt.yticks([])
    #  ax.set_title('reconstructed image')
    plt.imshow(img4, cmap='gray')

    # plt.savefig('fig_save/{}.png'.format(i))
    
plt.show()

# %%
import cv2
from PIL import Image
from torchvision import transforms
from matplotlib import pyplot as plt


toPIL = transforms.ToPILImage()

# prep images for display
for i in range(32):
# i = 31

    img1 = label[i]
    img2 = damaged_img[i]
    img3 = lidar[i]
    img4 = output[i]
    # print(img1.shape, img3.shape)
    # print(type(img1),type(img3))
    # im1 = toPIL(img1)
    img4 = img4[0]
    max_value = torch.max(img4)
    min_value = torch.min(img4)
    print(max_value,min_value)



    img4_normalized = (img4 - min_value) / (max_value - min_value)


    im4 = toPIL(img4_normalized)
    im3 = toPIL(img3)
    name = '%02d' %i

# im1.save('RecosntructedImages/ori_img/{}.png'.format(name))
# im2.save('RecosntructedImages/masked_img/{}.png'.format(name))
# im4.save('output_save/5_main_fusion_3_dense/A/{}.png'.format(name))
# im3.save('output_save/lidar_sparse_testing/{}.png'.format(name))
# im4.save('{}.png'.format(name))

# import numpy as np
# import cv2

# for i in range(32):
#     if i ==13:
#         img1 = label[i].numpy()
#         img1 = img1.transpose(1, 2, 0)
#         img2 = damaged_img[i].numpy()
#         img2 = img2.transpose(1, 2, 0)
#         img3 = lidar[i].detach().numpy()
#         img3 = img3.transpose(1, 2, 0)
#         img4 = output[i].detach().numpy()
#         img4 = img4.transpose(1, 2, 0)

#         name = '%02d' %i
#         filepath = 'output_save/test/{}.png'.format(name)

#         # 调用函数将灰度图像保存为RGB图像的PNG
#         # cv2.imwrite(filepath, img4)
#         plt.xticks([])
#         plt.yticks([])
#         plt.imshow(img4, cmap='gray')
#         plt.savefig(filepath)
#         plt.colorbar()
#         plt.show()
# Out:
# tensor(1.0590, grad_fn=<MaxBackward1>) tensor(-0.0068, grad_fn=<MinBackward1>)
# tensor(1.1087, grad_fn=<MaxBackward1>) tensor(0.0157, grad_fn=<MinBackward1>)
# tensor(1.1730, grad_fn=<MaxBackward1>) tensor(0.0492, grad_fn=<MinBackward1>)
# tensor(1.2108, grad_fn=<MaxBackward1>) tensor(0.0889, grad_fn=<MinBackward1>)
# tensor(1.1027, grad_fn=<MaxBackward1>) tensor(0.0243, grad_fn=<MinBackward1>)
# tensor(1.0759, grad_fn=<MaxBackward1>) tensor(0.0110, grad_fn=<MinBackward1>)
# tensor(1.0808, grad_fn=<MaxBackward1>) tensor(-0.0420, grad_fn=<MinBackward1>)
# tensor(1.1386, grad_fn=<MaxBackward1>) tensor(0.0065, grad_fn=<MinBackward1>)
# tensor(1.1145, grad_fn=<MaxBackward1>) tensor(-0.0084, grad_fn=<MinBackward1>)
# tensor(1.1468, grad_fn=<MaxBackward1>) tensor(-0.0678, grad_fn=<MinBackward1>)
# tensor(1.1297, grad_fn=<MaxBackward1>) tensor(0.0129, grad_fn=<MinBackward1>)
# tensor(1.1884, grad_fn=<MaxBackward1>) tensor(-0.0378, grad_fn=<MinBackward1>)
# tensor(1.1725, grad_fn=<MaxBackward1>) tensor(0.0098, grad_fn=<MinBackward1>)
# tensor(1.2034, grad_fn=<MaxBackward1>) tensor(0.0052, grad_fn=<MinBackward1>)
# tensor(1.1897, grad_fn=<MaxBackward1>) tensor(-0.0379, grad_fn=<MinBackward1>)
# tensor(1.0158, grad_fn=<MaxBackward1>) tensor(-0.0865, grad_fn=<MinBackward1>)
# tensor(1.1563, grad_fn=<MaxBackward1>) tensor(0.0439, grad_fn=<MinBackward1>)
# tensor(1.1152, grad_fn=<MaxBackward1>) tensor(-0.0401, grad_fn=<MinBackward1>)
# tensor(1.1378, grad_fn=<MaxBackward1>) tensor(0.0118, grad_fn=<MinBackward1>)
# tensor(1.0568, grad_fn=<MaxBackward1>) tensor(-0.0113, grad_fn=<MinBackward1>)
# tensor(1.1285, grad_fn=<MaxBackward1>) tensor(0.0018, grad_fn=<MinBackward1>)
# tensor(1.0817, grad_fn=<MaxBackward1>) tensor(-0.0624, grad_fn=<MinBackward1>)
# tensor(1.0866, grad_fn=<MaxBackward1>) tensor(0.0049, grad_fn=<MinBackward1>)
# tensor(1.1885, grad_fn=<MaxBackward1>) tensor(-0.0627, grad_fn=<MinBackward1>)
# tensor(1.2119, grad_fn=<MaxBackward1>) tensor(0.0021, grad_fn=<MinBackward1>)
# tensor(0.9890, grad_fn=<MaxBackward1>) tensor(-0.0130, grad_fn=<MinBackward1>)
# tensor(1.1017, grad_fn=<MaxBackward1>) tensor(0.0346, grad_fn=<MinBackward1>)
# tensor(1.1487, grad_fn=<MaxBackward1>) tensor(-0.0351, grad_fn=<MinBackward1>)
# tensor(1.1557, grad_fn=<MaxBackward1>) tensor(0.0440, grad_fn=<MinBackward1>)
# tensor(1.1426, grad_fn=<MaxBackward1>) tensor(0.0385, grad_fn=<MinBackward1>)
# tensor(0.9970, grad_fn=<MaxBackward1>) tensor(-0.0692, grad_fn=<MinBackward1>)
# tensor(1.1206, grad_fn=<MaxBackward1>) tensor(-0.0156, grad_fn=<MinBackward1>)

# %%
# MSE for all damages
criterion = nn.MSELoss()
criterion.to(device)

for i, batch in enumerate(new_testloader):# i -->index of batch
    count = 0
    for j in range (batch_size):
        img1 = label[i]
        img3 = output[i]
        mse = criterion(img1,img3)
        mse = round(mse.item(),6)
        count = count+mse

    mse_mean = round(count,3)
    print(mse_mean)
# Out:
# 0.628
# 0.193
# 0.466
# 0.219
# 0.207
# 1.091
# 0.191
# 0.385

# %%
# # regional mse

# batch_size = 32

# def create_mask(image_shape, block_size, num_blocks):
#     mask = np.ones(image_shape, dtype=np.float32) 
#     block_size_px = (int(image_shape[0] * block_size), int(image_shape[1] * block_size))
#     np.random.seed(6)

#     for _ in range(num_blocks):
#         top_left = np.random.randint(0, image_shape[0] - block_size_px[0] + 1), np.random.randint(0, image_shape[1] - block_size_px[1] + 1)
#         bottom_right = top_left[0] + block_size_px[0], top_left[1] + block_size_px[1]
#         mask[top_left[0]:bottom_right[0], top_left[1]:bottom_right[1]] = 0
        
#     return mask


# block_size = 0.2  # 方块大小为原图大小的百分比
# num_blocks = 16  # 方块数量

# count = 0

# # for j in range(label.size(0)):
# #     ori_img_np = label[j][0].detach().numpy()
# #     output_np = output[j][0].detach().numpy()
# #     mask = create_mask(ori_img_np.shape[:2], block_size, num_blocks)
# #     local_mse = np.mean(np.square(output_np - ori_img_np) * mask)
# #     count = count+local_mse
# # local_mse = round(count/batch_size, 6)

# # baseline
# for j in range(label.size(0)):
#     ori_img_np = label[j][0].detach().numpy()
#     output_np = output[j][0].detach().numpy()
#     mask = create_mask(ori_img_np.shape[:2], block_size, num_blocks)
#     local_mse = np.mean(np.square(output_np - ori_img_np) * mask)
#     count = count+local_mse
# local_mse = round(count/batch_size, 6)

# print(local_mse)
# Out:
# 0.003846

# %%
import cv2
import os
import numpy

masked_region_list = []
original_image_list = []

image_path = 'testdataset/ori_image'
images = sorted(glob.glob(image_path + '/*'))[0:32]
damage_label = 'A'

def create_mask(image_shape, block_size, num_blocks):
    mask = np.ones(image_shape, dtype=np.float32) 
    block_size_px = (int(image_shape[0] * block_size), int(image_shape[1] * block_size))
    np.random.seed(6)
    masked_region = []

    for _ in range(num_blocks):
        top_left = np.random.randint(0, image_shape[0] - block_size_px[0] + 1), np.random.randint(0, image_shape[1] - block_size_px[1] + 1)
        bottom_right = top_left[0] + block_size_px[0], top_left[1] + block_size_px[1]
        mask[top_left[0]:bottom_right[0], top_left[1]:bottom_right[1]] = 0
        masked_region.append((top_left, bottom_right))
        
    return mask, masked_region


for i in range(len(images)):
    image = cv2.imread(images[i])
    image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    ori_img_name = os.path.basename(images[i])

    block_size = 0.2  # 方块大小为原图大小的百分比
    num_blocks = 16  # 方块数量
    mask, masked_region = create_mask(image.shape[:2], block_size, num_blocks)
    masked_region_list.append(masked_region)
    original_image_list.append(image)
    damaged_img1 = image * mask
    # cv2.imwrite(f'testdataset/damaged_image/{damage_label}_{ori_img_name}', damaged_img1)

regional_mse_list = []

for i in range(len(images)):
    original_image = original_image_list[i]
    masked_region = masked_region_list[i]
    original_image = (original_image-np.min(original_image))/(np.max(original_image)-np.min(original_image))
    

    
    # Obtain the output reconstructed image
    output_image = output[i][0].detach().numpy()  # Replace this with the code to get the output image from your image reconstruction network
    # output_image = (output_image-np.min(output_image))/(np.max(output_image)-np.min(output_image))
    
    mse = 0
    num_pixels = 0

    for region in masked_region:
        top_left, bottom_right = region
        original_pixels = original_image[top_left[0]:bottom_right[0], top_left[1]:bottom_right[1]]
        output_pixels = output_image[top_left[0]:bottom_right[0], top_left[1]:bottom_right[1]]
        diff = original_pixels.astype(np.float32) - output_pixels.astype(np.float32)
        mse += np.sum(diff ** 2)
        num_pixels += original_pixels.size

    mse /= num_pixels
    regional_mse_list.append(mse)

print(np.mean(regional_mse_list))
# Out:
# 0.023734229349283847

# %%
# SSIM

import torch
from skimage.metrics import structural_similarity as ssim
import glob


metric_value_list = []
batch_size = 32


for i, batch in enumerate(new_testloader):
    label, damaged_img, lidar = batch
    count = 0
    for j in range(label.size(0)):
        ori_img_np = label[j][0].detach().cpu().numpy()
        output_np = output[j][0].detach().cpu().numpy()
        ssim_img, diff = ssim(ori_img_np, output_np, full=True, data_range=1.0)
        count = count + ssim_img
    ssim_img = round(count / label.size(0), 3)
    print(ssim_img)
#     metric_value_list.append(ssim_img)

# print(metric_value_list)
# Out:
# 0.643
# 0.234
# 0.219
# 0.206
# 0.206
# 0.211
# 0.222
# 0.22

# %%
# LLIPS metrics

import lpips

loss_fn = lpips.LPIPS(net='alex')


for i, batch in enumerate(new_testloader):  # i -->index of batch
    label, damaged_img, lidar = batch
    count = 0
    for j in range(label.size(0)):
        # ori_img_np = ori_img[j][0].detach().numpy()
        # output_np = output[j][0].detach().numpy()
        lpips_img = loss_fn.forward(label, output)
        sum_result = (torch.sum(lpips_img)).item()
        count = count+sum_result
        # count = count.item()
    lpips_img = round(count/label.size(0),3)
    print(lpips_img)
#     metric_value_list.append(lpips_img)

# print(f'scuccess: {metric_value_list}')
# Out:
# Setting up [LPIPS] perceptual loss: trunk [alex], v[0.1], spatial [off]
# Loading model from: /usr/local/Anaconda3-2021.11-Linux-x86_64/envs/pytorch/lib/python3.8/site-packages/lpips/weights/v0.1/alex.pth
# 10.084
# 17.255
# 17.513
# 17.954
# 17.706
# 17.585
# 17.858
# 17.811
# 17.926
