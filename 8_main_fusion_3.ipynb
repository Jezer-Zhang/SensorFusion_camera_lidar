# %%
# encoders decoders and adjust layer changed

# %%
from matplotlib import pyplot as plt
from torch.utils.data import DataLoader
from sensorFusionDataset.creatDataset_2_encoder import CreateDatasets
from sensorFusionDataset.data_split import split_dataset
from sensorFusionNetwork.simpleAutoencoder import SimpleAutoencoder, TwoEncoderOneDecoder, EncoderFusion


from testLoop import test_loop_fusion
from trainLoop import train_loop_fusion
from visualization import plot_losses, plot_metrics,plotTraining
from earlystopping import EarlyStopping

import h5py as h5
from datetime import datetime
import copy
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import glob
import time

local_time =time.strftime("%Y-%m-%d %H:%M:%S", time.localtime())[-8:-1]
now = datetime.now()
dt_string = now.strftime("%Y%m%d_%H%M%S")
# CPU OR GPU
device = 'cuda' if torch.cuda.is_available() else 'cpu'

damaged_img_path = 'image_gray_200_damaged' 

lidar_mode = 'sparse'

if lidar_mode == 'sparse':
    lidar_path = 'lidar_tesor_200_sparse'
else:
    lidar_path = 'lidar_tesor_200_dense'

label_path = 'image_gray_200_original'

damaged_img_list = sorted(glob.glob(damaged_img_path + '/*'))[0:7200]
lidar_list = sorted(glob.glob(lidar_path + '/*'))[0:7200]
label_list = sorted(glob.glob(label_path + '/*'))[0:7200]


batch_size = 32
learning_rate = 1e-4
epochs = 600

MyDataset = CreateDatasets(label_list, damaged_img_list, lidar_list)#, img_size=img_size
train_dataset, test_dataset, val_dataset = split_dataset(MyDataset, 0.7, 0.2)
train_loader = DataLoader(dataset=train_dataset, batch_size=batch_size, shuffle=True, num_workers=0,
                          drop_last=True)
test_loader = DataLoader(dataset=test_dataset, batch_size=batch_size, shuffle=True, num_workers=0,
                         drop_last=True)
val_loader = DataLoader(dataset=val_dataset, batch_size=batch_size, shuffle=False, num_workers=0,
                        drop_last=True)

patience = 50	# 当验证集损失在连续20次训练周期中都没有得到降低时，停止模型训练，以防止模型过拟合
save_path = 'fusion_model/'
early_stopping = EarlyStopping(save_path = save_path, patience = patience)	

criterion = nn.MSELoss()




# new_model = SimpleAutoencoder()
# new_model.to(device)
# new_model.load_state_dict(torch.load('denoising_model/best_model_300_32_0.0004_20230422_153250.pth'))

# for name, value in new_model.named_parameters():
#     #print (name) # print(model.state_dict().keys())
#     if name.startswith('decoder'):
#         value.requires_grad = False
        
# params = filter(lambda p: p.requires_grad, new_model.parameters())
# optimizer = torch.optim.Adam(params, lr=learning_rate)

# criterion = nn.MSELoss()
# criterion.to(device)

training_loss = []
training_baseloss = []
test_loss = []
testing_baseloss = []
hisLrC = []
min_loss=10000

print (f'loading fertig! {device}' )
# Out:
# loading fertig! cuda

# %%
# retraining with the channel adjust
# loading model
removal_layer = nn.Sequential()

encoder_img = SimpleAutoencoder()
encoder_img.load_state_dict(torch.load('model_save/ori2ori/ori2ori_best_model_600_32_20230518_044338.pth'))
encoder_img.decoder = removal_layer


encoder_lidar = SimpleAutoencoder()
if lidar_mode == 'sparse':
    encoder_lidar.load_state_dict(torch.load('model_save/lidar2img/sparse_FIX_best_model_600_32_20230518_063828.pth'))
else:
    encoder_lidar.load_state_dict(torch.load('model_save/lidar2img/dense_FIX_best_model_600_32_20230518_154020.pth'))
encoder_lidar.decoder = removal_layer


decoder = SimpleAutoencoder()
decoder.load_state_dict(torch.load('model_save/ori2ori/ori2ori_best_model_600_32_20230518_044338.pth'))
# decoder.load_state_dict(torch.load('denoising_model/best_model_300_32_0.0004_20230422_153250.pth'))
decoder.encoder = removal_layer

channelAdjust = EncoderFusion()
# channelAdjust.to(device)

fusion_net = TwoEncoderOneDecoder(encoder_img, encoder_lidar, decoder, channelAdjust)
fusion_net.to(device)

# for name, value in fusion_net.named_parameters():
#     # print (name) # print(model.state_dict().keys())
#     if name.startswith('decoder'):
#         value.requires_grad = False
# params = filter(lambda p: p.requires_grad, fusion_net.parameters())


learning_rate = 0.0004  # 2e-4 batchsize=30
optimizer = torch.optim.Adam(fusion_net.parameters(), lr=learning_rate)

criterion = nn.MSELoss()
criterion.to(device)


start_time = time.time()
for epoch in range(1, epochs + 1):
    # monitor training loss
    ##############################
    # start training the model #
    ##############################
    hisLrC.append(epoch)
    train_epoch_loss, train_epoch_baseloss = train_loop_fusion(train_loader, fusion_net, criterion, optimizer, device)
    training_loss.append(train_epoch_loss)
    # training_baseloss.append(train_epoch_baseloss)
    print('Epoch: {}/{} \tTraining Loss: {:.6f} \t{:.0f}s'.format(epoch, epochs, train_epoch_loss,
                                                                  time.time() - start_time))

    ##############################
    # start testing the model #
    ##############################
    with torch.no_grad():
        test_epoch_loss, test_epoch_baseloss = test_loop_fusion(test_loader, fusion_net, criterion, device)
        test_loss.append(test_epoch_loss)
        # testing_baseloss.append(test_epoch_baseloss)
        
    # type(train_epoch_loss)) ---> float
    # writer.add_scalars('loss', {'training loss': train_epoch_loss, 'test loss': test_epoch_loss}, epoch)

        
    if test_epoch_loss < min_loss:
        min_loss = test_epoch_loss
        best_model_wts = copy.deepcopy(fusion_net.state_dict())
       

    if epoch == epochs:
        torch.save(best_model_wts, 'model_save/fusion/allchanged_best_model_{}_{}_{}.pth'.format(epochs, batch_size,dt_string))
        print('best_testloss:{:.3f}\t epoch:{}'.format(min_loss, test_loss.index(min_loss)))     

    # 早停止
    date = dt_string
    early_stopping(test_epoch_loss, fusion_net, date)
    #达到早停止条件时，early_stop会被置为True
    if early_stopping.early_stop:
        torch.save(best_model_wts, 'model_save/fusion/allchanged_best_model_{}_{}_{}.pth'.format(epochs, batch_size,dt_string))
        # torch.save(fusion_net.state_dict(), 'Experiment2_sequence_inverse/fusion_model/last_model_{}_{}_{}.pth'.format(epochs, batch_size,dt_string))
        print('best_testloss:{:.3f}\t epoch:{}'.format(min_loss, test_loss.index(min_loss)))  
        print("Early stopping")
        break #跳出迭代，结束训练    
    
# train_baseline = sum(training_baseloss)/len(training_baseloss)
# test_baseline = sum(testing_baseloss)/len(training_baseloss)
# psnr_baseline = np.mean(psnr_base_list)

# train_baseline=train_baseline.item()
# test_baseline =test_baseline.item()
last_trainingloss = training_loss[-1]
last_testloss = test_loss[-1]


# write the dataset in one existed h5-file
now = datetime.now()
dt_string = now.strftime("%Y%m%d_%H%M%S")

lossTrainArr = np.array(training_loss)
lossTestArr = np.array(test_loss)
bestLoss = np.array([min_loss])
LrCArr = np.array(hisLrC)

h5f =h5.File(f"log/recording_{dt_string}.hdf5","w")
# h5f = h5.File('train/train.h5', 'r+') # write in an exsited h5 file
g1 = h5f.create_group('log1')
g1.attrs['data']=now.strftime("%Y-%m-%d")
# g1.attrs['model']=ModelWts
# g1.attrs['optLrOrg']=str(optLrOrg)+'={:3.1e}'.format(optLrOrg) 
# g1.attrs['lrAdstep']= str(lrAdstep)
# g1.attrs['optimizer']= str(optimizer)[:4]

g1.create_dataset('lossTrain', data=lossTrainArr)
g1.create_dataset('lossTest', data=lossTestArr)
g1.create_dataset('bestLoss', data=bestLoss)
g1.create_dataset('LrCArr', data=LrCArr)
h5f.close()

# print('train_baseline:{:.3f} \t test_baseline:{:.3f} \t last trainingloss:{:.3f} \t last testloss:{:.3f}'.format(train_baseline, test_baseline,last_trainingloss,last_testloss))
# Out:
# Epoch: 1/600 	Training Loss: 1.200318 	24s
# Epoch: 2/600 	Training Loss: 0.938431 	48s
# Epoch: 3/600 	Training Loss: 0.828043 	73s
# Epoch: 4/600 	Training Loss: 0.788306 	98s
# Epoch: 5/600 	Training Loss: 0.728045 	122s
# Epoch: 6/600 	Training Loss: 0.686945 	147s
# Epoch: 7/600 	Training Loss: 0.622751 	171s
# Epoch: 8/600 	Training Loss: 0.613807 	196s
# Epoch: 9/600 	Training Loss: 0.580550 	221s
# Epoch: 10/600 	Training Loss: 0.552488 	245s
# EarlyStopping counter: 1 out of 50
# Epoch: 11/600 	Training Loss: 0.542880 	270s
# Epoch: 12/600 	Training Loss: 0.516210 	295s
# Epoch: 13/600 	Training Loss: 0.500502 	319s
# EarlyStopping counter: 1 out of 50
# Epoch: 14/600 	Training Loss: 0.494043 	344s
# Epoch: 15/600 	Training Loss: 0.480495 	368s
# Epoch: 16/600 	Training Loss: 0.473630 	393s
# EarlyStopping counter: 1 out of 50
# Epoch: 17/600 	Training Loss: 0.445655 	418s
# EarlyStopping counter: 2 out of 50
# Epoch: 18/600 	Training Loss: 0.437816 	442s
# Epoch: 19/600 	Training Loss: 0.431080 	467s
# Epoch: 20/600 	Training Loss: 0.413301 	492s
# EarlyStopping counter: 1 out of 50
# Epoch: 21/600 	Training Loss: 0.410223 	516s
# Epoch: 22/600 	Training Loss: 0.395908 	542s
# Epoch: 23/600 	Training Loss: 0.415356 	566s
# Epoch: 24/600 	Training Loss: 0.397255 	591s
# EarlyStopping counter: 1 out of 50
# Epoch: 25/600 	Training Loss: 0.388478 	616s
# Epoch: 26/600 	Training Loss: 0.373067 	640s
# Epoch: 27/600 	Training Loss: 0.353353 	665s
# Epoch: 28/600 	Training Loss: 0.368048 	690s
# EarlyStopping counter: 1 out of 50
# Epoch: 29/600 	Training Loss: 0.350606 	714s
# Epoch: 30/600 	Training Loss: 0.344946 	739s
# Epoch: 31/600 	Training Loss: 0.355747 	763s
# EarlyStopping counter: 1 out of 50
# Epoch: 32/600 	Training Loss: 0.341565 	788s
# EarlyStopping counter: 2 out of 50
# Epoch: 33/600 	Training Loss: 0.336120 	813s
# EarlyStopping counter: 3 out of 50
# Epoch: 34/600 	Training Loss: 0.334972 	837s
# Epoch: 35/600 	Training Loss: 0.328851 	862s
# EarlyStopping counter: 1 out of 50
# Epoch: 36/600 	Training Loss: 0.323824 	887s
# Epoch: 37/600 	Training Loss: 0.338933 	912s
# EarlyStopping counter: 1 out of 50
# Epoch: 38/600 	Training Loss: 0.324657 	937s
# EarlyStopping counter: 2 out of 50
# Epoch: 39/600 	Training Loss: 0.339585 	961s
# EarlyStopping counter: 3 out of 50
# Epoch: 40/600 	Training Loss: 0.342259 	986s
# Epoch: 41/600 	Training Loss: 0.315009 	1011s
# Epoch: 42/600 	Training Loss: 0.298869 	1035s
# EarlyStopping counter: 1 out of 50
# Epoch: 43/600 	Training Loss: 0.307384 	1060s
# Epoch: 44/600 	Training Loss: 0.292895 	1084s
# Epoch: 45/600 	Training Loss: 0.297729 	1109s
# EarlyStopping counter: 1 out of 50
# Epoch: 46/600 	Training Loss: 0.292858 	1134s
# EarlyStopping counter: 2 out of 50
# Epoch: 47/600 	Training Loss: 0.297005 	1159s
# EarlyStopping counter: 3 out of 50
# Epoch: 48/600 	Training Loss: 0.290458 	1183s
# EarlyStopping counter: 4 out of 50
# Epoch: 49/600 	Training Loss: 0.280692 	1208s
# EarlyStopping counter: 5 out of 50
# Epoch: 50/600 	Training Loss: 0.298540 	1233s
# EarlyStopping counter: 6 out of 50
# Epoch: 51/600 	Training Loss: 0.302557 	1257s
# EarlyStopping counter: 7 out of 50
# Epoch: 52/600 	Training Loss: 0.296153 	1282s
# Epoch: 53/600 	Training Loss: 0.270084 	1306s
# EarlyStopping counter: 1 out of 50
# Epoch: 54/600 	Training Loss: 0.280382 	1331s
# EarlyStopping counter: 2 out of 50
# Epoch: 55/600 	Training Loss: 0.268123 	1356s
# Epoch: 56/600 	Training Loss: 0.278843 	1380s
# EarlyStopping counter: 1 out of 50
# Epoch: 57/600 	Training Loss: 0.271100 	1405s
# EarlyStopping counter: 2 out of 50
# Epoch: 58/600 	Training Loss: 0.268185 	1430s
# EarlyStopping counter: 3 out of 50
# Epoch: 59/600 	Training Loss: 0.268483 	1455s
# Epoch: 60/600 	Training Loss: 0.267908 	1479s
# Epoch: 61/600 	Training Loss: 0.263634 	1504s
# Epoch: 62/600 	Training Loss: 0.252537 	1529s
# EarlyStopping counter: 1 out of 50
# Epoch: 63/600 	Training Loss: 0.254859 	1553s
# EarlyStopping counter: 2 out of 50
# Epoch: 64/600 	Training Loss: 0.255649 	1578s
# EarlyStopping counter: 3 out of 50
# Epoch: 65/600 	Training Loss: 0.262977 	1602s
# EarlyStopping counter: 4 out of 50
# Epoch: 66/600 	Training Loss: 0.262592 	1627s
# EarlyStopping counter: 5 out of 50
# Epoch: 67/600 	Training Loss: 0.257223 	1652s
# EarlyStopping counter: 6 out of 50
# Epoch: 68/600 	Training Loss: 0.245449 	1676s
# Epoch: 69/600 	Training Loss: 0.243772 	1700s
# Epoch: 70/600 	Training Loss: 0.244262 	1724s
# EarlyStopping counter: 1 out of 50
# Epoch: 71/600 	Training Loss: 0.246701 	1749s
# Epoch: 72/600 	Training Loss: 0.232667 	1773s
# Epoch: 73/600 	Training Loss: 0.256590 	1798s
# EarlyStopping counter: 1 out of 50
# Epoch: 74/600 	Training Loss: 0.271468 	1822s
# EarlyStopping counter: 2 out of 50
# Epoch: 75/600 	Training Loss: 0.252978 	1846s
# EarlyStopping counter: 3 out of 50
# Epoch: 76/600 	Training Loss: 0.233603 	1871s
# EarlyStopping counter: 4 out of 50
# Epoch: 77/600 	Training Loss: 0.234320 	1895s
# EarlyStopping counter: 5 out of 50
# Epoch: 78/600 	Training Loss: 0.234511 	1920s
# EarlyStopping counter: 6 out of 50
# Epoch: 79/600 	Training Loss: 0.229122 	1944s
# EarlyStopping counter: 7 out of 50
# Epoch: 80/600 	Training Loss: 0.225459 	1968s
# Epoch: 81/600 	Training Loss: 0.227288 	1993s
# EarlyStopping counter: 1 out of 50
# Epoch: 82/600 	Training Loss: 0.236069 	2017s
# EarlyStopping counter: 2 out of 50
# Epoch: 83/600 	Training Loss: 0.222884 	2041s
# EarlyStopping counter: 3 out of 50
# Epoch: 84/600 	Training Loss: 0.227548 	2066s
# EarlyStopping counter: 4 out of 50
# Epoch: 85/600 	Training Loss: 0.229630 	2090s
# EarlyStopping counter: 5 out of 50
# Epoch: 86/600 	Training Loss: 0.225357 	2114s
# EarlyStopping counter: 6 out of 50
# Epoch: 87/600 	Training Loss: 0.229825 	2139s
# EarlyStopping counter: 7 out of 50
# Epoch: 88/600 	Training Loss: 0.223929 	2163s
# EarlyStopping counter: 8 out of 50
# Epoch: 89/600 	Training Loss: 0.228468 	2187s
# EarlyStopping counter: 9 out of 50
# Epoch: 90/600 	Training Loss: 0.224201 	2212s
# EarlyStopping counter: 10 out of 50
# Epoch: 91/600 	Training Loss: 0.237822 	2236s
# EarlyStopping counter: 11 out of 50
# Epoch: 92/600 	Training Loss: 0.248608 	2260s
# Epoch: 93/600 	Training Loss: 0.226244 	2284s
# Epoch: 94/600 	Training Loss: 0.208882 	2309s
# Epoch: 95/600 	Training Loss: 0.205357 	2333s
# EarlyStopping counter: 1 out of 50
# Epoch: 96/600 	Training Loss: 0.208536 	2357s
# EarlyStopping counter: 2 out of 50
# Epoch: 97/600 	Training Loss: 0.215456 	2382s
# EarlyStopping counter: 3 out of 50
# Epoch: 98/600 	Training Loss: 0.213794 	2406s
# EarlyStopping counter: 4 out of 50
# Epoch: 99/600 	Training Loss: 0.206859 	2430s
# EarlyStopping counter: 5 out of 50
# Epoch: 100/600 	Training Loss: 0.206901 	2454s
# Epoch: 101/600 	Training Loss: 0.204361 	2479s
# EarlyStopping counter: 1 out of 50
# Epoch: 102/600 	Training Loss: 0.203037 	2503s
# EarlyStopping counter: 2 out of 50
# Epoch: 103/600 	Training Loss: 0.207515 	2527s
# EarlyStopping counter: 3 out of 50
# Epoch: 104/600 	Training Loss: 0.209974 	2551s
# EarlyStopping counter: 4 out of 50
# Epoch: 105/600 	Training Loss: 0.196661 	2576s
# EarlyStopping counter: 5 out of 50
# Epoch: 106/600 	Training Loss: 0.198885 	2600s
# EarlyStopping counter: 6 out of 50
# Epoch: 107/600 	Training Loss: 0.252733 	2624s
# EarlyStopping counter: 7 out of 50
# Epoch: 108/600 	Training Loss: 0.198648 	2649s
# EarlyStopping counter: 8 out of 50
# Epoch: 109/600 	Training Loss: 0.200001 	2673s
# EarlyStopping counter: 9 out of 50
# Epoch: 110/600 	Training Loss: 0.199344 	2698s
# EarlyStopping counter: 10 out of 50
# Epoch: 111/600 	Training Loss: 0.198228 	2722s
# EarlyStopping counter: 11 out of 50
# Epoch: 112/600 	Training Loss: 0.191902 	2746s
# EarlyStopping counter: 12 out of 50
# Epoch: 113/600 	Training Loss: 0.191829 	2771s
# EarlyStopping counter: 13 out of 50
# Epoch: 114/600 	Training Loss: 0.200290 	2795s
# EarlyStopping counter: 14 out of 50
# Epoch: 115/600 	Training Loss: 0.198238 	2819s
# EarlyStopping counter: 15 out of 50
# Epoch: 116/600 	Training Loss: 0.186936 	2843s
# EarlyStopping counter: 16 out of 50
# Epoch: 117/600 	Training Loss: 0.191257 	2868s
# EarlyStopping counter: 17 out of 50
# Epoch: 118/600 	Training Loss: 0.200218 	2892s
# EarlyStopping counter: 18 out of 50
# Epoch: 119/600 	Training Loss: 0.182389 	2917s
# Epoch: 120/600 	Training Loss: 0.185181 	2941s
# EarlyStopping counter: 1 out of 50
# Epoch: 121/600 	Training Loss: 0.183875 	2965s
# EarlyStopping counter: 2 out of 50
# Epoch: 122/600 	Training Loss: 0.189442 	2989s
# EarlyStopping counter: 3 out of 50
# Epoch: 123/600 	Training Loss: 0.183997 	3014s
# EarlyStopping counter: 4 out of 50
# Epoch: 124/600 	Training Loss: 0.182721 	3038s
# EarlyStopping counter: 5 out of 50
# Epoch: 125/600 	Training Loss: 0.181089 	3063s
# EarlyStopping counter: 6 out of 50
# Epoch: 126/600 	Training Loss: 0.184279 	3087s
# EarlyStopping counter: 7 out of 50
# Epoch: 127/600 	Training Loss: 0.179364 	3111s
# EarlyStopping counter: 8 out of 50
# Epoch: 128/600 	Training Loss: 0.231641 	3136s
# EarlyStopping counter: 9 out of 50
# Epoch: 129/600 	Training Loss: 0.196950 	3160s
# EarlyStopping counter: 10 out of 50
# Epoch: 130/600 	Training Loss: 0.182786 	3184s
# EarlyStopping counter: 11 out of 50
# Epoch: 131/600 	Training Loss: 0.204120 	3209s
# EarlyStopping counter: 12 out of 50
# Epoch: 132/600 	Training Loss: 0.179374 	3233s
# EarlyStopping counter: 13 out of 50
# Epoch: 133/600 	Training Loss: 0.174566 	3258s
# EarlyStopping counter: 14 out of 50
# Epoch: 134/600 	Training Loss: 0.174173 	3282s
# EarlyStopping counter: 15 out of 50
# Epoch: 135/600 	Training Loss: 0.178143 	3307s
# EarlyStopping counter: 16 out of 50
# Epoch: 136/600 	Training Loss: 0.196237 	3331s
# EarlyStopping counter: 17 out of 50
# Epoch: 137/600 	Training Loss: 0.171939 	3355s
# EarlyStopping counter: 18 out of 50
# Epoch: 138/600 	Training Loss: 0.172981 	3380s
# EarlyStopping counter: 19 out of 50
# Epoch: 139/600 	Training Loss: 0.171529 	3404s
# EarlyStopping counter: 20 out of 50
# Epoch: 140/600 	Training Loss: 0.167636 	3429s
# EarlyStopping counter: 21 out of 50
# Epoch: 141/600 	Training Loss: 0.169482 	3453s
# EarlyStopping counter: 22 out of 50
# Epoch: 142/600 	Training Loss: 0.170009 	3477s
# EarlyStopping counter: 23 out of 50
# Epoch: 143/600 	Training Loss: 0.169981 	3502s
# EarlyStopping counter: 24 out of 50
# Epoch: 144/600 	Training Loss: 0.167605 	3526s
# EarlyStopping counter: 25 out of 50
# Epoch: 145/600 	Training Loss: 0.221927 	3551s
# EarlyStopping counter: 26 out of 50
# Epoch: 146/600 	Training Loss: 0.173157 	3575s
# EarlyStopping counter: 27 out of 50
# Epoch: 147/600 	Training Loss: 0.162346 	3600s
# Epoch: 148/600 	Training Loss: 0.168344 	3624s
# EarlyStopping counter: 1 out of 50
# Epoch: 149/600 	Training Loss: 0.165079 	3648s
# EarlyStopping counter: 2 out of 50
# Epoch: 150/600 	Training Loss: 0.166847 	3673s
# EarlyStopping counter: 3 out of 50
# Epoch: 151/600 	Training Loss: 0.168091 	3697s
# EarlyStopping counter: 4 out of 50
# Epoch: 152/600 	Training Loss: 0.169217 	3771s
# EarlyStopping counter: 5 out of 50
# Epoch: 153/600 	Training Loss: 0.172434 	4085s
# EarlyStopping counter: 6 out of 50
# Epoch: 154/600 	Training Loss: 0.161000 	4111s
# EarlyStopping counter: 7 out of 50
# Epoch: 155/600 	Training Loss: 0.166377 	4135s
# EarlyStopping counter: 8 out of 50
# Epoch: 156/600 	Training Loss: 0.161475 	4159s
# EarlyStopping counter: 9 out of 50
# Epoch: 157/600 	Training Loss: 0.160823 	4184s
# EarlyStopping counter: 10 out of 50
# Epoch: 158/600 	Training Loss: 0.159686 	4208s
# EarlyStopping counter: 11 out of 50
# Epoch: 159/600 	Training Loss: 0.158751 	4233s
# EarlyStopping counter: 12 out of 50
# Epoch: 160/600 	Training Loss: 0.161862 	4257s
# EarlyStopping counter: 13 out of 50
# Epoch: 161/600 	Training Loss: 0.164769 	4281s
# EarlyStopping counter: 14 out of 50
# Epoch: 162/600 	Training Loss: 0.157083 	4306s
# EarlyStopping counter: 15 out of 50
# Epoch: 163/600 	Training Loss: 0.170434 	4330s
# EarlyStopping counter: 16 out of 50
# Epoch: 164/600 	Training Loss: 0.173895 	4355s
# EarlyStopping counter: 17 out of 50
# Epoch: 165/600 	Training Loss: 0.154835 	4379s
# EarlyStopping counter: 18 out of 50
# Epoch: 166/600 	Training Loss: 0.160167 	4404s
# EarlyStopping counter: 19 out of 50
# Epoch: 167/600 	Training Loss: 0.152615 	4428s
# EarlyStopping counter: 20 out of 50
# Epoch: 168/600 	Training Loss: 0.157916 	4452s
# EarlyStopping counter: 21 out of 50
# Epoch: 169/600 	Training Loss: 0.155250 	4477s
# EarlyStopping counter: 22 out of 50
# Epoch: 170/600 	Training Loss: 0.151890 	4501s
# EarlyStopping counter: 23 out of 50
# Epoch: 171/600 	Training Loss: 0.204282 	4526s
# EarlyStopping counter: 24 out of 50
# Epoch: 172/600 	Training Loss: 0.153732 	4550s
# EarlyStopping counter: 25 out of 50
# Epoch: 173/600 	Training Loss: 0.151631 	4575s
# EarlyStopping counter: 26 out of 50
# Epoch: 174/600 	Training Loss: 0.149784 	4599s
# EarlyStopping counter: 27 out of 50
# Epoch: 175/600 	Training Loss: 0.155504 	4623s
# EarlyStopping counter: 28 out of 50
# Epoch: 176/600 	Training Loss: 0.150890 	4648s
# EarlyStopping counter: 29 out of 50
# Epoch: 177/600 	Training Loss: 0.148435 	4673s
# Epoch: 178/600 	Training Loss: 0.149971 	4698s
# EarlyStopping counter: 1 out of 50
# Epoch: 179/600 	Training Loss: 0.153428 	4723s
# EarlyStopping counter: 2 out of 50
# Epoch: 180/600 	Training Loss: 0.147104 	4747s
# EarlyStopping counter: 3 out of 50
# Epoch: 181/600 	Training Loss: 0.151212 	4772s
# EarlyStopping counter: 4 out of 50
# Epoch: 182/600 	Training Loss: 0.154454 	4797s
# EarlyStopping counter: 5 out of 50
# Epoch: 183/600 	Training Loss: 0.228962 	4821s
# EarlyStopping counter: 6 out of 50
# Epoch: 184/600 	Training Loss: 0.164397 	4846s
# EarlyStopping counter: 7 out of 50
# Epoch: 185/600 	Training Loss: 0.144900 	4871s
# Epoch: 186/600 	Training Loss: 0.146044 	4896s
# EarlyStopping counter: 1 out of 50
# Epoch: 187/600 	Training Loss: 0.144458 	4920s
# EarlyStopping counter: 2 out of 50
# Epoch: 188/600 	Training Loss: 0.144757 	4945s
# Epoch: 189/600 	Training Loss: 0.144792 	4970s
# EarlyStopping counter: 1 out of 50
# Epoch: 190/600 	Training Loss: 0.163871 	4995s
# EarlyStopping counter: 2 out of 50
# Epoch: 191/600 	Training Loss: 0.164128 	5019s
# EarlyStopping counter: 3 out of 50
# Epoch: 192/600 	Training Loss: 0.143177 	5044s
# EarlyStopping counter: 4 out of 50
# Epoch: 193/600 	Training Loss: 0.141574 	5069s
# EarlyStopping counter: 5 out of 50
# Epoch: 194/600 	Training Loss: 0.140879 	5093s
# EarlyStopping counter: 6 out of 50
# Epoch: 195/600 	Training Loss: 0.141704 	5118s
# EarlyStopping counter: 7 out of 50
# Epoch: 196/600 	Training Loss: 0.147830 	5143s
# EarlyStopping counter: 8 out of 50
# Epoch: 197/600 	Training Loss: 0.143597 	5167s
# EarlyStopping counter: 9 out of 50
# Epoch: 198/600 	Training Loss: 0.145366 	5192s
# EarlyStopping counter: 10 out of 50
# Epoch: 199/600 	Training Loss: 0.143800 	5217s
# EarlyStopping counter: 11 out of 50
# Epoch: 200/600 	Training Loss: 0.144425 	5242s
# EarlyStopping counter: 12 out of 50
# Epoch: 201/600 	Training Loss: 0.145461 	5267s
# EarlyStopping counter: 13 out of 50
# Epoch: 202/600 	Training Loss: 0.144295 	5292s
# EarlyStopping counter: 14 out of 50
# Epoch: 203/600 	Training Loss: 0.143607 	5316s
# EarlyStopping counter: 15 out of 50
# Epoch: 204/600 	Training Loss: 0.155606 	5341s
# EarlyStopping counter: 16 out of 50
# Epoch: 205/600 	Training Loss: 0.145923 	5366s
# EarlyStopping counter: 17 out of 50
# Epoch: 206/600 	Training Loss: 0.138280 	5390s
# EarlyStopping counter: 18 out of 50
# Epoch: 207/600 	Training Loss: 0.139351 	5415s
# EarlyStopping counter: 19 out of 50
# Epoch: 208/600 	Training Loss: 0.139596 	5440s
# EarlyStopping counter: 20 out of 50
# Epoch: 209/600 	Training Loss: 0.142578 	5464s
# EarlyStopping counter: 21 out of 50
# Epoch: 210/600 	Training Loss: 0.269577 	5489s
# EarlyStopping counter: 22 out of 50
# Epoch: 211/600 	Training Loss: 0.169956 	5513s
# EarlyStopping counter: 23 out of 50
# Epoch: 212/600 	Training Loss: 0.142362 	5538s
# EarlyStopping counter: 24 out of 50
# Epoch: 213/600 	Training Loss: 0.135381 	5562s
# EarlyStopping counter: 25 out of 50
# Epoch: 214/600 	Training Loss: 0.133736 	5587s
# EarlyStopping counter: 26 out of 50
# Epoch: 215/600 	Training Loss: 0.132803 	5612s
# EarlyStopping counter: 27 out of 50
# Epoch: 216/600 	Training Loss: 0.134962 	5636s
# EarlyStopping counter: 28 out of 50
# Epoch: 217/600 	Training Loss: 0.131918 	5660s
# EarlyStopping counter: 29 out of 50
# Epoch: 218/600 	Training Loss: 0.135212 	5685s
# EarlyStopping counter: 30 out of 50
# Epoch: 219/600 	Training Loss: 0.137721 	5709s
# EarlyStopping counter: 31 out of 50
# Epoch: 220/600 	Training Loss: 0.135646 	5733s
# EarlyStopping counter: 32 out of 50
# Epoch: 221/600 	Training Loss: 0.133393 	5758s
# EarlyStopping counter: 33 out of 50
# Epoch: 222/600 	Training Loss: 0.135130 	5782s
# EarlyStopping counter: 34 out of 50
# Epoch: 223/600 	Training Loss: 0.135928 	5806s
# EarlyStopping counter: 35 out of 50
# Epoch: 224/600 	Training Loss: 0.133959 	5831s
# EarlyStopping counter: 36 out of 50
# Epoch: 225/600 	Training Loss: 0.148522 	5855s
# EarlyStopping counter: 37 out of 50
# Epoch: 226/600 	Training Loss: 0.141126 	5880s
# EarlyStopping counter: 38 out of 50
# Epoch: 227/600 	Training Loss: 0.131515 	5905s
# EarlyStopping counter: 39 out of 50
# Epoch: 228/600 	Training Loss: 0.136644 	5929s
# EarlyStopping counter: 40 out of 50
# Epoch: 229/600 	Training Loss: 0.135530 	5954s
# EarlyStopping counter: 41 out of 50
# Epoch: 230/600 	Training Loss: 0.134897 	5978s
# EarlyStopping counter: 42 out of 50
# Epoch: 231/600 	Training Loss: 0.153593 	6003s
# EarlyStopping counter: 43 out of 50
# Epoch: 232/600 	Training Loss: 0.145198 	6027s
# EarlyStopping counter: 44 out of 50
# Epoch: 233/600 	Training Loss: 0.140871 	6052s
# EarlyStopping counter: 45 out of 50
# Epoch: 234/600 	Training Loss: 0.128851 	6077s
# EarlyStopping counter: 46 out of 50
# Epoch: 235/600 	Training Loss: 0.131569 	6101s
# EarlyStopping counter: 47 out of 50
# Epoch: 236/600 	Training Loss: 0.130148 	6126s
# EarlyStopping counter: 48 out of 50
# Epoch: 237/600 	Training Loss: 0.132126 	6150s
# EarlyStopping counter: 49 out of 50
# Epoch: 238/600 	Training Loss: 0.133125 	6175s
# EarlyStopping counter: 50 out of 50
# best_testloss:0.275	 epoch:187
# Early stopping

# %%
zoomin = 10
zoomout = 238
plotTraining(lossTrainArr, lossTestArr, LrCArr, bestLoss, zoomin, zoomout)

# %%
# create testdataset

damaged_img_path = 'testdataset/damaged_image' 

if lidar_mode == 'sparse':
    lidar_path = 'testdataset/lidar_tensor/sparse'
else:
    lidar_path = 'testdataset/lidar_tensor/dense'

label_path = 'testdataset/ori_image'

damaged_img_list = sorted(glob.glob(damaged_img_path + '/*'))
lidar_list = sorted(glob.glob(lidar_path + '/*'))
label_list = sorted(glob.glob(label_path + '/*'))

learning_rate = 1e-4
batch_size = 32

TestDataset = CreateDatasets(label_list, damaged_img_list, lidar_list)
new_testloader = DataLoader(dataset=TestDataset, batch_size=batch_size, shuffle=False, num_workers=0, drop_last=True)

# load model
removal_layer = nn.Sequential()

encoder_img = SimpleAutoencoder()
encoder_img.decoder = removal_layer


encoder_lidar = SimpleAutoencoder()
encoder_lidar.decoder = removal_layer


decoder = SimpleAutoencoder()
decoder.encoder = removal_layer

channelAdjust = EncoderFusion()

test_model_best = TwoEncoderOneDecoder(encoder_img, encoder_lidar, decoder, channelAdjust)
# for name, value in test_model_best.named_parameters():
#     print(name)

# test_model_last.load_state_dict(torch.load('model_save/damage_{}/last_model_{}.pth'.format(damage_label, experimentIndex)))

# if lidar_mode == 'sparse':
#     test_model_best.load_state_dict(
#     torch.load('model_save/fusion/3_sparse_best_model_600_32_20230521_174942.pth')
# )
# else:
#     test_model_best.load_state_dict(
#     torch.load('model_save/fusion/3_dense_best_model_600_32_20230522_072759.pth')
# )
# # test_model.to(device)
# test_model_last.eval()

test_model_best.load_state_dict(
    torch.load('model_save/fusion/8_allchanged_best_model_600_32_20230523_144827.pth')
)
test_model_best.eval()


dataiter = iter(new_testloader)
label, damaged_img, lidar = next(dataiter)
# label, damaged_img, lidar = next(dataiter)
# label, damaged_img, lidar = next(dataiter)
# label, damaged_img, lidar = next(dataiter)
# label, damaged_img, lidar = next(dataiter)
# label, damaged_img, lidar = next(dataiter)
# label, damaged_img, lidar = next(dataiter)
# label, damaged_img, lidar = next(dataiter)




output = test_model_best(damaged_img, lidar)

# %%
##################################################
# visualize one batch of the validation images #
##################################################
# test_model.to(device)


removal_layer = nn.Sequential()

encoder_img = SimpleAutoencoder()
encoder_img.decoder = removal_layer


encoder_lidar = SimpleAutoencoder()
encoder_lidar.decoder = removal_layer


decoder = SimpleAutoencoder()
decoder.encoder = removal_layer

channelAdjust = EncoderFusion()

test_model_best = TwoEncoderOneDecoder(encoder_img, encoder_lidar, decoder, channelAdjust)
# for name, value in test_model_best.named_parameters():
#     print(name)

if lidar_mode == 'sparse':
    test_model_best.load_state_dict(
    torch.load('model_save/fusion/3_sparse_best_model_600_32_20230521_174942.pth')
)
else:
    test_model_best.load_state_dict(
    torch.load('model_save/fusion/3_dense_best_model_600_32_20230522_072759.pth')
)

# test_model.to(device)
# test_model_last.eval()
test_model_best.eval()


# obtain one batch of test images
dataiter = iter(new_testloader)
# dataiter = iter(valloader)

label, damaged_img, lidar = next(dataiter)

# get sample outputs
output = test_model_best(damaged_img, lidar)

# prep images for display
# i = 31
for i in range(32):

    img1 = label[i].numpy()
    img1 = img1.transpose(1, 2, 0)
    img2 = damaged_img[i].numpy()
    img2 = img2.transpose(1, 2, 0)
    img3 = lidar[i].detach().numpy()
    img3 = img3.transpose(1, 2, 0)
    img4 = output[i].detach().numpy()
    img4 = img4.transpose(1, 2, 0)


    ax = plt.subplot(1, 4, 1)
    plt.xticks([])
    plt.yticks([])
    # ax.set_title('label')
    plt.imshow(img1,cmap='gray')

    ax = plt.subplot(1, 4, 2)
    plt.xticks([])
    plt.yticks([])
    # ax.set_title('damaged image')
    plt.imshow(img2,cmap='gray')

    ax = plt.subplot(1, 4, 3)
    plt.xticks([])
    plt.yticks([])
    # ax.set_title('lidar')
    plt.imshow(img3)

    ax = plt.subplot(1, 4, 4)
    plt.xticks([])
    plt.yticks([])
    #  ax.set_title('reconstructed image')
    plt.imshow(img4, cmap='gray')

    # plt.savefig('fig_save/{}.png'.format(i))
    
plt.show()

# %%
import cv2
from PIL import Image
from torchvision import transforms
from matplotlib import pyplot as plt


toPIL = transforms.ToPILImage()

# # prep images for display
# for i in range(32):
#     img1 = label[i]
#     img2 = damaged_img[i]
#     img3 = lidar[i]
#     img4 = output[i]
#     # print(img1.shape, img3.shape)
#     # print(type(img1),type(img3))
#     # im1 = toPIL(img1)
#     im4 = toPIL(img4)
#     im3 = toPIL(img3)
#     name = '%02d' %i

#     # im1.save('RecosntructedImages/ori_img/{}.png'.format(name))
#     # im2.save('RecosntructedImages/masked_img/{}.png'.format(name))
#     # im4.save('output_save/5_main_fusion_3_dense/A/{}.png'.format(name))
#     im3.save('output_save/lidar_sparse_testing/{}.png'.format(name))

    
import numpy as np
import cv2

for i in range(32):
    if i ==13:
        img1 = label[i].numpy()
        img1 = img1.transpose(1, 2, 0)
        img2 = damaged_img[i].numpy()
        img2 = img2.transpose(1, 2, 0)
        img3 = lidar[i].detach().numpy()
        img3 = img3.transpose(1, 2, 0)
        img4 = output[i].detach().numpy()
        img4 = img4.transpose(1, 2, 0)

        name = '%02d' %i
        filepath = 'output_save/test/{}.png'.format(name)

        # 调用函数将灰度图像保存为RGB图像的PNG
        # cv2.imwrite(filepath, img4)
        plt.xticks([])
        plt.yticks([])
        plt.imshow(img4, cmap='gray')
        plt.savefig(filepath)
        plt.colorbar()
        plt.show()

# %%
# MSE for all damages
criterion = nn.MSELoss()
criterion.to(device)

for i, batch in enumerate(new_testloader):# i -->index of batch
    count = 0
    for j in range (batch_size):
        img1 = label[i]
        img3 = output[i]
        mse = criterion(img1,img3)
        mse = round(mse.item(),6)
        count = count+mse

    mse_mean = round(count,3)
    print(mse_mean)
# Out:
# 0.602
# 0.201
# 0.515
# 0.24
# 0.165
# 0.821
# 0.152
# 0.384

# %%
# # regional mse

# batch_size = 32

# def create_mask(image_shape, block_size, num_blocks):
#     mask = np.ones(image_shape, dtype=np.float32) 
#     block_size_px = (int(image_shape[0] * block_size), int(image_shape[1] * block_size))
#     np.random.seed(6)

#     for _ in range(num_blocks):
#         top_left = np.random.randint(0, image_shape[0] - block_size_px[0] + 1), np.random.randint(0, image_shape[1] - block_size_px[1] + 1)
#         bottom_right = top_left[0] + block_size_px[0], top_left[1] + block_size_px[1]
#         mask[top_left[0]:bottom_right[0], top_left[1]:bottom_right[1]] = 0
        
#     return mask


# block_size = 0.2  # 方块大小为原图大小的百分比
# num_blocks = 16  # 方块数量

# count = 0

# for j in range(label.size(0)):
#     ori_img_np = label[j][0].detach().numpy()
#     output_np = output[j][0].detach().numpy()
#     mask = create_mask(ori_img_np.shape[:2], block_size, num_blocks)
#     local_mse = np.mean(np.square(output_np - ori_img_np) * mask)
#     count = count+local_mse
# local_mse = round(count/batch_size, 6)

# # baseline
# for j in range(label.size(0)):
#     ori_img_np = label[j][0].detach().numpy()
#     output_np = output[j][0].detach().numpy()
#     mask = create_mask(ori_img_np.shape[:2], block_size, num_blocks)
#     local_mse = np.mean(np.square(output_np - ori_img_np) * mask)
#     count = count+local_mse
# local_mse = round(count/batch_size, 6)

# print(local_mse)
# Out:
# 0.003846

# %%
import cv2
import os
import numpy

masked_region_list = []
original_image_list = []

image_path = 'testdataset/ori_image'
images = sorted(glob.glob(image_path + '/*'))[0:32]
damage_label = 'A'

def create_mask(image_shape, block_size, num_blocks):
    mask = np.ones(image_shape, dtype=np.float32) 
    block_size_px = (int(image_shape[0] * block_size), int(image_shape[1] * block_size))
    np.random.seed(6)
    masked_region = []

    for _ in range(num_blocks):
        top_left = np.random.randint(0, image_shape[0] - block_size_px[0] + 1), np.random.randint(0, image_shape[1] - block_size_px[1] + 1)
        bottom_right = top_left[0] + block_size_px[0], top_left[1] + block_size_px[1]
        mask[top_left[0]:bottom_right[0], top_left[1]:bottom_right[1]] = 0
        masked_region.append((top_left, bottom_right))
        
    return mask, masked_region


for i in range(len(images)):
    image = cv2.imread(images[i])
    image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    ori_img_name = os.path.basename(images[i])

    block_size = 0.2  # 方块大小为原图大小的百分比
    num_blocks = 16  # 方块数量
    mask, masked_region = create_mask(image.shape[:2], block_size, num_blocks)
    masked_region_list.append(masked_region)
    original_image_list.append(image)
    damaged_img1 = image * mask
    # cv2.imwrite(f'testdataset/damaged_image/{damage_label}_{ori_img_name}', damaged_img1)

regional_mse_list = []

for i in range(len(images)):
    original_image = original_image_list[i]
    masked_region = masked_region_list[i]
    original_image = (original_image-np.min(original_image))/(np.max(original_image)-np.min(original_image))
    

    
    # Obtain the output reconstructed image
    output_image = output[i][0].detach().numpy()  # Replace this with the code to get the output image from your image reconstruction network
    # output_image = (output_image-np.min(output_image))/(np.max(output_image)-np.min(output_image))
    
    mse = 0
    num_pixels = 0

    for region in masked_region:
        top_left, bottom_right = region
        original_pixels = original_image[top_left[0]:bottom_right[0], top_left[1]:bottom_right[1]]
        output_pixels = output_image[top_left[0]:bottom_right[0], top_left[1]:bottom_right[1]]
        diff = original_pixels.astype(np.float32) - output_pixels.astype(np.float32)
        mse += np.sum(diff ** 2)
        num_pixels += original_pixels.size

    mse /= num_pixels
    regional_mse_list.append(mse)

print(np.mean(regional_mse_list))
# Out:
# 0.020927276844668087

# %%
# SSIM

import torch
from skimage.metrics import structural_similarity as ssim
import glob


metric_value_list = []
batch_size = 32


for i, batch in enumerate(new_testloader):
    label, damaged_img, lidar = batch
    count = 0
    for j in range(label.size(0)):
        ori_img_np = label[j][0].detach().cpu().numpy()
        output_np = output[j][0].detach().cpu().numpy()
        ssim_img, diff = ssim(ori_img_np, output_np, full=True, data_range=1.0)
        count = count + ssim_img
    ssim_img = round(count / label.size(0), 3)
    print(ssim_img)
#     metric_value_list.append(ssim_img)

# print(metric_value_list)
# Out:
# 0.654
# 0.227
# 0.212
# 0.199
# 0.201
# 0.204
# 0.216
# 0.214

# %%
# LLIPS metrics

import lpips

loss_fn = lpips.LPIPS(net='alex')


for i, batch in enumerate(new_testloader):  # i -->index of batch
    label, damaged_img, lidar = batch
    count = 0
    for j in range(label.size(0)):
        # ori_img_np = ori_img[j][0].detach().numpy()
        # output_np = output[j][0].detach().numpy()
        lpips_img = loss_fn.forward(label, output)
        sum_result = (torch.sum(lpips_img)).item()
        count = count+sum_result
        # count = count.item()
    lpips_img = round(count/label.size(0),3)
    print(lpips_img)
#     metric_value_list.append(lpips_img)

# print(f'scuccess: {metric_value_list}')
# Out:
# Setting up [LPIPS] perceptual loss: trunk [alex], v[0.1], spatial [off]
# Loading model from: /usr/local/Anaconda3-2021.11-Linux-x86_64/envs/pytorch/lib/python3.8/site-packages/lpips/weights/v0.1/alex.pth
# 8.739
# 17.011
# 17.312
# 17.636
# 17.43
# 17.243
# 17.537
# 17.527
# 17.676

# %%
# SSIM

import torch
from skimage.metrics import structural_similarity as ssim
import glob


metric_value_list = []
batch_size = 32


for i, batch in enumerate(new_testloader):
    label, damaged_img, lidar = batch
    count = 0
    for j in range(label.size(0)):
        ori_img_np = label[j][0].detach().cpu().numpy()
        output_np = output[j][0].detach().cpu().numpy()
        ssim_img, diff = ssim(ori_img_np, output_np, full=True, data_range=1.0)
        count = count + ssim_img
    ssim_img = round(count / label.size(0), 3)
    print(ssim_img)
#     metric_value_list.append(ssim_img)

# print(metric_value_list)
# Out:
# 0.678
# 0.237
# 0.224
# 0.21
# 0.209
# 0.213
# 0.227
# 0.226
# 0.237

# %%
8.7
16.697
